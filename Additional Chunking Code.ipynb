# %%
import pandas as pd
import numpy as np
import nltk
import re
from tabulate import tabulate
import pickle

# %% [markdown]
# ## Helper Functions

# %%
from nltk.corpus import wordnet as wn, brown
from nltk.corpus import stopwords

stopwords = stopwords.words('english')
stemmer = nltk.stem.porter.PorterStemmer()
lemmatizer = nltk.WordNetLemmatizer()

def filter_terms(in_str, sub_list=None):
    if sub_list is None:
        return in_str

    for pattern in sub_list:
        in_str = re.sub("\\b" + pattern + "\\b", '', in_str)

    return in_str

def normalize(word):
    """Normalizes words to lowercase and stems and lemmatizes it."""
    word = word.lower()
    word = stemmer.stem_word(word)
    word = lemmatizer.lemmatize(word)
    return word

def acceptable_word(word):
    """Checks conditions for acceptable word: length, stopword."""
    accepted = bool(2 <= len(word) <= 40
        and word.lower() not in stopwords)
    return accepted

def leaves(tree, phrase):
    """Finds NP (nounphrase) leaf nodes of a chunk tree."""
    for subtree in tree.subtrees(filter = lambda t: t.label()==phrase):
        yield subtree.leaves()
        
def get_terms(tree, phrase):
    for leaf in leaves(tree, phrase):
        term = [ w.lower() for w,t in leaf if w ]
        yield term

# %% [markdown]
# # POS Tagger

# %% [markdown]
# The default pos_tag method from nltk is too slow.
#
# Training a new backoff tagger with the brown brown corpus.

# %%
from nltk.corpus import brown

default_tagger = nltk.DefaultTagger('NN')

brown_tagged_sents = brown.tagged_sents()

def build_backoff_tagger(train_sents):
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    t3 = nltk.TrigramTagger(train_sents, backoff=t2)
    return t3

# Pickle the backoff tagger so that we don't have to retrain
try:
    with open('ngram_tagger.pickle', 'rb') as f:
        ngram_tagger = pickle.load(f)
    ngram_tagger
except NameError:
    ngram_tagger = build_backoff_tagger(brown_tagged_sents)
    with open('ngram_tagger.pickle', 'wb') as f:
        pickle.dump(ngram_tagger, f)

# %% [markdown]
# ## Data Prep

# %%
dataset = pd.read_csv("dataset.txt", delimiter="|", encoding="ISO-8859-1", index_col="AutoID")
# Remove non text chars
dataset["FullText"] = dataset["FullText"].apply(lambda x: (re.sub('[^a-zA-Z ]+', '', x).strip()))

# We only care about banks a-d
# every other bank is irrelevant
relevant_banks = ["twit_hndl_BankA", "twit_hndl_BankB", 
                  "twit_hndl_BankC", "twit_hndl_BankD", 
                  "BankA", "BankB", "BankC", "BankD"]

# Filter the dataset for only the banks that we care about
print("before:", len(dataset))
dataset = dataset[dataset["FullText"].apply(lambda x: any(substring in x for substring in relevant_banks))]
print("after:", len(dataset))
print(dataset.head())

# Filter just Facebook data
fb_mask = (dataset["MediaType"] == "facebook")
fb_data = dataset[fb_mask].reset_index()
fb_data.set_index("AutoID", inplace=True)
# Out:
# before: 220377
# after: 192180
#              Date  Year  Month MediaType  \
# AutoID
# 1       8/26/2015  2015      8   twitter
# 2        8/5/2015  2015      8   twitter
# 3       8/12/2015  2015      8   twitter
# 4        8/5/2015  2015      8   twitter
# 5       8/12/2015  2015      8   twitter
#
#                                                  FullText
# AutoID
# 1       ways the internet of things will change BankB ...
# 2       BankB BankB Name downgrades apple stock to neu...
# 3             BankB returns to profit on INTERNET board t
# 4       BankB tells advisers to exit paulson hedge fun...
# 5       BankC may plead guilty over foreign exchange p...

# %% [markdown]
# ## Use Topics from Bigram Collocations to Tag Messages

# %%
# Assign Messages to Banks
fb_data["BankA"] = fb_data["FullText"].str.strip().str.lower().str.contains("banka|bank a", regex=True)
fb_data["BankB"] = fb_data["FullText"].str.strip().str.lower().str.contains("bankb|bank b", regex=True)
fb_data["BankC"] = fb_data["FullText"].str.strip().str.lower().str.contains("bankc|bank c", regex=True)
fb_data["BankD"] = fb_data["FullText"].str.strip().str.lower().str.contains("bankd|bank d", regex=True)

# Assign Topics to Banks
# Customer Service
fb_data["Customer Service"] = fb_data["FullText"].str.strip().str.lower().str.contains("customer service", regex=True)
fb_data["Close Account"] = fb_data["FullText"].str.strip().str.lower().str.contains("close account", regex=True)
fb_data["New Bank"] = fb_data["FullText"].str.strip().str.lower().str.contains("new bank", regex=True)

# Adivising
fb_data["Financial Advisers"] = fb_data["FullText"].str.strip().str.lower().str.contains("financial advisers", regex=True)
fb_data["Wealth Manager"] = fb_data["FullText"].str.strip().str.lower().str.contains("wealth managers", regex=True)
fb_data["Bank Teller"] = fb_data["FullText"].str.strip().str.lower().str.contains("bank teller", regex=True)

# Product
fb_data["Bank Account"] = fb_data["FullText"].str.strip().str.lower().str.contains("bank account", regex=True)
fb_data["Checking Account"] = fb_data["FullText"].str.strip().str.lower().str.contains("checking account", regex=True)
fb_data["Credit Card"] = fb_data["FullText"].str.strip().str.lower().str.contains("credit card", regex=True)
fb_data["Debit Card"] = fb_data["FullText"].str.strip().str.lower().str.contains("debit card", regex=True)
fb_data["Account Bank"] = fb_data["FullText"].str.strip().str.lower().str.contains("account bank", regex=True)
fb_data["Money Account"] = fb_data["FullText"].str.strip().str.lower().str.contains("money account", regex=True)
fb_data["Bank Card"] = fb_data["FullText"].str.strip().str.lower().str.contains("bank card", regex=True)
fb_data["Savings Account"] = fb_data["FullText"].str.strip().str.lower().str.contains("savings account", regex=True)

# %%
fb_data = fb_data[fb_data[["Customer Service", "Close Account", "New Bank", "Financial Advisers", 
                           "Wealth Manager", "Bank Teller", "Bank Account", "Checking Account", 
                           "Credit Card", "Debit Card", "Account Bank", "Money Account", "Bank Card", 
                           "Savings Account"]].any(1)]

# %% [markdown]
# ## Define Chunking Functions

# %%
def get_noun_phrases(some_text):
    # Define Chunker Rules
    # Attempt rules individually to evaluate
    # Taken from Su Nam Kim Paper...
    #     {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
    #     {<VB.*>+<RB><JJ.*>+}
    #     {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
    #     {<PRP>?<NN.*>+<VB.*><DT|RB>?<JJ.*>+<CC>?<JJ>+?}
    #        {<DT.*><WP.*><VBP>*<RB>*<VBN><IN><NN>}
    #         {<NN|NNS|NNP|NNPS><IN>*<NN|NNS|NNP|NNPS>+}
    #         {<JJ>*<NN|NNS|NNP|NNPS><CC>*<NN|NNS|NNP|NNPS>+}
    #         {<JJ>*<NN|NNS|NNP|NNPS>+}
    #         {<CS.*|RB.*><PP$><BEDZ><RP>?<VB.*><NN.*>+}
    noun_chunker = nltk.RegexpParser('''
        NP:
        # hoping to find things like:
        # "customer service is the worst"
        # "atms are horrible"
        {(<NN.*|N.*>+<BE.*><DT>?<JJ.*>)}
    ''')
    noun_phrases = []
    tree = noun_chunker.parse(some_text)

    noun_phrase = [w for w in get_terms(tree, 'NP')]
    if len(noun_phrase) > 0:
        for i, phrase in enumerate(noun_phrase):
            noun_phrases.append(" ".join(phrase))
    return noun_phrases
    
def get_adj_phrases(some_text):
    # Define Chunker Rules
    noun_chunker = nltk.RegexpParser('''
        AJ:
            {<JJ.*><NN.*>+}
            {<JJ.*>}
    ''')
    adj_phrases = []
    tree = noun_chunker.parse(some_text)

    adj_phrase = [w for w in get_terms(tree, 'AJ')]
    if len(adj_phrase) > 0:
        for i, phrase in enumerate(adj_phrase):
            adj_phrases.append(" ".join(phrase))
    return adj_phrases

# %% [markdown]
# ## Chunk Messages and Attach to Dataframe

# %%
fb_data["tagged"] = fb_data["FullText"].apply(lambda x: ngram_tagger.tag(nltk.tokenize.word_tokenize(x)))
fb_data["noun_phrases"] = fb_data["tagged"].apply(lambda x: ",".join(get_noun_phrases(x)))
# fb_data["noun_phrases"][fb_data["noun_phrases"].apply(len) > 0]

# %%
fb_data["tagged"] = fb_data["FullText"].apply(lambda x: ngram_tagger.tag(nltk.tokenize.word_tokenize(x)))
fb_data["adj_phrases"] = fb_data["tagged"].apply(lambda x: ",".join(get_adj_phrases(x)))
# fb_data["adj_phrases"][fb_data["adj_phrases"].apply(len) > 0]

# %%
# saving to use for viz
fb_data.to_csv("data/fb_data.csv")

# %%
# for exploration tool
fb_data.reset_index().to_json("/Users/vijayv/code/sound_cloud_analytics/project/static/data/fb_data.json", orient="index")

# %% [markdown]
# # Warning:
#
# ## Code below here is very exploratory and is written very verbosely
#
# ## High Level Topics
#
# Previously used to pickle tagged data to be reused later by the keyphrase extractor notebook.

# %%
# Add topics here
groups = {
    "customer_service": np.array(["customer service", "close account", "new bank"]),
    "advising": np.array(["financial advisers", "wealth managers", "bank teller"]),
    "product": np.array(["bank account", "checking account", "credit card", "debit card", "account bank", "money account", "bank card", "savings account"]),
}

for topic_name, topic in groups.items():
    pattern_string = "|".join(topic)
    pattern = re.compile(pattern_string)
    filters = fb_data["FullText"].str.contains(pattern, regex=True)
    df = fb_data[filters]
    # Remove any data with an internet address
    df = df[~df["FullText"].str.contains("INTERNET")]
    df.to_csv("data/" + topic_name + ".csv", index=False)
    # POS tag tokens from comments
    df_tagged = np.array([ngram_tagger.tag(nltk.tokenize.word_tokenize(comment)) for comment in df["FullText"]])
    with open("data/" + topic_name + '.pickle', 'wb') as f:
        pickle.dump(df_tagged, f)

# %% [markdown]
# ## Group: Customer Service

# %%
df_customer_service = pd.read_csv("data/customer_service.csv", index_col="AutoID")
df_customer_service.describe()
# Out:
#               Year        Month
# count  1243.000000  1243.000000
# mean   2014.503620     7.122285
# std       0.500188     3.459847
# min    2014.000000     1.000000
# 25%    2014.000000     4.000000
# 50%    2015.000000     8.000000
# 75%    2015.000000    10.000000
# max    2015.000000    12.000000

# %%
df_cs = df_customer_service[df_customer_service["FullText"].str.contains("customer service")]
df_close_account = df_customer_service[df_customer_service["FullText"].str.contains("close account")]
df_new_bank = df_customer_service[df_customer_service["FullText"].str.contains("new bank")]
print(df_close_account.describe())
# Out:
#               Year     Month
# count    10.000000  10.00000
# mean   2014.400000   8.10000
# std       0.516398   2.84605
# min    2014.000000   3.00000
# 25%    2014.000000   6.00000
# 50%    2014.000000   8.50000
# 75%    2015.000000  10.50000
# max    2015.000000  12.00000

# %%
df_cs_tagged = np.array([ngram_tagger.tag(nltk.tokenize.word_tokenize(comment)) for comment in df_cs["FullText"]])
df_close_account_tagged = np.array([ngram_tagger.tag(nltk.tokenize.word_tokenize(comment)) for comment in df_close_account["FullText"]])
df_new_bank_account_tagged = np.array([ngram_tagger.tag(nltk.tokenize.word_tokenize(comment)) for comment in df_new_bank["FullText"]])
picked_data = df_new_bank_account_tagged

# %%
try:
    # data/bank_services.pickle or data/customer_service.pickle
    with open('data/customer_service.pickle', 'rb') as f:
        picked_data = pickle.load(f)
except NameError as e:
    print(e)

# %%
# Define Chunker Rules
# Taken from Su Nam Kim Paper...
# Modified for brown tagset
#     {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
#     {<VB.*>+<RB><JJ.*>+}
#     {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
#     Work with Penn Treebank
#     {<PRP>?<NN.*>+<VB.*><DT|RB>?<JJ.*>+<CC>?<JJ>+?}
#        {<DT.*><WP.*><VBP>*<RB>*<VBN><IN><NN>}
#         {<NN|NNS|NNP|NNPS><IN>*<NN|NNS|NNP|NNPS>+}
#         {<JJ>*<NN|NNS|NNP|NNPS><CC>*<NN|NNS|NNP|NNPS>+}
#         {<JJ>*<NN|NNS|NNP|NNPS>+}
#         {<CS.*|RB.*><PP$><BEDZ><RP>?<VB.*><NN.*>+}
noun_chunker = nltk.RegexpParser('''
    NP:
        {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
        {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
        {<VB.*>+<RB><JJ.*>+}
    AJ:
        {<JJ.*>}
''')

# Key Phrases from Facebook
noun_phrases = []
adj_phrases = []
for i, comment in enumerate(picked_data):
    tree = noun_chunker.parse(comment)
    
    noun_phrase = [w for w in get_terms(tree, 'NP')]
    if len(noun_phrase) > 0:
        for i, phrase in enumerate(noun_phrase):
            noun_phrases.append(phrase)
    
    adj_phrase = [w for w in get_terms(tree, 'AJ')]
    if len(adj_phrase) > 0:
        for i, phrase in enumerate(adj_phrase):
            adj_phrases.append(phrase)

# %%
for noun_phrase in noun_phrases:
    if noun_phrase:
        print(noun_phrase)
        print()
# Out:
# ['informationbankb', 'customer', 'service', 'rep', 'mr']
#
# ['whats']
#
# ['name']
#
# ['creditor']
#
# ['youre']
#
# ['stop', 'payment']
#
# ['ron', 'don', 'don', 'child', 'supportshe', 'stops']
#
# ['strbankeht']
#
# ['eyes']
#
# ['eyesmr']
#
# ['cant']
#
# ['hold']
#
# ['child', 'support']
#
# ['don', 'i', 'didnt']
#
# ['sosmilingof', 'course', 'i']
#
# ['i']
#
# ['transaction', 'happy', 'hump', 'day']
#
# ['twithndl', 'provocateur']
#
# ['worlds']
#
# ['customer', 'service']
#
# ['bankd']
#
# ['exchange', 'theyd']
#
# ['return']
#
# ['replacement']
#
# ['day', 'courier']
#
# ['twithndlbankb']
#
# ['service', 'wasnt']
#
# ['robotic']
#
# ['purpose']
#
# ['humans']
#
# ['family']
#
# ['friends']
#
# ['account']
#
# ['experience']
#
# ['view']
#
# ['twithndlbankb']
#
# ['page']
#
# ['complaints']
#
# ['complaints']
#
# ['customer', 'service']
#
# ['i']
#
# ['i']
#
# ['st', 'hand', 'bankb']
#
# ['shits']
#
# ['customers']
#
# ['customers', 'theyve']
#
# ['yrs']
#
# ['twithndlbankb']
#
# ['i']
#
# ['fraudulent', 'card']
#
# ['paycheck']
#
# ['pay', 'card']
#
# ['fraud', 'i']
#
# ['account']
#
# ['bankb']
#
# ['customer', 'service', 'representatives']
#
# ['i']
#
# ['twithndl']
#
# ['i', 'm']
#
# ['customer', 'service', 'experience', 'i', 'd']
#
# ['additional', 'details']
#
# ['feedbankb']
#
# ['leadership', 'team']
#
# ['contact']
#
# ['twithndlbanka', 'bankabank']
#
# ['horrible', 'horrible', 'bank']
#
# ['bank']
#
# ['banka']
#
# ['reevaluate']
#
# ['life', 'service', 'products']
#
# ['customer', 'service']
#
# ['bank', 'times']
#
# ['i', 'call', 'customer', 'service']
#
# ['th']
#
# ['bankc', 'bank', 'sucks']
#
# ['direct', 'deposit']
#
# ['reactivate']
#
# ['account']
#
# ['i']
#
# ['weeks']
#
# ['paper', 'check']
#
# ['happy', 'camper', 'thaday', 'i']
#
# ['new', 'bank']
#
# ['suggestions']
#
# ['bankd']
#
# ['banka']
#
# ['bankb', 'customer', 'service', 'rebanke', 'sucks', 'time']
#
# ['swappbankes']
#
# ['bankb', 'ur', 'killing']
#
# ['switch']
#
# ['usaa']
#
# ['rawr']
#
# ['bad', 'customer', 'service', 'ur']
#
# ['bankb', 'aka', 'bankb']
#
# ['phone']
#
# ['minutes', 'minutes']
#
# ['lord']
#
# ['i']
#
# ['new', 'bank']
#
# ['suggestions']
#
# ['bankd', 'bank', 'customer', 'service']
#
# ['terrible', 'experience']
#
# ['bout']
#
# ['switch', 'banks']
#
# ['guys']
#
# ['years']
#
# ['guys']
#
# ['terrible', 'experience']
#
# ['hope']
#
# ['actual', 'teller']
#
# ['issue']
#
# ['i']
#
# ['guys']
#
# ['bankdbanksucks']
#
# ['money']
#
# ['bankd', 'bank']
#
# ['cash', 'deposit']
#
# ['bankdbank']
#
# ['rep']
#
# ['i']
#
# ['account']
#
# ['bankd']
#
# ['money', 'order']
#
# ['cash']
#
# ['bankdbank']
#
# ['inconsiderate', 'customer', 'service', 'service']
#
# ['bankc']
#
# ['customer', 'service', 'reps']
#
# ['jobs']
#
# ['banka']
#
# ['new', 'bank', 'realmoney']
#
# ['customer', 'service']
#
# ['waste']
#
# ['time', 'w']
#
# ['bank']
#
# ['month']
#
# ['issue']
#
# ['isnt']
#
# ['account']
#
# ['heading']
#
# ['bankb']
#
# ['ordeal', 'i']
#
# ['deposit']
#
# ['i']
#
# ['fee', 'couldnt']
#
# ['god']
#
# ['healthy', 'person']
#
# ['people']
#
# ['i']
#
# ['i']
#
# ['disconnect']
#
# ['i']
#
# ['make']
#
# ['deposit']
#
# ['city']
#
# ['bankd']
#
# ['banka']
#
# ['bank', 'atms']
#
# ['choice']
#
# ['isnt']
#
# ['case']
#
# ['atmmake']
#
# ['atm']
#
# ['person']
#
# ['i']
#
# ['miles']
#
# ['word']
#
# ['deposit']
#
# ['i']
#
# ['i']
#
# ['people']
#
# ['say']
#
# ['deposit']
#
# ['care']
#
# ['i']
#
# ['miles']
#
# ['decent', 'company']
#
# ['customer', 'service', 'director']
#
# ['class']
#
# ['people', 'i']
#
# ['minutes']
#
# ['people']
#
# ['lie']
#
# ['years']
#
# ['customer']
#
# ['bankb']
#
# ['dirt', 'horrible', 'customer', 'service', 'service']
#
# ['st', 'tip', 'dont', 'bank']
#
# ['bankb', 'horrible', 'customer', 'service', 'service', 'fees', 'i']
#
# ['tack', 'fees']
#
# ['years']
#
# ['i']
#
# ['bankb']
#
# ['convenience']
#
# ['multiple', 'locations']
#
# ['lobankc', 'anke']
#
# ['banke']
#
# ['addition']
#
# ['good', 'customer', 'service']
#
# ['way']
#
# ['company']
#
# ['dramatibankc', 'anke']
#
# ['years']
#
# ['person']
#
# ['way', 'i']
#
# ['past']
#
# ['companies']
#
# ['order']
#
# ['bankb']
#
# ['drive', 'throughs']
#
# ['arm']
#
# ['convenient', 'hours']
#
# ['drive']
#
# ['i']
#
# ['bankb', 'parking', 'lot']
#
# ['minutes']
#
# ['branch']
#
# ['people']
#
# ['company']
#
# ['decisions', 'bankb']
#
# ['way']
#
# ['years']
#
# ['title', 'company']
#
# ['file']
#
# ['satisfaction']
#
# ['lien']
#
# ['property']
#
# ['client']
#
# ['title', 'company']
#
# ['business']
#
# ['strbankehtened']
#
# ['bankc']
#
# ['mortgage']
#
# ['weeks']
#
# ['help', 'attorneys', 'owner', 'realtors']
#
# ['help', 'dont', 'count']
#
# ['bankc']
#
# ['customer', 'service']
#
# ['banka']
#
# ['hosting', 'tonights', 'pre', 'game', 'meal', 'pizzas']
#
# ['great', 'speaker']
#
# ['downside']
#
# ['new', 'bank', 'doesnt', 'smell', 'brand']
#
# ['thanks', 'banka']
#
# ['great', 'night']
#
# ['couple', 'weeks']
#
# ['i']
#
# ['new', 'bankb', 'account']
#
# ['days']
#
# ['account']
#
# ['notice', 'notification']
#
# ['i']
#
# ['direct', 'deposit']
#
# ['i']
#
# ['time', 'i']
#
# ['i']
#
# ['bank']
#
# ['customer', 'service']
#
# ['day']
#
# ['stupid', 'conversation']
#
# ['answer']
#
# ['ladies']
#
# ['phoneoh']
#
# ['letter']
#
# ['days', 'days']
#
# ['accountwhich', 'i', 'didnt']
#
# ['account']
#
# ['whole', 'week']
#
# ['i']
#
# ['week']
#
# ['return']
#
# ['payment']
#
# ['sender']
#
# ['bills']
#
# ['i', 'dont']
#
# ['money']
#
# ['gas']
#
# ['time']
#
# ['lawyer']
#
# ['front']
#
# ['mess', 'bankb']
#
# ['rare', 'complaint']
#
# ['banka']
#
# ['customer', 'service']
#
# ['phone']
#
# ['internet', 'i']
#
# ['i', 'haved', 'work']
#
# ['companies']
#
# ['i', 'rebanke']
#
# ['cake']
#
# ['applause']
#
# ['bankb']
#
# ['international', 'scammers', 'i']
#
# ['i']
#
# ['guys']
#
# ['top']
#
# ['foot', 'soldierscustomer', 'service']
#
# ['sponsors']
#
# ['friends']
#
# ['banka', 'bank']
#
# ['community']
#
# ['financial', 'education']
#
# ['customer', 'service']
#
# ['bad', 'customer', 'service']
#
# ['online']
#
# ['totbanke']
#
# ['bankb']
#
# ['banka', 'banker']
#
# ['local', 'branch']
#
# ['colleague']
#
# ['capital']
#
# ['bank', 'doesnt', 'charge', 'nonbank', 'atm', 'fees']
#
# ['way']
#
# ['twithndlbanka']
#
# ['whole', 'new', 'lobanka']
#
# ['abysmal', 'professionalism']
#
# ['customer', 'service']
#
# ['new', 'bank']
#
# ['bankb']
#
# ['bank']
#
# ['planet']
#
# ['customer', 'service', 'i']
#
# ['hoops']
#
# ['obstacles']
#
# ['i']
#
# ['bankb']
#
# ['care']
#
# ['mothers']
#
# ['kind']
#
# ['bank', 'doesnt']
#
# ['faxed', 'document']
#
# ['vp']
#
# ['own', 'branches']
#
# ['banka']
#
# ['customer', 'service']
#
# ['love']
#
# ['customer', 'service']
#
# ['i']
#
# ['small', 'town']
#
# ['large', 'metro', 'area', 'i']
#
# ['great', 'respect']
#
# ['i']
#
# ['excellent', 'service']
#
# ['j']
#
# ['banka', 'dealer', 'services']
#
# ['bankb']
#
# ['paperwork']
#
# ['cant']
#
# ['good', 'things']
#
# ['terrible', 'customer', 'service', 'i']
#
# ['fulltime', 'student']
#
# ['fees', 'i', 'couldnt']
#
# ['food']
#
# ['toilette', 'paper']
#
# ['thanks', 'banka']
#
# ['customers']
#
# ['whats']
#
# ['money']
#
# ['bank']
#
# ['accidentbanke', 'overdrew']
#
# ['bank', 'account']
#
# ['overdraft', 'fees']
#
# ['bankb']
#
# ['oversight']
#
# ['part']
#
# ['fee']
#
# ['lady']
#
# ['problem']
#
# ['money', 'i', 'didnt', 'catch']
#
# ['name']
#
# ['i']
#
# ['customer', 'service', 'people']
#
# ['years']
#
# ['bankd']
#
# ['bankd', 'i']
#
# ['new', 'bank']
#
# ['suggestions']
#
# ['rebanke']
#
# ['difference']
#
# ['bankes']
#
# ['institutions']
#
# ['years']
#
# ['banka']
#
# ['customer', 'service']
#
# ['dont', 'care']
#
# ['money']
#
# ['banks']
#
# ['years']
#
# ['bankb']
#
# ['time']
#
# ['switch', 'banks']
#
# ['horrible', 'customer', 'service']
#
# ['faulty', 'online', 'system', 'i']
#
# ['cant', 'use']
#
# ['good', 'suggestions']
#
# ['business']
#
# ['careful', 'consideration', 'banka']
#
# ['points']
#
# ['credit', 'report']
#
# ['basibankc', 'anke']
#
# ['problem']
#
# ['system']
#
# ['price']
#
# ['horrific', 'customer', 'service', 'exeperiance']
#
# ['life', 'i']
#
# ['lawyer']
#
# ['bank']
#
# ['interest']
#
# ['customers', 'employees']
#
# ['information']
#
# ['i']
#
# ['bankb']
#
# ['person', 'i']
#
# ['online', 'chat']
#
# ['security', 'questions']
#
# ['minutes']
#
# ['responses', 'i']
#
# ['dear', 'bankb', 'i', 'originbanke']
#
# ['service']
#
# ['transfer']
#
# ['actual', 'person', 'i']
#
# ['bankbs', 'customer', 'service']
#
# ['people']
#
# ['way']
#
# ['customers']
#
# ['idiots']
#
# ['computers']
#
# ['machines']
#
# ['day']
#
# ['online']
#
# ['problems']
#
# ['lot']
#
# ['money']
#
# ['cant']
#
# ['real', 'people']
#
# ['real', 'customers']
#
# ['machines']
#
# ['bankes']
#
# ['customers']
#
# ['real', 'person']
#
# ['dont', 'start']
#
# ['customers']
#
# ['real', 'people']
#
# ['dollar', 'signs']
#
# ['i']
#
# ['bankc', 'account']
#
# ['protection', 'plan']
#
# ['charges', 'i']
#
# ['call']
#
# ['bankc']
#
# ['i', 'havent']
#
# ['i']
#
# ['account', 'i']
#
# ['zero', 'balance']
#
# ['multiple', 'attempts']
#
# ['customer', 'service', 'i']
#
# ['bank', 'buster']
#
# ['means']
#
# ['bankb']
#
# ['pennies']
#
# ['idea']
#
# ['dealings']
#
# ['bankc']
#
# ['i']
#
# ['account']
#
# ['i']
#
# ['customer', 'service', 'representatives', 'i']
#
# ['bankes']
#
# ['business', 'bankc']
#
# ['ajisha', 'i']
#
# ['bankb']
#
# ['wife']
#
# ['account']
#
# ['bankb', 'i']
#
# ['bank', 'local']
#
# ['customer', 'service']
#
# ['ethical', 'business', 'practices', 'i']
#
# ['banke']
#
# ['banke']
#
# ['i']
#
# ['i']
#
# ['banka']
#
# ['thought', 'i']
#
# ['i']
#
# ['banka']
#
# ['recommendations']
#
# ['new', 'bank']
#
# ['hearts']
#
# ['red', 'cross', 'dont', 'change', 'bankbs', 'terrible', 'customer', 'service', 'years']
#
# ['customer']
#
# ['terminal', 'cancer']
#
# ['i']
#
# ['deposit', 'error']
#
# ['chemo', 'week']
#
# ['bank', 'oif', 'america']
#
# ['account']
#
# ['customer', 'service', 'people']
#
# ['i']
#
# ['indian', 'thats']
#
# ['bankc', 'india']
#
# ['outsource', 'jobs']
#
# ['money', 'bankc']
#
# ['people']
#
# ['break']
#
# ['i', 'havent']
#
# ['bankc', 'atm']
#
# ['long', 'time']
#
# ['pain']
#
# ['customers']
#
# ['small', 'businesses']
#
# ['bankd']
#
# ['paymentsfederation']
#
# ['small', 'businessesname', 'customer', 'service']
#
# ['credit', 'control']
#
# ['fraction']
#
# ['cost', 'call']
#
# ['information']
#
# ['amazing', 'i', 'didnt']
#
# ['credit', 'card']
#
# ['new', 'expiration', 'date']
#
# ['vendorcarbonitebecause', 'i']
#
# ['services', 'i', 'emailed', 'vendor']
#
# ['i']
#
# ['credit', 'card']
#
# ['i']
#
# ['use']
#
# ['services', 'carbonite']
#
# ['charge']
#
# ['credit', 'card']
#
# ['banka']
#
# ['chargepaid']
#
# ['i']
#
# ['carbonite']
#
# ['refund']
#
# ['i']
#
# ['banka']
#
# ['hour']
#
# ['different', 'people']
#
# ['case']
#
# ['reference', 'number']
#
# ['i']
#
# ['person']
#
# ['couldnt']
#
# ['days']
#
# ['dispute']
#
# ['charge', 'rebanke']
#
# ['banka']
#
# ['credit', 'card']
#
# ['fault']
#
# ['loss']
#
# ['loss']
#
# ['customer']
#
# ['customer', 'i']
#
# ['i']
#
# ['banka', 'fees']
#
# ['death']
#
# ['cant']
#
# ['assistance', 'i']
#
# ['time']
#
# ['new', 'bank']
#
# ['america']
#
# ['bankb', 'customer', 'service']
#
# ['bankrupt', 'i']
#
# ['years', 'years']
#
# ['months']
#
# ['i']
#
# ['lol']
#
# ['bankb', 'technical', 'support']
#
# ['couldnt', 'answer']
#
# ['question']
#
# ['customer', 'service']
#
# ['hour']
#
# ['customer', 'service', 'person']
#
# ['bankb']
#
# ['banka', 'branch']
#
# ['hours', 'hours']
#
# ['account']
#
# ['account']
#
# ['hoursand', 'yearstook']
#
# ['stand']
#
# ['customer', 'service']
#
# ['account']
#
# ['thanks']
#
# ['bank']
#
# ['arizona']
#
# ['people']
#
# ['advice']
#
# ['subject']
#
# ['classes']
#
# ['bankege']
#
# ['customers']
#
# ['customer', 'service', 'i']
#
# ['terrible', 'experince', 'bankb']
#
# ['anbanke']
#
# ['poor', 'customer', 'service']
#
# ['bankers']
#
# ['dont']
#
# ['rerouted']
#
# ['rerouted']
#
# ['banka']
#
# ['issaquah']
#
# ['reason', 'bankb']
#
# ['bank']
#
# ['america']
#
# ['convenience', 'fee']
#
# ['check']
#
# ['account']
#
# ['i', 'dont']
#
# ['account']
#
# ['manager']
#
# ['fee']
#
# ['i']
#
# ['account']
#
# ['horrible', 'customer', 'service']
#
# ['reason']
#
# ['bankb', 'i', 'dont']
#
# ['guys']
#
# ['customer', 'service']
#
# ['mins']
#
# ['cant']
#
# ['guys']
#
# ['bank', 'thats']
#
# ['bankaor', 'bankb', 'i']
#
# ['new', 'bank', 'account']
#
# ['bankb', 'users']
#
# ['trouble']
#
# ['online']
#
# ['new', 'bank', 'cant']
#
# ['register']
#
# ['suggestions']
#
# ['i']
#
# ['i']
#
# ['car', 'i']
#
# ['service', 'i']
#
# ['banka']
#
# ['customer', 'service', 'nightmare']
#
# ['months']
#
# ['sign']
#
# ['paperless', 'statements']
#
# ['bankd']
#
# ['monthly', 'paper', 'statements', 'i']
#
# ['minutes']
#
# ['phone']
#
# ['different', 'customer', 'service', 'people']
#
# ['problem', 'i']
#
# ['rep']
#
# ['loan', 'i']
#
# ['banka']
#
# ['i']
#
# ['customer', 'service']
#
# ['ur', 'phone']
#
# ['times']
#
# ['day', 'tulsa', 'teacher', 'banke']
#
# ['u']
#
# ['i']
#
# ['recommendations']
#
# ['bank']
#
# ['works']
#
# ['small', 'businesses', 'twithndlbanka', 'banka']
#
# ['officibanke']
#
# ['bank']
#
# ['small', 'business', 'owner']
#
# ['i']
#
# ['business']
#
# ['personal', 'account']
#
# ['banke']
#
# ['business']
#
# ['customer', 'service']
#
# ['good', 'bank']
#
# ['bankd', 'i']
#
# ['new', 'bank']
#
# ['recommendation']
#
# ['i']
#
# ['business']
#
# ['bankd']
#
# ['job']
#
# ['customer', 'service', 'representatives']
#
# ['bankb', 'i', 'work']
#
# ['online']
#
# ['bankb', 'website']
#
# ['tempe']
#
# ['hour']
#
# ['bank']
#
# ['service', 'fees']
#
# ['swipe', 'ur', 'card']
#
# ['bucks']
#
# ['ur', 'self']
#
# ['new', 'bank', 'i']
#
# ['i', 'biddeford']
#
# ['bankb']
#
# ['biddeford', 'i']
#
# ['banks']
#
# ['deal']
#
# ['i', 'dont']
#
# ['i']
#
# ['pocket']
#
# ['min', 'balance']
#
# ['monthly', 'charges']
#
# ['contract']
#
# ['u']
#
# ['theres']
#
# ['frosting']
#
# ['cake']
#
# ['matter']
#
# ['u', 'use', 'ur', 'card', 'u']
#
# ['t']
#
# ['fee']
#
# ['u']
#
# ['bankb']
#
# ['account']
#
# ['whats']
#
# ['dont']
#
# ['account']
#
# ['ur', 'account']
#
# ['ur']
#
# ['i']
#
# ['info']
#
# ['freaking']
#
# ['transfer', 'fee']
#
# ['account']
#
# ['banka', 'time']
#
# ['new', 'bank']
#
# ['argh', 'bankb']
#
# ['westland']
#
# ['wayne', 'road', 'road']
#
# ['branch']
#
# ['universe', 'customer', 'service']
#
# ['ass', 'bankb']
#
# ['valuable', 'time']
#
# ['tv']
#
# ['repair']
#
# ['manufacturers', 'fault']
#
# ['pay']
#
# ['itagainst']
#
# ['advice']
#
# ['standards']
#
# ['repair']
#
# ['cost']
#
# ['store']
#
# ['old', 'tv']
#
# ['meantimeat', 'store', 'managers', 'discretion']
#
# ['i']
#
# ['d', 'tv', 'pairs']
#
# ['extra', 'glasses', 'wall']
#
# ['brackets']
#
# ['tv']
#
# ['phonecalls']
#
# ['customer', 'services']
#
# ['bankd']
#
# ['loan']
#
# ['old', 'tv']
#
# ['age']
#
# ['size']
#
# ['condition', 'i', 'dont', 'carewhich', 'i', 'wouldnt']
#
# ['thousands']
#
# ['times']
#
# ['i']
#
# ['i']
#
# ['instore']
#
# ['scene']
#
# ['order']
#
# ['ithey']
#
# ['mins']
#
# ['store', 'manager', 'magibankc', 'anke']
#
# ['phone']
#
# ['nonecould', 'i']
#
# ['hurry']
#
# ['tv', 'i', 'purbankdd']
#
# ['good', 'faith']
#
# ['days']
#
# ['itim']
#
# ['time']
#
# ['im']
#
# ['time', 'period']
#
# ['i']
#
# ['blank', 'wall', 'i']
#
# ['soaps']
#
# ['guimond', 'omg']
#
# ['im']
#
# ['livid', 'i']
#
# ['idiot']
#
# ['works']
#
# ['bankd', 'bank']
#
# ['sierra', 'vista']
#
# ['i', 'cashes']
#
# ['check']
#
# ['shorted']
#
# ['u']
#
# ['numbers']
#
# ['course']
#
# ['o', 'call', 'customer', 'service']
#
# ['course']
#
# ['arent']
#
# ['call', 'center']
#
# ['bank', 'ive']
#
# ['repost']
#
# ['i']
#
# ['idiot']
#
# ['transaction']
#
# ['card']
#
# ['card']
#
# ['story']
#
# ['brand', 'new', 'account']
#
# ['customer', 'service']
#
# ['account']
#
# ['managers', 'manager']
#
# ['phone']
#
# ['course']
#
# ['horrible', 'service', 'i']
#
# ['bankc']
#
# ['let']
#
# ['credit', 'agencys']
#
# ['i']
#
# ['account']
#
# ['incompetent', 'company']
#
# ['bankb']
#
# ['th', 'dr']
#
# ['peoria']
#
# ['way']
#
# ['front', 'door', 'clerk']
#
# ['tellers']
#
# ['cuz', 'bankb']
#
# ['people']
#
# ['banks']
#
# ['ways']
#
# ['transactions']
#
# ['customer', 'service', 'service']
#
# ['attention']
#
# ['fam', 'banka']
#
# ['customer', 'service']
#
# ['u']
#
# ['holla']
#
# ['attention']
#
# ['banka', 'i']
#
# ['treatment']
#
# ['customer', 'service']
#
# ['claims', 'representative', 'i']
#
# ['online', 'purbankd']
#
# ['th']
#
# ['july']
#
# ['purbankd']
#
# ['i']
#
# ['turn']
#
# ['money']
#
# ['business', 'days']
#
# ['i']
#
# ['multiple', 'times']
#
# ['issue']
#
# ['customer', 'service', 'representative']
#
# ['purbankd']
#
# ['amount']
#
# ['website', 'i']
#
# ['purbankd']
#
# ['claims', 'department']
#
# ['charge']
#
# ['days']
#
# ['claims', 'department', 'representative', 'tory']
#
# ['disrespectful']
#
# ['call']
#
# ['i', 'wouldnt']
#
# ['bank']
#
# ['banka']
#
# ['crooked', 'organization']
#
# ['awe']
#
# ['i']
#
# ['i', 'work']
#
# ['banka']
#
# ['issues']
#
# ['contact', 'customer', 'service']
#
# ['local', 'branch']
#
# ['banka']
#
# ['i']
#
# ['good', 'customer', 'service']
#
# ['i']
#
# ['ayyy']
#
# ['hr', 'yup', 'i']
#
# ['ima']
#
# ['ima']
#
# ['good', 'teller']
#
# ['ba']
#
# ['horrible', 'customer', 'service', 'service']
#
# ['online']
#
# ['bankd']
#
# ['bad', 'start']
#
# ['day', 'bankb', 'atm']
#
# ['cash', 'deposit']
#
# ['customer', 'service']
#
# ['min']
#
# ['transfers']
#
# ['department']
#
# ['bank']
#
# ['til']
#
# ['finbanke', 'i']
#
# ['bailed']
#
# ['bankb']
#
# ['point', 'interest']
#
# ['months']
#
# ['customer', 'service', 'awesome', 'bank']
#
# ['funds']
#
# ['good', 'decent', 'rate']
#
# ['concern']
#
# ['family']
#
# ['brick']
#
# ['mortar']
#
# ['number']
#
# ['times']
#
# ['row']
#
# ['magazine']
#
# ['bankb', 'bitch', 'azz', 'customer', 'service']
#
# ['pissing']
#
# ['bankb']
#
# ['irish', 'ass', 'love']
#
# ['tv', 'commercials']
#
# ['customer', 'service', 'bunch']
#
# ['bullshite']
#
# ['bankb', 'college', 'branch']
#
# ['california']
#
# ['customer', 'service']
#
# ['tellers', 'fault']
#
# ['i']
#
# ['teller']
#
# ['window']
#
# ['people']
#
# ['office', 'i']
#
# ['branch']
#
# ['i', 'work']
#
# ['busy', 'area']
#
# ['tellers', 'available', 'try']
#
# ['force']
#
# ['atm', 'machine']
#
# ['bank', 'online']
#
# ['bankb']
#
# ['merchant', 'i']
#
# ['shoppers', 'info']
#
# ['i']
#
# ['customer', 'service']
#
# ['details']
#
# ['center', 'rep']
#
# ['i']
#
# ['reply']
#
# ['philippines', 'i', 'bank']
#
# ['place']
#
# ['bankb', 'i']
#
# ['american', 'rep']
#
# ['arizona']
#
# ['american', 'jobs']
#
# ['outsourcing']
#
# ['i', 'cant']
#
# ['english']
#
# ['dont', 'handle']
#
# ['money']
#
# ['healthcare']
#
# ['bankb']
#
# ['poor', 'customer', 'service']
#
# ['bankege']
#
# ['exploits']
#
# ['americans']
#
# ['practices']
#
# ['bankb', 'customer', 'service']
#
# ['customers']
#
# ['access']
#
# ['online', 'account']
#
# ['bankb', 'customer', 'service', 'department']
#
# ['family']
#
# ['merry', 'christmas', 'i']
#
# ['world']
#
# ['companies']
#
# ['affending']
#
# ['i']
#
# ['america']
#
# ['nation']
#
# ['bankb', 'i']
#
# ['bankb', 'customer', 'service']
#
# ['abankaul']
#
# ['charge']
#
# ['items']
#
# ['shouldnt']
#
# ['hours', 'rectifying']
#
# ['i']
#
# ['executive', 'relations']
#
# ['numbers']
#
# ['lack']
#
# ['ethics']
#
# ['business', 'etiquette']
#
# ['bank']
#
# ['compromise']
#
# ['debit', 'card', 'numerous', 'times']
#
# ['company']
#
# ['bankb', 'customer', 'service', 'sucks']
#
# ['bankb', 'customer', 'service', 'sucks', 'week']
#
# ['thanksgiving']
#
# ['bank']
#
# ['funds', 'availability']
#
# ['bankb']
#
# ['bank']
#
# ['thanks']
#
# ['lot']
#
# ['glad', 'i']
#
# ['customer']
#
# ['bank']
#
# ['bankb', 'customer', 'service', 'couldnt']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['bankb', 'doesnt']
#
# ['customers']
#
# ['switchbankes']
#
# ['afternoon', 'i']
#
# ['actual', 'customer', 'service']
#
# ['money']
#
# ['different', 'bank']
#
# ['i']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['dont', 'mind']
#
# ['money']
#
# ['account']
#
# ['authorization']
#
# ['bank']
#
# ['changbankes']
#
# ['recommendations']
#
# ['bankb']
#
# ['account', 'times']
#
# ['regional', 'manager']
#
# ['customer', 'service']
#
# ['phone']
#
# ['hours']
#
# ['bankb']
#
# ['bank']
#
# ['world']
#
# ['theyre']
#
# ['ways']
#
# ['hundreds']
#
# ['savings']
#
# ['account']
#
# ['fees']
#
# ['i']
#
# ['time']
#
# ['new', 'bank']
#
# ['good', 'opinions']
#
# ['banks']
#
# ['savings', 'student']
#
# ['account']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['walmart']
#
# ['t']
#
# ['way']
#
# ['businesses']
#
# ['bout']
#
# ['bankb']
#
# ['real', 'bad', 'customer', 'service', 'representative']
#
# ['middle']
#
# ['sentence']
#
# ['bankb']
#
# ['poor', 'customer', 'service']
#
# ['incompetent', 'tellers']
#
# ['customer']
#
# ['hour']
#
# ['bankb']
#
# ['incompetent', 'customer', 'service', 'i']
#
# ['i']
#
# ['number', 'i']
#
# ['message']
#
# ['times']
#
# ['number']
#
# ['times']
#
# ['call']
#
# ['weeks']
#
# ['issue']
#
# ['bankb']
#
# ['customer', 'service', 'service', 'i']
#
# ['bankb']
#
# ['banks']
#
# ['customers']
#
# ['bank', 'branch']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['i']
#
# ['comcast']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['idiots']
#
# ['phone']
#
# ['times']
#
# ['i']
#
# ['funds']
#
# ['moment', 'thanks']
#
# ['lot']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['money']
#
# ['post']
#
# ['account']
#
# ['problem']
#
# ['account']
#
# ['security', 'breach']
#
# ['regular', 'postings']
#
# ['i']
#
# ['hours']
#
# ['problem']
#
# ['i']
#
# ['satisfaction']
#
# ['i']
#
# ['gift', 'card', 'compensation']
#
# ['time']
#
# ['cant']
#
# ['i', 'm']
#
# ['bankbn', 'years']
#
# ['customer', 'i']
#
# ['bankb', 'horrible', 'customer', 'service']
#
# ['debit', 'card', 'activation', 'callin', 'information', 'doesnt', 'work']
#
# ['bankb', 'atm']
#
# ['bankb']
#
# ['i']
#
# ['japan', 'i']
#
# ['terrible', 'customer', 'service', 'service']
#
# ['students']
#
# ['i', 'dont']
#
# ['america']
#
# ['account']
#
# ['i']
#
# ['bankb']
#
# ['america']
#
# ['i']
#
# ['bankb']
#
# ['bankb']
#
# ['customer', 'service', 'i']
#
# ['i', 'cant']
#
# ['bank']
#
# ['bankb']
#
# ['fucking', 'joke']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['joke']
#
# ['financial', 'institution']
#
# ['carriage']
#
# ['customers']
#
# ['bit']
#
# ['fees', 'i']
#
# ['terrible', 'customer', 'service', 'experience']
#
# ['bank']
#
# ['social', 'media']
#
# ['front']
#
# ['branches']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['joke']
#
# ['account', 'asap', 'i', 'cant']
#
# ['cost']
#
# ['bankb']
#
# ['abankaul']
#
# ['bank']
#
# ['help']
#
# ['especibanke']
#
# ['customer', 'service', 'representative']
#
# ['bank']
#
# ['morning']
#
# ['service', 'desk']
#
# ['tellers']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['stuff']
#
# ['blame']
#
# ['customer', 'service']
#
# ['times']
#
# ['issue']
#
# ['loan', 'origination', 'manager', 'i']
#
# ['question', 'ummm']
#
# ['minority', 'bankb', 'mortgage', 'loans']
#
# ['woman', 'i']
#
# ['bankb']
#
# ['horrible', 'terrible', 'customer', 'service', 'service']
#
# ['fraudulent']
#
# ['practices']
#
# ['corrupt', 'organization']
#
# ['industry']
#
# ['bankb']
#
# ['new', 'bank']
#
# ['florida']
#
# ['bankb']
#
# ['old', 'bank']
#
# ['number']
#
# ['system']
#
# ['number']
#
# ['new', 'bank']
#
# ['relationships', 'bankb', 'badbusiness']
#
# ['bankb']
#
# ['banks']
#
# ['customer', 'service', 'change', 'banks']
#
# ['bankb']
#
# ['horrible', 'bank']
#
# ['need']
#
# ['new', 'bank']
#
# ['bankb']
#
# ['devil', 'i']
#
# ['account']
#
# ['i']
#
# ['years']
#
# ['dozens']
#
# ['stories']
#
# ['abankaul', 'customer', 'service', 'service', 'i', 'cant']
#
# ['long', 'bankb']
#
# ['bankb']
#
# ['bank', 'i']
#
# ['i']
#
# ['phone', 'call']
#
# ['debit', 'card']
#
# ['problem']
#
# ['fact']
#
# ['september', 'i']
#
# ['branches']
#
# ['account']
#
# ['consultant']
#
# ['debit', 'card']
#
# ['month']
#
# ['i']
#
# ['statement']
#
# ['account']
#
# ['overdrawn', 'i']
#
# ['customer', 'service']
#
# ['account']
#
# ['cashiers', 'check']
#
# ['balance']
#
# ['i']
#
# ['phone', 'calls']
#
# ['bank', 'account', 'i']
#
# ['months']
#
# ['credit']
#
# ['bankb']
#
# ['law', 'suit']
#
# ['hands']
#
# ['rebanke']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['bakersfield', 'california', 'massive', 'line']
#
# ['door']
#
# ['st']
#
# ['month']
#
# ['tellers']
#
# ['bank']
#
# ['i', 'dont']
#
# ['account']
#
# ['u']
#
# ['bankb']
#
# ['i']
#
# ['account']
#
# ['charge']
#
# ['fortune']
#
# ['little', 'thing']
#
# ['customer', 'service', 'reps', 'i']
#
# ['i']
#
# ['bank']
#
# ['use']
#
# ['services', 'i']
#
# ['posting']
#
# ['twitter']
#
# ['social', 'media', 'sites']
#
# ['bankb']
#
# ['cool', 'doe']
#
# ['finna']
#
# ['account']
#
# ['new', 'bank']
#
# ['irriated']
#
# ['bankb']
#
# ['bank']
#
# ['horrible', 'customer', 'service']
#
# ['high', 'fees']
#
# ['bankb', 'mortgage']
#
# ['i', 'specibanke']
#
# ['banka', 'bank']
#
# ['online', 'payment']
#
# ['funds']
#
# ['account']
#
# ['error']
#
# ['part']
#
# ['time']
#
# ['computer', 'glitches']
#
# ['cant', 'wait']
#
# ['customer', 'service', 'dept']
#
# ['suchcrooks']
#
# ['bankb']
#
# ['terrible', 'customer', 'service']
#
# ['bankb', 'representative']
#
# ['foreign', 'transaction', 'fees']
#
# ['i']
#
# ['work']
#
# ['churches']
#
# ['france']
#
# ['safety']
#
# ['recent', 'shootings']
#
# ['i']
#
# ['kind']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['account', 'customer', 'service']
#
# ['bankb']
#
# ['customers', 'whove']
#
# ['years']
#
# ['new', 'bank', 'monday']
#
# ['bankb']
#
# ['money']
#
# ['real', 'customer', 'service']
#
# ['fluffy', 'advertisement']
#
# ['net']
#
# ['customer', 'i']
#
# ['line']
#
# ['phone']
#
# ['reps']
#
# ['hour']
#
# ['results']
#
# ['simple', 'request', 'i']
#
# ['time']
#
# ['money']
#
# ['bank']
#
# ['little', 'customer', 'service', 'bank']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['wth']
#
# ['bankb']
#
# ['new', 'bank']
#
# ['bank', 'trust']
#
# ['rebanke', 'sux', 'bc']
#
# ['i', 'travel']
#
# ['isnt']
#
# ['bank', 'trust']
#
# ['new', 'account']
#
# ['mydirectdeposit']
#
# ['screw']
#
# ['i']
#
# ['switch']
#
# ['banka', 'lol']
#
# ['bankb', 'sucks']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['indudtry']
#
# ['bankb', 'sucks']
#
# ['week']
#
# ['person']
#
# ['year', 'i', 'call']
#
# ['customer', 'services']
#
# ['dont']
#
# ['account']
#
# ['bankb', 'u']
#
# ['card']
#
# ['cutoff']
#
# ['fraud']
#
# ['branch']
#
# ['temp', 'card']
#
# ['appointment', 'branches']
#
# ['branch', 'actubanke']
#
# ['new', 'bank']
#
# ['responses']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['hour']
#
# ['representative']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['i', 'start']
#
# ['customer', 'service', 'reps', 'cant', 'answer']
#
# ['questions']
#
# ['lock']
#
# ['account']
#
# ['time']
#
# ['i']
#
# ['pack']
#
# ['cigarettes']
#
# ['gas', 'station']
#
# ['account']
#
# ['cant', 'access']
#
# ['i']
#
# ['bills']
#
# ['i']
#
# ['paychecks']
#
# ['plural', 'thats']
#
# ['im']
#
# ['payment']
#
# ['tools', 'loan']
#
# ['credit']
#
# ['unfair', 'i']
#
# ['answers']
#
# ['bankb']
#
# ['i']
#
# ['office']
#
# ['new', 'pin', 'number']
#
# ['time', 'i']
#
# ['banker']
#
# ['families']
#
# ['big', 'hug']
#
# ['way']
#
# ['haha']
#
# ['usual', 'thats']
#
# ['customer', 'service']
#
# ['ive']
#
# ['bankb']
#
# ['week']
#
# ['finbanke']
#
# ['customer']
#
# ['company']
#
# ['bankb']
#
# ['experience']
#
# ['customer', 'service']
#
# ['time']
#
# ['bankb']
#
# ['customer']
#
# ['card']
#
# ['fraud']
#
# ['end']
#
# ['new', 'card']
#
# ['days']
#
# ['bankb']
#
# ['july']
#
# ['card']
#
# ['i']
#
# ['means']
#
# ['customer', 'service']
#
# ['sorry', 'theres']
#
# ['i', 'cant']
#
# ['corporation']
#
# ['i', 'trust']
#
# ['money']
#
# ['disrespectful']
#
# ['customers']
#
# ['leave']
#
# ['money']
#
# ['means']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['mall', 'branch']
#
# ['florida']
#
# ['i']
#
# ['teller', 'i']
#
# ['different', 'day']
#
# ['line']
#
# ['hour', 'i']
#
# ['complaint']
#
# ['understaffed']
#
# ['fact']
#
# ['i']
#
# ['i']
#
# ['manager']
#
# ['basibankc', 'anke']
#
# ['fault']
#
# ['teller']
#
# ['rude', 'i']
#
# ['bank']
#
# ['personbanke']
#
# ['reason', 'i']
#
# ['i']
#
# ['money']
#
# ['mattress']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['horrible', 'i']
#
# ['run']
#
# ['issue', 'i']
#
# ['weeks']
#
# ['i']
#
# ['reps']
#
# ['phone']
#
# ['exactand']
#
# ['branch']
#
# ['able', 'resolve']
#
# ['issue']
#
# ['request', 'i']
#
# ['documents', 'i']
#
# ['emailed']
#
# ['reps']
#
# ['reps']
#
# ['mail']
#
# ['i']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['i']
#
# ['food']
#
# ['table']
#
# ['gas']
#
# ['i']
#
# ['new', 'bank']
#
# ['bankb']
#
# ['bank']
#
# ['customer', 'service']
#
# ['years', 'i']
#
# ['time']
#
# ['change']
#
# ['bankb']
#
# ['customer', 'service', 'skills']
#
# ['grip']
#
# ['day']
#
# ['appointment']
#
# ['medallion', 'signature', 'rebanke']
#
# ['branch', 'banka', 'bank']
#
# ['u']
#
# ['business']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['joke']
#
# ['credit', 'card', 'online']
#
# ['doesnt']
#
# ['times']
#
# ['i']
#
# ['negative', 'balance', 'i']
#
# ['weekend']
#
# ['work']
#
# ['finbanke']
#
# ['count', 'routing', 'number']
#
# ['credit']
#
# ['bankb']
#
# ['phone']
#
# ['i']
#
# ['i']
#
# ['info']
#
# ['overpayment']
#
# ['card']
#
# ['customers']
#
# ['routing', 'info']
#
# ['checks']
#
# ['work']
#
# ['cheep']
#
# ['customer', 'service', 'reps']
#
# ['people']
#
# ['billions']
#
# ['crooks']
#
# ['bankb']
#
# ['mobile', 'app']
#
# ['joke']
#
# ['bankb', 'manager', 'isnt']
#
# ['accurate', 'account', 'info']
#
# ['couldnt']
#
# ['nonchalant', 'attitude']
#
# ['app', 'isnt']
#
# ['accurate', 'account', 'balances']
#
# ['i']
#
# ['account']
#
# ['customer', 'service']
#
# ['help']
#
# ['headache']
#
# ['banks', 'dont', 'pay']
#
# ['i', 'doubt']
#
# ['bank']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['basibankc', 'anke']
#
# ['cant']
#
# ['banka', 'customer', 'service']
#
# ['misinformed', 'im']
#
# ['issues']
#
# ['phishing', 'call']
#
# ['system']
#
# ['banka']
#
# ['account']
#
# ['i']
#
# ['fraud', 'i', 'dont']
#
# ['banka', 'account']
#
# ['u']
#
# ['press']
#
# ['customer', 'service', 'number']
#
# ['bankb']
#
# ['card']
#
# ['safe', 'happywednesday']
#
# ['literbanke']
#
# ['bankive']
#
# ['life']
#
# ['i', 'call', 'customer', 'service']
#
# ['bankb']
#
# ['i', 'dont', 'rebanke']
#
# ['money']
#
# ['hours']
#
# ['bank']
#
# ['people']
#
# ['money']
#
# ['banks', 'money', 'i']
#
# ['bankc']
#
# ['i']
#
# ['bank']
#
# ['bankd', 'bank']
#
# ['havent']
#
# ['issues']
#
# ['money']
#
# ['thanks', 'bankc']
#
# ['customer', 'care', 'center']
#
# ['bank']
#
# ['minutes']
#
# ['simple', 'print']
#
# ['new', 'year']
#
# ['bankb']
#
# ['staff']
#
# ['people']
#
# ['atm']
#
# ['f']
#
# ['atm']
#
# ['teller']
#
# ['branch']
#
# ['person']
#
# ['desk', 'i', 'call']
#
# ['customer', 'service']
#
# ['s', 't']
#
# ['banka']
#
# ['years']
#
# ['bank']
#
# ['possible', 'customer', 'service', 'possible', 'customer', 'service']
#
# ['phone']
#
# ['possible', 'i', 'couldnt']
#
# ['branch']
#
# ['bed']
#
# ['days']
#
# ['i', 'praise']
#
# ['crappy', 'i']
#
# ['crap']
#
# ['call', 'center']
#
# ['customes', 'dont']
#
# ['minutes']
#
# ['good', 'help']
#
# ['work']
#
# ['idiot']
#
# ['experience']
#
# ['banka']
#
# ['good', 'grief']
#
# ['banka']
#
# ['rule', 'poor', 'customer', 'service', 'service']
#
# ['dont']
#
# ['box']
#
# ['realtor']
#
# ['i']
#
# ['loan', 'officer']
#
# ['banka', 'mortgage']
#
# ['client']
#
# ['finance', 'portion']
#
# ['todays']
#
# ['customer', 'services']
#
# ['i']
#
# ['hard', 'work']
#
# ['mom', 'bankb', 'mortgage', 'servicing', 'supervisor']
#
# ['ppl', 'work']
#
# ['problems']
#
# ['employees']
#
# ['rebanke']
#
# ['quality', 'customer', 'service']
#
# ['i']
#
# ['own', 'business', 'entrepreneur']
#
# ['customer', 'service']
#
# ['banka']
#
# ['ladies']
#
# ['ralphs', 'branch', 'rock', 'rock']
#
# ['business', 'account']
#
# ['bank']
#
# ['amazing', 'customer', 'service', 'screw', 'bankb']
#
# ['bankbs', 'fees']
#
# ['money']
#
# ['account']
#
# ['teller']
#
# ['i']
#
# ['i']
#
# ['transfer']
#
# ['money']
#
# ['bankb', 'account']
#
# ['i']
#
# ['complaint']
#
# ['poor', 'customer', 'service', 'service']
#
# ['i']
#
# ['loyal', 'customer', 'bankb', 'sucks']
#
# ['hackers']
#
# ['wawa', 'gas', 'stations', 'atms']
#
# ['atms']
#
# ['streets', 'scumbags']
#
# ['day', 'i']
#
# ['new', 'bank', 'account']
#
# ['banka', 'bank', 'bank']
#
# ['bank']
#
# ['full', 'amount']
#
# ['scumbagscharger']
#
# ['account']
#
# ['im']
#
# ['way', 'bankb']
#
# ['philly']
#
# ['file']
#
# ['complaint']
#
# ['police', 'department', 'thanks', 'scumbag']
#
# ['weekend']
#
# ['banka', 'customers', 'i']
#
# ['call']
#
# ['debit', 'card']
#
# ['lockedto']
#
# ['number']
#
# ['i']
#
# ['digit', 'number']
#
# ['pin', 'number', 'i']
#
# ['scam', 'i']
#
# ['banka', 'customer', 'service']
#
# ['theyve']
#
# ['complaints']
#
# ['numbers']
#
# ['pin', 'numbersif']
#
# ['elderly', 'people']
#
# ['family']
#
# ['friends']
#
# ['numbers']
#
# ['bankb']
#
# ['dunlin', 'ga']
#
# ['bank']
#
# ['friday']
#
# ['multiple', 'mailings']
#
# ['instructions']
#
# ['change']
#
# ['i']
#
# ['debit', 'card']
#
# ['issue']
#
# ['weeks']
#
# ['week', 'great', 'customer', 'service', 'thanks', 'bankb']
#
# ['photo']
#
# ['text', 'message']
#
# ['banka', 'dont', 'call']
#
# ['scam']
#
# ['social', 'security', 'number']
#
# ['money']
#
# ['share']
#
# ['fall']
#
# ['i']
#
# ['bankb']
#
# ['card']
#
# ['customer', 'service']
#
# ['scam']
#
# ['share']
#
# ['friends']
#
# ['groups']
#
# ['billings', 'customer', 'service', 'group']
#
# ['m']
#
# ['ladies']
#
# ['brew', 'kiosk']
#
# ['heightsnear', 'wendys']
#
# ['bankajust']
#
# ['morning']
#
# ['bearable']
#
# ['ladies']
#
# ['morning', 'love']
#
# ['people']
#
# ['day']
#
# ['actubanke']
#
# ['bankb']
#
# ['bank']
#
# ['abankaul']
#
# ['money']
#
# ['butt']
#
# ['gf']
#
# ['i']
#
# ['abankaul']
#
# ['didnt']
#
# ['i']
#
# ['logo']
#
# ['french', 'poodle']
#
# ['fee', 'fee', 'fee', 'fee', 'fee']
#
# ['i']
#
# ['different', 'big', 'bank']
#
# ['i', 'matter']
#
# ['i', 'didnt']
#
# ['right', 'kind']
#
# ['account']
#
# ['bankb']
#
# ['time', 'i']
#
# ['teller']
#
# ['i']
#
# ['memo', 'line']
#
# ['money']
#
# ['banke']
#
# ['fee']
#
# ['i', 'couldnt']
#
# ['way']
#
# ['clear', 'i']
#
# ['bankb']
#
# ['fee']
#
# ['bankb']
#
# ['person']
#
# ['industry', 'i']
#
# ['i']
#
# ['people']
#
# ['bank']
#
# ['customer', 'service']
#
# ['big', 'bank']
#
# ['doesnt', 'care']
#
# ['customers', 'good', 'riddens']
#
# ['bankb']
#
# ['sucks', 'horrible', 'customer', 'service', 'service', 'rude', 'attendance']
#
# ['bankb', 'customers']
#
# ['bankb', 'customer']
#
# ['minutes']
#
# ['line']
#
# ['bankb']
#
# ['bank']
#
# ['deposit']
#
# ['bankb']
#
# ['fees']
#
# ['dont']
#
# ['horrible', 'customer', 'service', 'i']
#
# ['times']
#
# ['money']
#
# ['boii']
#
# ['i', 'cant']
#
# ['banka', 'mfer', 'aint']
#
# ['new', 'bank']
#
# ['bout']
#
# ['new', 'bank', 'account']
#
# ['banka']
#
# ['bowie']
#
# ['banka', 'envelope']
#
# ['tons']
#
# ['receipts']
#
# ['albertsons']
#
# ['i']
#
# ['customer', 'service']
#
# ['business', 'owner', 'friends']
#
# ['bank']
#
# ['credit', 'card', 'machine', 'pros', 'cons', 'i']
#
# ['terrible', 'time']
#
# ['banks']
#
# ['banka']
#
# ['credit', 'card', 'processing', 'fees']
#
# ['i']
#
# ['bankd']
#
# ['wont', 'deposit']
#
# ['money']
#
# ['tomorrobanka', 'rom']
#
# ['thursday', 'i']
#
# ['customer', 'service', 'specialist']
#
# ['options', 'i']
#
# ['real', 'bank']
#
# ['customers']
#
# ['customer', 'service']
#
# ['time']
#
# ['week']
#
# ['cant']
#
# ['issue', 'i']
#
# ['business']
#
# ['bankb']
#
# ['future']
#
# ['banka']
#
# ['ive']
#
# ['phone']
#
# ['man']
#
# ['tony']
#
# ['minutes']
#
# ['gon', 'na']
#
# ['island']
#
# ['own', 'labanka', 'irm']
#
# ['hell']
#
# ['customer', 'service']
#
# ['i']
#
# ['love']
#
# ['banka']
#
# ['new', 'debit', 'card']
#
# ['american', 'voice', 'i']
#
# ['extra', 'crap']
#
# ['international', 'toll', 'free', 'numbers']
#
# ['strbankeht']
#
# ['normal', 'customer', 'service']
#
# ['bankc', 'customer', 'service']
#
# ['hell']
#
# ['good', 'bank']
#
# ['business']
#
# ['services']
#
# ['towel']
#
# ['bankb']
#
# ['account']
#
# ['new', 'bank']
#
# ['i']
#
# ['hobanka', 'rustrated', 'i']
#
# ['bank', 'banka', 'i']
#
# ['staff']
#
# ['customer', 'service', 'reps']
#
# ['policies']
#
# ['i', 'vent']
#
# ['i']
#
# ['i', 'freaking']
#
# ['bankd', 'bank', 'yup']
#
# ['money']
#
# ['i']
#
# ['new', 'bank']
#
# ['logic']
#
# ['bankd']
#
# ['upgrades']
#
# ['line']
#
# ['system']
#
# ['friday', 'business', 'day']
#
# ['business']
#
# ['personal', 'customers']
#
# ['account']
#
# ['line']
#
# ['own', 'customer', 'service', 'representatives', 'cant']
#
# ['account', 'information']
#
# ['cant']
#
# ['bankc']
#
# ['merchant']
#
# ['customer', 'service', 'reps']
#
# ['i']
#
# ['additional', 'business']
#
# ['text', 'message', 'notifications']
#
# ['rep']
#
# ['i']
#
# ['legal', 'claim']
#
# ['merchant']
#
# ['idea']
#
# ['i']
#
# ['horrifying', 'i']
#
# ['halloween', 'vein']
#
# ['way']
#
# ['bankc']
#
# ['cant', 'wait']
#
# ['new', 'bank']
#
# ['bankb']
#
# ['banka']
#
# ['deal']
#
# ['sorry', 'theivbanke']
#
# ['capital']
#
# ['capital']
#
# ['business']
#
# ['bank']
#
# ['furthest', 'thing']
#
# ['small', 'business']
#
# ['presidents', 'office']
#
# ['joke']
#
# ['customer', 'service']
#
# ['joke']
#
# ['mobile', 'deposit']
#
# ['small', 'business']
#
# ['excuse']
#
# ['book', 'bankd']
#
# ['bank']
#
# ['weve']
#
# ['chances']
#
# ['banka']
#
# ['way']
#
# ['claim']
#
# ['new', 'bank']
#
# ['faith']
#
# ['abilities']
#
# ['transactions']
#
# ['bankd']
#
# ['weeks', 'i']
#
# ['multiple', 'customer', 'service', 'representatives', 'i']
#
# ['online', 'payment']
#
# ['old', 'mortgage', 'company']
#
# ['mortgage']
#
# ['old', 'mortgage', 'company']
#
# ['check', 'bankd']
#
# ['account', 'i']
#
# ['stop', 'payment']
#
# ['refund']
#
# ['money', 'i']
#
# ['run']
#
# ['bankd']
#
# ['refund']
#
# ['money', 'i']
#
# ['stop', 'payment']
#
# ['august', 'th']
#
# ['i']
#
# ['havent']
#
# ['refund']
#
# ['cash']
#
# ['bankd', 'bankd', 'i']
#
# ['refund']
#
# ['money']
#
# ['day', 'i', 'call', 'i']
#
# ['stop', 'payment']
#
# ['day']
#
# ['bankd', 'i']
#
# ['money']
#
# ['bankd', 'bank', 'bank']
#
# ['experience']
#
# ['month', 'amatuer', 'customer', 'service', 'service']
#
# ['guys']
#
# ['i']
#
# ['bankd', 'bankd', 'dissatisfaction']
#
# ['bankd', 'bank']
#
# ['account']
#
# ['legal', 'gun', 'shop']
#
# ['owner']
#
# ['bankd', 'bank', 'customer', 'service']
#
# ['house']
#
# ['years']
#
# ['i']
#
# ['wrong', 'number']
#
# ['gon', 'na', 'start', 'recording']
#
# ['bankd', 'bank', 'customer', 'service']
#
# ['rebanke']
#
# ['bankd', 'bank', 'customer', 'service', 'sucks']
#
# ['bankd', 'bank']
#
# ['account']
#
# ['notice']
#
# ['i']
#
# ['time']
#
# ['new', 'bank']
#
# ['bankd', 'bank']
#
# ['branch']
#
# ['ridgecrest']
#
# ['bankb']
#
# ['i']
#
# ['occasional', 'hour', 'drive']
#
# ['i']
#
# ['face']
#
# ['experience']
#
# ['bankds', 'customer', 'service', 'advice']
#
# ['bankd', 'bank']
#
# ['jobs', 'u']
#
# ['hoe']
#
# ['tellees']
#
# ['customer', 'service']
#
# ['real', 'person']
#
# ['machines']
#
# ['cant', 'answere']
#
# ['questions']
#
# ['example']
#
# ['society']
#
# ['society']
#
# ['loosing']
#
# ['basis']
#
# ['human', 'connection']
#
# ['bankd', 'bank']
#
# ['fu', 'ed']
#
# ['i']
#
# ['place']
#
# ['new', 'bank']
#
# ['link', 'wit']
#
# ['bankb', 'rite']
#
# ['bankd', 'bank']
#
# ['garbage', 'i', 'pay']
#
# ['i']
#
# ['new', 'account']
#
# ['account']
#
# ['i']
#
# ['debt', 'selfish', 'people']
#
# ['account']
#
# ['stupid', 'reasons']
#
# ['i']
#
# ['time']
#
# ['new', 'bank', 'i']
#
# ['maps']
#
# ['bank', 'account']
#
# ['money']
#
# ['real', 'information', 'people']
#
# ['bad', 'days']
#
# ['day']
#
# ['sunshine']
#
# ['happiness']
#
# ['people']
#
# ['head']
#
# ['ass']
#
# ['negative', 'posts']
#
# ['timeline']
#
# ['robots']
#
# ['bankd', 'bank']
#
# ['customer', 'dew']
#
# ['poor', 'customer', 'service', 'service']
#
# ['bankd']
#
# ['i']
#
# ['buisness']
#
# ['poor', 'customer', 'service', 'lack']
#
# ['i']
#
# ['bankd', 'banks']
#
# ['india']
#
# ['customer', 'service', 'years']
#
# ['banke']
#
# ['i']
#
# ['american']
#
# ['bankd']
#
# ['customer', 'service']
#
# ['bank']
#
# ['years']
#
# ['account']
#
# ['good', 'standing']
#
# ['month']
#
# ['financial', 'trouble']
#
# ['account']
#
# ['overdrawn', 'bankd']
#
# ['withdrabanka']
#
# ['account']
#
# ['transactions']
#
# ['i']
#
# ['negative', 'balance', 'i']
#
# ['insufficient', 'funds', 'fees']
#
# ['weeks', 'i']
#
# ['documentation']
#
# ['bankd']
#
# ['decline']
#
# ['purbankds']
#
# ['funded', 'i']
#
# ['customer', 'service']
#
# ['waiving']
#
# ['fees']
#
# ['i']
#
# ['manager']
#
# ['rebanke', 'isnt']
#
# ['bankd']
#
# ['i', 'dont']
#
# ['money']
#
# ['old', 'check']
#
# ['auto', 'payment']
#
# ['i', 'cant', 'deposit']
#
# ['paycheck']
#
# ['account']
#
# ['fees']
#
# ['i']
#
# ['bills', 'i']
#
# ['assistance']
#
# ['wonder', 'i']
#
# ['notices']
#
# ['joint', 'class', 'action', 'law', 'suites']
#
# ['bankd']
#
# ['bankd', 'interview', 'customer', 'service', 'representative', 'service', 'representative', 'bankd', 'interview', 'customer', 'service', 'representative', 'service', 'representative']
#
# ['bankd', 'bank', 'teller']
#
# ['bankd']
#
# ['bankd']
#
# ['amazbanke', 'i', 'couldnt']
#
# ['customer', 'service', 'rep']
#
# ['morning', 'i']
#
# ['issue']
#
# ['nsf', 'fees']
#
# ['bankb']
#
# ['account']
#
# ['great', 'customer', 'service', 'bankd', 'bankdbankd']
#
# ['bankd']
#
# ['friendly', 'bank']
#
# ['customer', 'service']
#
# ['comment']
#
# ['true', 'i']
#
# ['treatment']
#
# ['i', 'call', 'bankc']
#
# ['aggravating', 'good', 'luck']
#
# ['bank', 'i']
#
# ['bankc']
#
# ['poor', 'customer', 'service']
#
# ['bankc', 'bank', 'bank']
#
# ['customer', 'service']
#
# ['phone']
#
# ['need']
#
# ['help']
#
# ['guru']
#
# ['technological', 'mess']
#
# ['bankc', 'bank']
#
# ['fees']
#
# ['account']
#
# ['month']
#
# ['dope']
#
# ['zipfer', 'customer', 'service']
#
# ['bankc', 'bank']
#
# ['pissed']
#
# ['money']
#
# ['new', 'bank']
#
# ['bankcmortgage']
#
# ['dirmsgv']
#
# ['customer', 'service']
#
# ['difference']
#
# ['dirmsgv']
#
# ['crap']
#
# ['face']
#
# ['bankc']
#
# ['months', 'i']
#
# ['new', 'bank']
#
# ['business']
#
# ['shame']
#
# ['years']
#
# ['bankc']
#
# ['customer', 'service', 'deparettwitment']
#
# ['supervisors', 'u']
#
# ['u']
#
# ['money']
#
# ['account']
#
# ['bankc', 'malaysia']
#
# ['serious', 'issue']
#
# ['fraud', 'bad', 'customer', 'service', 'disastrobanke']
#
# ['bankc']
#
# ['bank']
#
# ['world']
#
# ['outsource']
#
# ['customer', 'service']
#
# ['manilla']
#
# ['bankc', 'i']
#
# ['provider']
#
# ['banka', 'account']
#
# ['business']
#
# ['experience']
#
# ['bankb']
#
# ['gecu', 'i']
#
# ['customer', 'service']
#
# ['bankc', 'customer', 'service']
#
# ['top']
#
# ['state']
#
# ['virginia']
#
# ['bankc', 'account']
#
# ['cant', 'conduct']
#
# ['type']
#
# ['elevens', 'atm']
#
# ['joke']
#
# ['bankc']
#
# ['major', 'bank']
#
# ['virginia']
#
# ['bankc']
#
# ['physical', 'branch']
#
# ['time']
#
# ['different', 'bank']
#
# ['couldnt']
#
# ['abu', 'dhabi']
#
# ['flight']
#
# ['bankd', 'i']
#
# ['new', 'bank']
#
# ['customer']
#
# ['junction', 'customer', 'service']
#
# ['permanent', 'position', 'century', 'city']
#
# ['western', 'cape', 'bankd', 'response']
#
# ['part']
#
# ['jobsjunction', 'co', 'za']
#
# ['customer']
#
# ['bankd', 'response']
#
# ['city', 'customer', 'service']
#
# ['city']
#
# ['response']
#
# ['part']
#
# ['group']
#
# ['organisation']
#
# ['staff']
#
# ['nationalities']
#
# ['locations']
#
# ['countries']
#
# ['rich', 'history']
#
# ['product']
#
# ['marketing', 'innovation', 'particul', 'grade', 'jobs']
#
# ['customer', 'service', 'ans', 'sales']
#
# ['bankb']
#
# ['customer', 'service']
#
# ['banka']
#
# ['i']
#
# ['location', 'smh', 'twithndlbanka', 'bank']
#
# ['customer', 'service']
#
# ['local', 'bankb']
#
# ['customer']
#
# ['bank']
#
# ['real', 'customer', 'service', 'complaint']
#
# ['safeway']
#
# ['bank']
#
# ['nathan', 'engstrom']
#
# ['i']
#
# ['balance']
#
# ['bank', 'account']
#
# ['banka', 'y', 'modern', 'videos']
#
# ['customer', 'service']
#
# ['banka']
#
# ['customer', 'service']
#
# ['i']
#
# ['banka']
#
# ['years']
#
# ['problems']
#
# ['statements']
#
# ['i']
#
# ['email']
#
# ['payment']
#
# ['way']
#
# ['cant']
#
# ['payment']
#
# ['bank', 'cant']
#
# ['debit', 'card']
#
# ['phone']
#
# ['rebanke']
#
# ['i']
#
# ['great', 'customer', 'service']
#
# ['attitude']
#
# ['customer', 'service', 'i']
#
# ['i']
#
# ['company']
#
# ['email', 'hack']
#
# ['reply', 'email', 'address']
#
# ['banka', 'bank']
#
# ['end']
#
# ['link']
#
# ['banka', 'account', 'login']
#
# ['fishy', 'thing']
#
# ['website']
#
# ['banka', 'bank']
#
# ['account']
#
# ['others']
#
# ['account']
#
# ['i']
#
# ['post']
#
# ['photos']
#
# ['email']
#
# ['customer']
#
# ['form']
#
# ['good', 'relationship']
#
# ['customer']
#
# ['ms']
#
# ['customer', 'service', 'officer']
#
# ['good', 'quote']
#
# ['client', 'n']
#
# ['comnand']
#
# ['customer']
#
# ['patience']
#
# ['kind']
#
# ['customer']
#
# ['customer']
#
# ['bankc', 'singapore', 'i']
#
# ['ms']
#
# ['excellent', 'knowledge']
#
# ['customer', 'service']
#
# ['waste']
#
# ['good', 'customer', 'service']
#
# ['ms']
#
# ['customer', 'service']
#
# ['bankd', 'store', 'managers']
#
# ['problem']
#
# ['pm']
#
# ['manager']
#
# ['call', 'rebanke']
#
# ['customer', 'service']
#
# ['i']
#
# ['bank', 'i']
#
# ['business']
#
# ['bankb']
#
# ['i']
#
# ['time']
#
# ['bank']
#
# ['i']
#
# ['minutes']
#
# ['dispute']
#
# ['maintenance', 'fees']
#
# ['lovely', 'rep']
#
# ['question']
#
# ['manager']
#
# ['minutes']
#
# ['explanation']
#
# ['i']
#
# ['customer', 'service', 'reps']
#
# ['nation']
#
# ['money', 'i']
#
# ['forbankb', 'sucks', 'butt']
#
# ['customer', 'service', 'sucks']
#
# ['banka']
#
# ['street', 'lansdale']
#
# ['customer', 'service']
#
# ['nice', 'i']
#
# ['i', 'bank']
#
# ['bankb']
#
# ['rude', 'service']
#
# ['customer', 'service']
#
# ['sprint']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['day', 'shift']
#
# ['club']
#
# ['tv', 'idea', 'tata', 'vodafoneinboundday', 'shift']
#
# ['club']
#
# ['tv', 'idea', 'tata', 'vodafoneinbound']
#
# ['job', 'vacancyopening']
#
# ['portaljob']
#
# ['inbound', 'process']
#
# ['club', 'mahindra']
#
# ['vodafone']
#
# ['tv', 'icici', 'bank', 'bankc', 'bank', 'etc']
#
# ['targetspure', 'customer', 'servicesunday', 'fix']
#
# ['dc', 'friends']
#
# ['new', 'bank']
#
# ['fan']
#
# ['bankc']
#
# ['bankb']
#
# ['banks']
#
# ['city', 'atm']
#
# ['branch']
#
# ['experience']
#
# ['banks']
#
# ['banka', 'sucks', 'time']
#
# ['new', 'bank']
#
# ['suggestions']
#
# ['nice', 'local', 'bank']
#
# ['banka', 's', 'retail', 'credit', 'customer', 'service']
#
# ['phone']
#
# ['terrible', 'experience']
#
# ['making']
#
# ['use']
#
# ['service']
#
# ['dear', 'banka', 'i']
#
# ['customer', 'service']
#
# ['drill', 'sergeant']
#
# ['dear', 'bankb']
#
# ['people']
#
# ['line', 'teller', 'windows']
#
# ['tellers', 'teller']
#
# ['business']
#
# ['day']
#
# ['surprise']
#
# ['week']
#
# ['numbers']
#
# ['day']
#
# ['math']
#
# ['customer', 'service', 'sucks']
#
# ['dear', 'bankb']
#
# ['bank']
#
# ['town']
#
# ['atm']
#
# ['charge']
#
# ['monthly', 'maintenance', 'fee']
#
# ['town']
#
# ['nearby', 'city']
#
# ['miles']
#
# ['direction', 'i']
#
# ['i']
#
# ['great', 'customer', 'service']
#
# ['atm', 'drive']
#
# ['bankb']
#
# ['bankczens', 'thanks']
#
# ['great', 'customer', 'service']
#
# ['folks']
#
# ['small', 'town']
#
# ['decision']
#
# ['dear', 'banka', 'banka']
#
# ['rock', 'hardcore']
#
# ['bank', 'i']
#
# ['customer', 'service', 'thanks']
#
# ['katonak']
#
# ['dear', 'banka', 'banka']
#
# ['cancelation']
#
# ['debit', 'card']
#
# ['charges']
#
# ['great', 'customer', 'services']
#
# ['dear', 'banka', 'banka']
#
# ['rock', 'hardcore']
#
# ['branch']
#
# ['great', 'customer', 'service', 'thanks']
#
# ['katonak']
#
# ['dear', 'banka', 'banka']
#
# ['phone', 'customer', 'service']
#
# ['workers']
#
# ['outsource']
#
# ['information']
#
# ['money']
#
# ['customer', 'service']
#
# ['bankd', 'home', 'mortgages']
#
# ['bankd', 'liquid', 'visa', 'debit']
#
# ['walmart']
#
# ['customer', 'service']
#
# ['shoprite']
#
# ['debit']
#
# ['credit', 'i']
#
# ['customer', 'service']
#
# ['cards']
#
# ['bankb', 'atms']
#
# ['credit']
#
# ['bankbs']
#
# ['app']
#
# ['phones']
#
# ['full', 'well']
#
# ['alternative']
#
# ['web', 'page']
#
# ['poor', 'substitute']
#
# ['key', 'functionality', 'companies']
#
# ['commitment']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['commitment']
#
# ['bankb']
#
# ['sub']
#
# ['customer', 'service']
#
# ['mistakes']
#
# ['email']
#
# ['bankc']
#
# ['i']
#
# ['debit', 'atm', 'card']
#
# ['bankc']
#
# ['i']
#
# ['i', 'call']
#
# ['customer', 'service']
#
# ['touch']
#
# ['i']
#
# ['i']
#
# ['credit', 'debit', 'atm']
#
# ['bankc', 'i']
#
# ['credit', 'report']
#
# ['agenicies']
#
# ['thing']
#
# ['bankctbank']
#
# ['bank']
#
# ['banka']
#
# ['customer', 'service', 'reps']
#
# ['app']
#
# ['bankb', 'app']
#
# ['customer', 'service']
#
# ['problems', 'people']
#
# ['app']
#
# ['correct', 'information']
#
# ['overdraft', 'fee']
#
# ['information']
#
# ['app']
#
# ['correct', 'balance']
#
# ['i']
#
# ['business']
#
# ['years']
#
# ['bankb', 'customer', 'service', 'survey']
#
# ['bankd', 'bank', 'branch']
#
# ['question']
#
# ['i', 'dont']
#
# ['customer', 'service']
#
# ['baby']
#
# ['branch']
#
# ['letter']
#
# ['ceo']
#
# ['banka', 'bank', 'i']
#
# ['customer', 'service']
#
# ['times']
#
# ['customers']
#
# ['talk']
#
# ['letter']
#
# ['banka']
#
# ['customer', 'service']
#
# ['route']
#
# ['bankd', 'bank']
#
# ['lack']
#
# ['customer', 'service']
#
# ['rude', 'employees']
#
# ['saddens']
#
# ['years']
#
# ['service']
#
# ['i']
#
# ['message']
#
# ['manager']
#
# ['bankb']
#
# ['general', 'policies', 'i']
#
# ['i']
#
# ['specifibankc', 'anke']
#
# ['hardship']
#
# ['payment', 'policy']
#
# ['i']
#
# ['phone']
#
# ['customer', 'service']
#
# ['policies']
#
# ['i']
#
# ['account', 'i']
#
# ['decisions']
#
# ['lot']
#
# ['company', 'i']
#
# ['business']
#
# ['i']
#
# ['i']
#
# ['policies']
#
# ['account', 'holders']
#
# ['kids']
#
# ['weekly', 'allowances', 'bankb']
#
# ['bank', 'poor', 'customer', 'service', 'service']
#
# ['kids']
#
# ['money']
#
# ['finance']
#
# ['young', 'ages']
#
# ['customers']
#
# ['customer', 'service', 'department']
#
# ['bankd', 'bank']
#
# ['hours']
#
# ['philapeans']
#
# ['i']
#
# ['usa']
#
# ['americans']
#
# ['customer', 'service', 'line']
#
# ['talk']
#
# ['bankd', 'bank', 'time']
#
# ['new', 'bank', 'bankb']
#
# ['i']
#
# ['bank']
#
# ['bankb']
#
# ['i']
#
# ['while', 'i']
#
# ['customer', 'service']
#
# ['bogas', 'number']
#
# ['dont']
#
# ['bank', 'card']
#
# ['mexico']
#
# ['money']
#
# ['atm', 'bankb']
#
# ['bank']
#
# ['own', 'great', 'customer', 'servicenot']
#
# ['bankb']
#
# ['work', 'tommrow']
#
# ['woekin']
#
# ['week']
#
# ['thrn', 'opening']
#
# ['new', 'bank', 'account']
#
# ['bankb', 'thursday']
#
# ['day']
#
# ['im']
#
# ['small', 'town']
#
# ['good', 'standing']
#
# ['folks']
#
# ['word']
#
# ['i']
#
# ['social', 'media']
#
# ['ppl']
#
# ['care']
#
# ['banka']
#
# ['customer', 'service']
#
# ['bankeing', 'institution']
#
# ['doesnt', 'penalize']
#
# ['i']
#
# ['i']
#
# ['bucks']
#
# ['account']
#
# ['home']
#
# ['i']
#
# ['bank']
#
# ['i']
#
# ['tellers']
#
# ['mom']
#
# ['theres']
#
# ['epic']
#
# ['bankd', 'bank', 'theyve']
#
# ['tellers']
#
# ['atms']
#
# ['line']
#
# ['door']
#
# ['teller', 'service']
#
# ['tellers']
#
# ['drive']
#
# ['window']
#
# ['atms']
#
# ['rebanke']
#
# ['kind']
#
# ['customer', 'service']
#
# ['allobanka', 'rom']
#
# ['companies']
#
# ['gentleman']
#
# ['people']
#
# ['line']
#
# ['teller', 'service']
#
# ['atm']
#
# ['airport']
#
# ['theyre']
#
# ['machines']
#
# ['people']
#
# ['companies']
#
# ['people']
#
# ['people', 'i']
#
# ['way', 'bankd']
#
# ['happy', 'holidays']
#
# ['banka']
#
# ['customer', 'service']
#
# ['staff']
#
# ['company', 'lookingforanotherbank', 'sodisappointed']
#
# ['time', 'i']
#
# ['bankb']
#
# ['hour']
#
# ['complete', 'joke']
#
# ['i']
#
# ['customer', 'service', 'number']
#
# ['i']
#
# ['secs']
#
# ['seconds', 'rebanke']
#
# ['joke', 'i']
#
# ['personal', 'account']
#
# ['husbands', 'business', 'account', 'asap']
#
# ['waterstone', 'plaza', 'plaza']
#
# ['homestead']
#
# ['time', 'i']
#
# ['bankb', 'i', 'dread']
#
# ['possible', 'customer', 'service']
#
# ['bank']
#
# ['excellent', 'customer', 'service', 'service']
#
# ['vista', 'ridge', 'lewisville', 'branch']
#
# ['helpful', 'bankb', 'happycustomer']
#
# ['exceptionbanke', 'bad', 'customer', 'service', 'i']
#
# ['bankb']
#
# ['business']
#
# ['poor', 'business', 'practices']
#
# ['own', 'business', 'look']
#
# ['werent']
#
# ['customer', 'service', 'i']
#
# ['banka', 'banker']
#
# ['switch', 'banks']
#
# ['recommendations']
#
# ['f', 'bankd']
#
# ['customer', 'service']
#
# ['im']
#
# ['im']
#
# ['manager']
#
# ['bank', 'teller', 'grr', 'thats']
#
# ['i', 'love']
#
# ['bankawhatever']
#
# ['kern']
#
# ['weekend']
#
# ['stress']
#
# ['f', 'bankd', 'bank', 'bank', 'i', 'call']
#
# ['customer', 'service', 'number']
#
# ['offline']
#
# ['customer', 'support']
#
# ['f', 'k', 'banka']
#
# ['account']
#
# ['customer', 'service', 'service']
#
# ['banka']
#
# ['cant', 'call', 'customer', 'service']
#
# ['real', 'person']
#
# ['business']
#
# ['fedex']
#
# ['rebanke']
#
# ['screws']
#
# ['vacation']
#
# ['tickets']
#
# ['time']
#
# ['week']
#
# ['weve']
#
# ['grand', 'kids']
#
# ['dont']
#
# ['tickets', 'thanks']
#
# ['fedex', 'i', 'rebanke']
#
# ['stock', 'price', 'tanks']
#
# ['terrible', 'service']
#
# ['attitude']
#
# ['wife']
#
# ['class']
#
# ['crap', 'customer', 'service']
#
# ['bankb']
#
# ['finbanke']
#
# ['new', 'bank', 'account']
#
# ['dis']
#
# ['bankb']
#
# ['tennessee']
#
# ['money']
#
# ['bankb', 'transition', 'mess']
#
# ['ridiculous', 'i']
#
# ['new', 'bank']
#
# ['weeks', 'i']
#
# ['banka']
#
# ['micromanaging', 'super', 'robot']
#
# ['future']
#
# ['system']
#
# ['doesnt']
#
# ['customer', 'service', 'humans']
#
# ['work']
#
# ['time']
#
# ['customer', 'service', 'humans']
#
# ['help']
#
# ['automatic', 'reply']
#
# ['system']
#
# ['i']
#
# ['banka']
#
# ['secret', 'deal']
#
# ['post', 'office']
#
# ['mail']
#
# ['banka']
#
# ['normal', 'mail']
#
# ['new', 'debit', 'card']
#
# ['days']
#
# ['damn', 'system']
#
# ['robots']
#
# ['banka']
#
# ['new', 'bank']
#
# ['money']
#
# ['bankc', 'customer', 'service']
#
# ['insult']
#
# ['injury']
#
# ['banka', 'bank']
#
# ['new', 'bank']
#
# ['i']
#
# ['account']
#
# ['month']
#
# ['direct', 'deposit']
#
# ['care']
#
# ['i']
#
# ['son']
#
# ['money']
#
# ['predicament']
#
# ['bank']
#
# ['bankb']
#
# ['weeks']
#
# ['new', 'bank']
#
# ['bankb']
#
# ['fortyfive', 'minutes']
#
# ['i']
#
# ['banka', 'doesnt']
#
# ['customer', 'service']
#
# ['customers', 'time']
#
# ['new', 'bank']
#
# ['fraud']
#
# ['bankd', 'debit', 'card']
#
# ['portland']
#
# ['customer', 'service']
#
# ['little', 'sister']
#
# ['couldnt']
#
# ['hoops', 'i']
#
# ['dam', 'money', 'bankb', 'i']
#
# ['bankd']
#
# ['ass']
#
# ['hoops']
#
# ['account']
#
# ['interest']
#
# ['account']
#
# ['ads']
#
# ['funds']
#
# ['bank', 'policy']
#
# ['stupid', 'dear', 'bankd']
#
# ['bank']
#
# ['account']
#
# ['elsewhwre', 'bankd']
#
# ['fanny', 'i']
#
# ['money']
#
# ['magicly']
#
# ['account', 'haha', 'bankd', 'bank']
#
# ['friendly', 'staff']
#
# ['bank']
#
# ...
#
# ['day', 'i']
#
# ['account']
#
# ['day', 'im']
#
# ['i']
#
# ['track']
#
# ['bills']
#
# ['ledger']
#
# ['account']
#
# ['day']
#
# ['new', 'atm', 'cards']
#
# ['bank']
#
# ['money', 'i']
#
# ['customer', 'service']
#
# ['help']
#
# ['screen']
#
# ['i']
#
# ['thats']
#
# ['fault']
#
# ['error']
#
# ['whats']
#
# ['bank']
#
# ['locations']
#
# ['louisiana', 'andtx']
#
# ['new', 'bank', 'account']
#
# ['asap']
#
# ['work']
#
# ['bank']
#
# ['banka']
#
# ['fraud']
#
# ['claims', 'assistance', 'center']
#
# ['instance']
#
# ['customers', 'fault', 'i']
#
# ['banks']
#
# ['line']
#
# ['defense', 'i']
#
# ['unprofessional', 'customer', 'service']
#
# ['top']
#
# ['recommendations', 'i']
#
# ['banka']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['abankaul']
#
# ['i']
#
# ['banka', 'i']
#
# ['mortgage', 'i']
#
# ['customer', 'service', 'people']
#
# ['i', 'call']
#
# ['customer', 'service']
#
# ['i']
#
# ['email']
#
# ['online', 'password']
#
# ['incorrectly', 'times']
#
# ['i']
#
# ['reset']
#
# ['online']
#
# ['i']
#
# ['customer', 'support', 'i']
#
# ['i']
#
# ['branch', 'i']
#
# ['victoria']
#
# ['obvious', 'reasons']
#
# ['call']
#
# ['escalated']
#
# ['i']
#
# ['thing', 'i']
#
# ['voice', 'message']
#
# ['rd', 'level']
#
# ['call']
#
# ['days', 'days']
#
# ['suggestions']
#
# ['i']
#
# ['contact']
#
# ['i']
#
# ['banka', 'customer']
#
# ['years']
#
# ['i']
#
# ['access']
#
# ['account']
#
# ['active', 'i']
#
# ['actubanke']
#
# ['company', 'policy', 'thanks']
#
# ['advance']
#
# ['new', 'bank', 'account']
#
# ['roommate']
#
# ['awesome', 'banker']
#
# ['banka']
#
# ['bankc', 'customer', 'service']
#
# ['bankb']
#
# ['lanes']
#
# ['people']
#
# ['rebanke']
#
# ['customer', 'service']
#
# ['switch']
#
# ['bankb', 'app']
#
# ['windows', 'phones']
#
# ['microsoft', 'i']
#
# ['time']
#
# ['new', 'bank', 'thats', 'bad', 'business']
#
# ['mortgages']
#
# ['illegbanke']
#
# ['big', 'money', 'sux']
#
# ['bankb']
#
# ['people']
#
# ['banka']
#
# ['peoples', 'posts']
#
# ['didnt', 'meet']
#
# ['expectations']
#
# ['isnt']
#
# ['apologizing']
#
# ['questions']
#
# ['complaints', 'discriminatory', 'customer', 'service']
#
# ['contact', 'bankd', 'customer', 'service', 'i']
#
# ['issue']
#
# ['email', 'i']
#
# ['contact']
#
# ['banka', 'usubanke']
#
# ['customer', 'service', 'people']
#
# ['tellers']
#
# ['lines']
#
# ['deposit']
#
# ['bankb']
#
# ['ok', 'tohave', 'people']
#
# ['line']
#
# ['tellers']
#
# ['people']
#
# ['line']
#
# ['totbanke']
#
# ['horrible', 'customer', 'service', 'i']
#
# ['line']
#
# ['minutes']
#
# ['people']
#
# ['hiresometellers']
#
# ['banka']
#
# ['money']
#
# ['sponsorships', 'banka']
#
# ['reinvest']
#
# ['customer', 'service']
#
# ['business']
#
# ['community', 'good', 'will']
#
# ['customer', 'service', 'rep']
#
# ['simple', 'question', 'i']
#
# ['i', 'pay']
#
# ['rest']
#
# ['balance']
#
# ['interest']
#
# ['card']
#
# ['month']
#
# ['interest']
#
# ['response']
#
# ['manager', 'i', 'didnt']
#
# ['manager']
#
# ['answer', 'i', 'work']
#
# ['bank']
#
# ['simple', 'answer']
#
# ['i']
#
# ['i', 'dont']
#
# ['dont']
#
# ['interest', 'rates']
#
# ['dont']
#
# ['statement']
#
# ['date']
#
# ['pay']
#
# ['full', 'balance']
#
# ['interest']
#
# ['balance']
#
# ['i', 'work']
#
# ['case']
#
# ['i']
#
# ['payment']
#
# ['full', 'i']
#
# ['complaint']
#
# ['member']
#
# ['management', 'team']
#
# ['night']
#
# ['quicksilver', 'card']
#
# ['way']
#
# ['i']
#
# ['business', 'practices']
#
# ['credit', 'cards', 'i']
#
# ['big', 'banks']
#
# ['dont']
#
# ['business']
#
# ['way']
#
# ['result', 'i']
#
# ['i']
#
# ['lot']
#
# ['balance', 'transfers']
#
# ['account']
#
# ['business']
#
# ['way']
#
# ['i']
#
# ['card']
#
# ['rewards']
#
# ['bankb']
#
# ['rate']
#
# ['rate']
#
# ['bankb']
#
# ['person']
#
# ['customer', 'service', 'min', 'wait']
#
# ['customer', 'service', 'reps']
#
# ['massive', 'bank', 'fees']
#
# ['charge']
#
# ['btw']
#
# ['rep']
#
# ['limit']
#
# ['shit', 'time']
#
# ['business']
#
# ['places']
#
# ['customer']
#
# ['i']
#
# ['bankb']
#
# ['problem']
#
# ['account']
#
# ['customer', 'service', 'pass']
#
# ['buck']
#
# ['i', 'call', 'bankb', 'customer', 'service']
#
# ['i']
#
# ['lady']
#
# ['philippines', 'i']
#
# ['way']
#
# ['jobs']
#
# ['america', 'bankb']
#
# ['bankd']
#
# ['credit', 'customer']
#
# ['years']
#
# ['work']
#
# ['interest', 'rate']
#
# ['britches']
#
# ['customer', 'service', 'doesnt', 'matter']
#
# ['passion', 'i']
#
# ['banka', 'i']
#
# ['new', 'bank']
#
# ['second']
#
# ['fucking']
#
# ['money']
#
# ['mins']
#
# ['call']
#
# ['bankd', 'bankd']
#
# ['i']
#
# ['email']
#
# ['i']
#
# ['application']
#
# ['customer', 'service', 'posisition']
#
# ['branch']
#
# ['polaris', 'i']
#
# ['molly']
#
# ['isnt']
#
# ['rebanke']
#
# ['oppourtunity']
#
# ['bankb']
#
# ['services']
#
# ['hours']
#
# ['customer', 'service']
#
# ['bank']
#
# ['i']
#
# ['clients']
#
# ['word']
#
# ['goodyear', 'tire', 'tire', 'centers']
#
# ['sign']
#
# ['bankc', 'credit', 'card']
#
# ['june']
#
# ['year', 'i']
#
# ['billing', 'statement']
#
# ['card']
#
# ['i']
#
# ['customer', 'service']
#
# ['youre']
#
# ['liar']
#
# ['i']
#
# ['account']
#
# ['incompetent', 'idiots']
#
# ['ass']
#
# ['customer', 'service', 'i']
#
# ['thankfully', 'i']
#
# ['account']
#
# ['deceased', 'aunt']
#
# ['customer']
#
# ['years']
#
# ['sisterwho']
#
# ['executoris']
#
# ['run']
#
# ['icing']
#
# ['cake']
#
# ['bankb', 'error']
#
# ['bank']
#
# ['money']
#
# ['account']
#
# ['bank']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['woolbright']
#
# ['boynton', 'beach', 'i']
#
# ['bankb']
#
# ['years']
#
# ['experience']
#
# ['bank']
#
# ['new', 'bank', 'account', 'holders', 'i', 'highlly', 'recomend', 'bankb']
#
# ['needs']
#
# ['bank']
#
# ['i']
#
# ['account']
#
# ['sons']
#
# ['tuition', 'check']
#
# ['unknown', 'reasons']
#
# ['hour', 'customer', 'service']
#
# ['i']
#
# ['account']
#
# ['day']
#
# ['i']
#
# ['hours']
#
# ['account']
#
# ['hours']
#
# ['i']
#
# ['letter']
#
# ['week']
#
# ['i']
#
# ['credit']
#
# ['place', 'i', 'hadnt']
#
# ['i']
#
# ['money']
#
# ['account']
#
# ['time']
#
# ['account']
#
# ['wasnt']
#
# ['month']
#
# ['letter']
#
# ['account', 'i']
#
# ['i']
#
# ['branch']
#
# ['time']
#
# ['systems']
#
# ['account']
#
# ['i']
#
# ['pissed', 'i']
#
# ['customer', 'service']
#
# ['customer']
#
# ['way']
#
# ['i']
#
# ['fees']
#
# ['account', 'i']
#
# ['bankd']
#
# ['son', 'tuition', 'checks']
#
# ['bank', 'experience']
#
# ['bankd', 'bank', 'bank']
#
# ['horrible', 'customer', 'service']
#
# ['manger']
#
# ['rude', 'i']
#
# ['account']
#
# ['bank']
#
# ['frys', 'location']
#
# ['baseline']
#
# ['rd']
#
# ['bank']
#
# ['bankd']
#
# ['customer', 'service']
#
# ['change']
#
# ['bankb']
#
# ['area']
#
# ['actubanke']
#
# ['bankb', 'banka', 'sucks', 'giant', 'donkey', 'balls', 'customer']
#
# ['i']
#
# ['bah']
#
# ['new', 'bank']
#
# ['land']
#
# ['excellent', 'bank']
#
# ['switchingnow']
#
# ['experience']
#
# ['mother', 'accidentbanke']
#
# ['money']
#
# ['close', 'account']
#
# ['bankb']
#
# ['money']
#
# ['weeks']
#
# ['bankb', 'agents']
#
# ['tricking']
#
# ['kick']
#
# ['local', 'branch']
#
# ['local', 'branch', 'kicks']
#
# ['wiring', 'transfer', 'dept', 'dept']
#
# ['days']
#
# ['weeks']
#
# ['bank']
#
# ['shame']
#
# ['bankb']
#
# ['bankd', 'bank']
#
# ['sucks']
#
# ['bank']
#
# ['shirty', 'employees']
#
# ['time']
#
# ['new', 'bank']
#
# ['customer', 'service']
#
# ['life', 'run', 'run', 'run', 'run']
#
# ['bankb', 'dont']
#
# ['control', 'tour', 'financial', 'well']
#
# ['customer', 'service', 'simple', 'things']
#
# ['banke']
#
# ['youre']
#
# ['business']
#
# ['banka', 'way']
#
# ['competition']
#
# ['technology']
#
# ['o', 'k', 'e']
#
# ['institution']
#
# ['customer', 'service']
#
# ['account']
#
# ['week']
#
# ['credit', 'refund', 'issueddue']
#
# ['bank', 'errorand', 'bankd', 'customer', 'service']
#
# ['unhelpful']
#
# ['customer', 'service']
#
# ['pitiful', 'account', 'management', 'support']
#
# ['bankc']
#
# ['robocalls']
#
# ['customer', 'service']
#
# ['planet']
#
# ['bankc', 'bank', 'bank']
#
# ['customers']
#
# ['customer', 'service']
#
# ['i']
#
# ['customer', 'service']
#
# ['hours']
#
# ['avail', 'weve']
#
# ['card', 'holders']
#
# ['years', 'i', 'use']
#
# ['bankb', 'card']
#
# ['purbankds', 'i']
#
# ['business']
#
# ['company']
#
# ['recent', 'experience']
#
# ['customer', 'service']
#
# ['card', 'department']
#
# ['payment']
#
# ['guarantee']
#
# ['i']
#
# ['card']
#
# ['min']
#
# ['min']
#
# ['call']
#
# ['actubanke']
#
# ['min']
#
# ['information']
#
# ['reps']
#
# ['banka']
#
# ['bank', 'i']
#
# ['card']
#
# ['days']
#
# ['training']
#
# ['employees']
#
# ['customer', 'service']
#
# ['banka']
#
# ['financial', 'institute']
#
# ['privacy']
#
# ['customer', 'service']
#
# ['people']
#
# ['revelant', 'questions']
#
# ['card']
#
# ['fraud', 'dept']
#
# ['american']
#
# ['bankc']
#
# ['banke']
#
# ['visa', 'bankd']
#
# ['infor']
#
# ['bankege']
#
# ['bank', 'institution']
#
# ['proper', 'training']
#
# ['customer', 'service', 'employees', 'dont']
#
# ['experiences']
#
# ['thieves', 'institution']
#
# ['i', 'end']
#
# ['disability', 'check']
#
# ['person']
#
# ['certain', 'amount']
#
# ['money']
#
# ['hundreds']
#
# ['institution', 'stealing']
#
# ['shame']
#
# ['bankb']
#
# ['wow', 'i']
#
# ['banka']
#
# ['fucking', 'ground']
#
# ['account']
#
# ['month']
#
# ['temp', 'card']
#
# ['mailwhich']
#
# ['happenedso', 'i']
#
# ['deposit']
#
# ['new', 'card']
#
# ['temporary', 'card']
#
# ['days']
#
# ['dude']
#
# ['id']
#
# ['new', 'temp', 'card']
#
# ['i']
#
# ['withdrawal']
#
# ['new', 'id']
#
# ['i']
#
# ['check']
#
# ['id']
#
# ['issue']
#
# ['i']
#
# ['banker']
#
# ['i']
#
# ['new', 'id']
#
# ['wont', 'issue']
#
# ['new', 'card']
#
# ['account']
#
# ['i', 'dont']
#
# ['great', 'customer', 'service']
#
# ['banka', 'rebanke']
#
# ['bad', 'customer', 'service']
#
# ['banka']
#
# ['wow']
#
# ['bankas', 'customer', 'service', 'i']
#
# ['account']
#
# ['credit', 'card']
#
# ['mortgage']
#
# ['todays', 'customer', 'service']
#
# ['bank']
#
# ['abankaul', 'hmmmm']
#
# ['relationship']
#
# ['wow', 'i']
#
# ['banka']
#
# ['manager']
#
# ['position', 'i', 'literbanke']
#
# ['quarters']
#
# ['i']
#
# ['i']
#
# ['politeness']
#
# ['employees']
#
# ['long', 'way']
#
# ['years']
#
# ['customer', 'service']
#
# ['totbanke']
#
# ['day']
#
# ['wow']
#
# ['phone']
#
# ['banke']
#
# ['dispute']
#
# ['late', 'fees']
#
# ['american']
#
# ['business', 'card']
#
# ['courtesy']
#
# ['i']
#
# ['company']
#
# ['board']
#
# ['directors']
#
# ['customer', 'service']
#
# ['i']
#
# ['business', 'card']
#
# ['bankd', 'visa', 'signature', 'card']
#
# ['twithndlbanka', 'bank']
#
# ['cents']
#
# ['i']
#
# ['certain', 'amount']
#
# ['business', 'account']
#
# ['month']
#
# ['i', 'deposit', 'money']
#
# ['bank']
#
# ['bank']
#
# ['money']
#
# ['privilege']
#
# ['profit']
#
# ['money']
#
# ['isnt']
#
# ['i']
#
# ['bank', 'regulation']
#
# ['bankers']
#
# ['new', 'bank']
#
# ['bankc']
#
# ['sa', 'service', 'nyo', 'poor', 'poor', 'poor', 'customer', 'service']
#
# ['payments']
#
# ['car']
#
# ['days', 'days']
#
# ['car']
#
# ['date']
#
# ['payment', 'i']
#
# ['end']
#
# ['month']
#
# ['feb', 'i']
#
# ['date', 'i']
#
# ['arm']
#
# ['trama']
#
# ['top']
#
# ['head']
#
# ['bottom']
#
# ['face', 'split']
#
# ['medication']
#
# ['odasity']
#
# ['excepted']
#
# ['payment']
#
# ['threats']
#
# ['days']
#
# ['i']
#
# ['check']
#
# ['bankb']
#
# ['trash', 'talk', 'i']
#
# ['customer', 'service']
#
# ['years']
#
# ['i']
#
# ['people']
#
# ['woman']
#
# ['customers']
#
# ['respect']
#
# ['payment']
#
# ['tulsa', 'oklahoma']
#
# ['banka']
#
# ['i']
#
# ['payment']
#
# ['trash']
#
# ['mouth']
#
# ['threats', 'thanks', 'terri']
#
# ['yah', 'i', 'love']
#
# ['bankb']
#
# ['people']
#
# ['customer', 'service']
#
# ['machine']
#
# ['card']
#
# ['switch']
#
# ['bankd']
#
# ['customer', 'service', 'couldnt']
#
# ['problem', 'wasnt']
#
# ['money']
#
# ['teller']
#
# ['job']
#
# ['i']
#
# ['banka']
#
# ['i']
#
# ['teller']
#
# ['inconvenience']
#
# ['shes']
#
# ['personal', 'grudge']
#
# ['i']
#
# ['opportunity']
#
# ['businesses']
#
# ['way']
#
# ['customer', 'services', 'i']
#
# ['experience']
#
# ['branch', 'manager']
#
# ['banka', 'bank']
#
# ['burien', 'i']
#
# ['sir']
#
# ['banka']
#
# ['customer', 'service']
#
# ['priority']
#
# ['trade']
#
# ['institution']
#
# ['banka']
#
# ['new', 'bank']
#
# ['customer', 'service', 'nightmare']
#
# ['banka']
#
# ['screw']
#
# ['business', 'days']
#
# ['peoples', 'money']
#
# ['i']
#
# ['terrible', 'customer', 'service', 'experience']
#
# ['bankb', 'branch', 'bankbsucks']
#
# ['interactions']
#
# ['banka', 'customer', 'serviceheaven']
#
# ['cant']
#
# ['stop']
#
# ['systemthat']
#
# ['decision']
#
# ['banka']
#
# ['issue']
#
# ['new', 'bank']
#
# ['end']
#
# ['account']
#
# ['i']
#
# ['assistance']
#
# ['minute', 'call']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['money']
#
# ['guys']
#
# ['loyal', 'customer']
#
# ['error']
#
# ['customer']
#
# ['fees']
#
# ['account', 'i', 'look']
#
# ['fees']
#
# ['i']
#
# ['phone']
#
# ['name']
#
# ['number']
#
# ['loyal', 'customer']
#
# ['banka', 'i']
#
# ['th', 'account']
#
# ['wonderful', 'customer', 'service']
#
# ['account']
#
# ['thing', 'monday']
#
# ['fee']
#
# ['rep']
#
# ['instant', 'transfers']
#
# ['didnt', 'state']
#
# ['transfer']
#
# ['effect']
#
# ['customer', 'service', 'wasnt']
#
# ['matter']
#
# ['account']
#
# ['customer']
#
# ['doesnt']
#
# ['right']
#
# ['customer']
#
# ['crap']
#
# ['business']
#
# ['guys']
#
# ['guys']
#
# ['banks']
#
# ['vad', 'customer', 'service']
#
# ['sense']
#
# ['reliability', 'r', 'urgency']
#
# ['branch', 'n', 'i']
#
# ['actual', 'debit', 'card']
#
# ['months', 'bankb']
#
# ['right', 'bank']
#
# ['america']
#
# ['guys']
#
# ['i']
#
# ['account']
#
# ['card']
#
# ['week']
#
# ['thanks']
#
# ['i', 'cant']
#
# ['money']
#
# ['license']
#
# ['n']
#
# ['guys']
#
# ['money']
#
# ['i']
#
# ['preparbanke', 'deposit']
#
# ['week']
#
# ['thanksgiving']
#
# ['family']
#
# ['customer', 'service', 'sucks']
#
# ['income', 'family']
#
# ['turkey', 'dinner']
#
# ['i', 'cant']
#
# ['money']
#
# ['whats']
#
# ['afghanistan', 'veteran']
#
# ['u', 's', 'marines']
#
# ['selfless', 'sacrifice']
#
# ['country', 'i', 'didnt']
#
# ['millions', 'questions', 'n']
#
# ['guys', 'dont']
#
# ['bankb']
#
# ['vets']
#
# ['fellobanka', 'riends']
#
# ['bankb']
#
# ['veteran']
#
# ['theives']
#
# ['talibans', 'i']
#
# ['years']
#
# ['i']
#
# ['day']
#
# ['customer', 'service']
#
# ['bankb']
#
# ['i', 'havent']
#
# ['inbox']
#
# ['customer', 'service', 'rep', 'literbanke']
#
# ['profanity']
#
# ['phone']
#
# ['supervisor', 'i']
#
# ['dont']
#
# ['people']
#
# ['i']
#
# ['bankb', 'customer']
#
# ['friends']
#
# ['thats']
#
# ['bankd', 'bank', 'bank']
#
# ['wan', 'na']
#
# ['customer', 'service']
#
# ['dumb', 'regulations']
#
# ['customers']
#
# ['inconvenience']
#
# ['lot']
#
# ['customers']
#
# ['banka', 'i']
#
# ['lmao']
#
# ['yall']
#
# ['bank']
#
# ['charges', 'ppl']
#
# ['money']
#
# ['savings']
#
# ['savings']
#
# ['times']
#
# ['hell']
#
# ['overdraft']
#
# ['savings']
#
# ['account', 'yall']
#
# ['bank']
#
# ['world', 'i']
#
# ['yall']
#
# ['second']
#
# ['new', 'card']
#
# ['new', 'bank']
#
# ['mail', 'i']
#
# ['account']
#
# ['im']
#
# ['dollars']
#
# ['overdrafted']
#
# ['savings']
#
# ['money']
#
# ['yall']
#
# ['customers']
#
# ['i']
#
# ['petition']
#
# ['bankb']
#
# ['im']
#
# ['america']
#
# ['banka', 'thanks']
#
# ['call', 'bankb']
#
# ['manager']
#
# ['i']
#
# ['lies']
#
# ['deceit']
#
# ['bank']
#
# ['money']
#
# ['employees']
#
# ['customers', 'dont']
#
# ['wrong', 'information', 'time']
#
# ['bankd']
#
# ['husband']
#
# ['customer']
#
# ['customer', 'service']
#
# ['branch']
#
# ['hanover', 'nj']
#
# ['bunch']
#
# ['horrible', 'employees']
#
# ['terrible', 'customer', 'service', 'service']
#
# ['bankb', 'i']
#
# ['web']
#
# ['i']
#
# ['news']
#
# ['company']
#
# ['freaking', 'joke']
#
# ['year', 'old', 'daughter']
#
# ['accidentbanke']
#
# ['item', 'online']
#
# ['credit', 'card', 'info']
#
# ['laptop']
#
# ['guys']
#
# ['refund']
#
# ['bull']
#
# ['guys']
#
# ['years']
#
# ['mistake']
#
# ['tickets', 'way']
#
# ['money']
#
# ['americans']
#
# ['account']
#
# ['guys']
#
# ['dollars']
#
# ['car', 'payment']
#
# ['i']
#
# ['refund']
#
# ['charges']
#
# ['guys']
#
# ['ridiculous', 'i']
#
# ['family']
#
# ['i', 'love']
#
# ['customer', 'service', 'rep']
#
# ['i']
#
# ['replayed']
#
# ['phone', 'call']
#
# ['inconsistencies']
#
# ['company']
#
# ['joke']
#
# ['bank']
#
# ['banka']
#
# ['money']
#
# ['company']
#
# ['bankb', 'location']
#
# ['jungermann', 'road']
#
# ['missouri']
#
# ['management']
#
# ['teller']
#
# ['customer', 'service']
#
# ['reason']
#
# ['cant']
#
# ['company']
#
# ['ridiculous', 'i']
#
# ['regions']
#
# ['i']
#
# ['customer']
#
# ['damn', 'number']
#
# ['customer', 'service']
#
# ['social', 'care', 'team']
#
# ['lack']
#
# ['word', 'horrendous']
#
# ['issue']
#
# ['incompetence']
#
# ['lack']
#
# ['thing', 'i', 'knobanka']
#
# ['banka', 'doesnt', 'care']
#
# ['customers']
#
# ['customer', 'service']
#
# ['i']
#
# ['problem']
#
# ['i']
#
# ['account']
#
# ['banka']
#
# ['agent']
#
# ['i', 'pay']
#
# ['credit', 'card']
#
# ['balance']
#
# ['balance']
#
# ['balance', 'increases']
#
# ['i']
#
# ['i']
#
# ['extra', 'money', 'pay']
#
# ['administration', 'fees']
#
# ['account', 'whats']
#
# ['banka']
#
# ['customer', 'service', 'stinks']
#
# ['love']
#
# ['nice', 'day']
#
# ['help']
#
# ['supervisor', 'i']
#
# ['banka', 'customer']
#
# ['i']
#
# ['looling']
#
# ['new', 'bank']
#
# ['refering']
#
# ['i']
#
# ['nice', 'day']
#
# ['customer', 'service', 'system']
#
# ['frustrating', 'i']
#
# ['times']
#
# ['days']
#
# ['i']
#
# ['credit', 'limit', 'i']
#
# ['real', 'close']
#
# ['answer']
#
# ['call']
#
# ['i']
#
# ['whole', 'time']
#
# ['process']
#
# ['different', 'person']
#
# ['time', 'i']
#
# ['bankc', 'account', 'i']
#
# ['thanks']
#
# ['aggravating', 'service']
#
# ['horrible', 'customer', 'service', 'rep', 'cost']
#
# ['customer']
#
# ['accountcredit', 'cardand']
#
# ['vendor']
#
# ['balances']
#
# ['elses', 'program']
#
# ['bankc', 'cards']
#
# ['i']
#
# ['outsource']
#
# ['issue']
#
# ['bankb']
#
# ['bad', 'customer', 'service']
#
# ['banks', 'banks']
#
# ['charge']
#
# ['fault']
#
# ['new', 'online']
#
# ['transfers']
#
# ['branch']
#
# ['customer', 'service', 'guy']
#
# ['help']
#
# ['i']
#
# ['money']
#
# ['sons', 'banka', 'account']
#
# ['hard', 'transfering']
#
# ['banka', 'account']
#
# ['county', 'customer', 'service', 'center']
#
# ['bankb']
#
# ['youre']
#
# ['years']
#
# ['types']
#
# ['such', 'horrendous', 'customer', 'service']
#
# ['bankc']
#
# ['yup', 'hour']
#
# ['minutes']
#
# ['favor']
#
# ['bank']
#
# ['bankb']
#
# ['reason']
#
# ['local', 'banks']
#
# ['bankes']
#
# ['great', 'interest', 'rates']
#
# ['customer', 'service']
#
# ['customer', 'service']
#
# ['unperson']

# %%
# Look for words that indicate useful replies such as because or due to
df_cs_because = df_cs[df_cs["FullText"].str.contains("because|due to", regex=True)]
for text in df_cs_because["FullText"].iloc[:100]:
    print(text.strip())
    print(nltk.pos_tag(text.strip().split()))
    print()
# Out:
# years ago i went with BankB because of the convenience that it afforded me the multiple locations not only here loBankC anke but banke in addition to just being able to have good customer service all the way around this company has changed so dramatiBankC anke in the last  years that it just makes a person sick by the way i have to past several different banking companies in order to go to a BankB and all of them have drive throughs that arm and daily they also have more convenient hours as those drive thru is operating while i sat in the BankB parking lot for  minutes waiting for the branch to open hopefully if enough people leave your company based on these decisions BankB will return to the way it used to be
# [('years', 'NNS'), ('ago', 'IN'), ('i', 'PRP'), ('went', 'VBD'), ('with', 'IN'), ('BankB', 'NNP'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('convenience', 'NN'), ('that', 'IN'), ('it', 'PRP'), ('afforded', 'VBD'), ('me', 'PRP'), ('the', 'DT'), ('multiple', 'NN'), ('locations', 'NNS'), ('not', 'RB'), ('only', 'RB'), ('here', 'RB'), ('loBankC', 'NNP'), ('anke', 'NN'), ('but', 'CC'), ('banke', 'NN'), ('in', 'IN'), ('addition', 'NN'), ('to', 'TO'), ('just', 'RB'), ('being', 'VBG'), ('able', 'JJ'), ('to', 'TO'), ('have', 'VB'), ('good', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('all', 'DT'), ('the', 'DT'), ('way', 'NN'), ('around', 'IN'), ('this', 'DT'), ('company', 'NN'), ('has', 'VBZ'), ('changed', 'VBN'), ('so', 'RB'), ('dramatiBankC', 'NNP'), ('anke', 'NN'), ('in', 'IN'), ('the', 'DT'), ('last', 'JJ'), ('years', 'NNS'), ('that', 'IN'), ('it', 'PRP'), ('just', 'RB'), ('makes', 'VBZ'), ('a', 'DT'), ('person', 'NN'), ('sick', 'NN'), ('by', 'IN'), ('the', 'DT'), ('way', 'NN'), ('i', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('past', 'JJ'), ('several', 'JJ'), ('different', 'JJ'), ('banking', 'NN'), ('companies', 'NNS'), ('in', 'IN'), ('order', 'NN'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('a', 'DT'), ('BankB', 'NNP'), ('and', 'CC'), ('all', 'DT'), ('of', 'IN'), ('them', 'PRP'), ('have', 'VBP'), ('drive', 'JJ'), ('throughs', 'NNS'), ('that', 'WDT'), ('arm', 'NN'), ('and', 'CC'), ('daily', 'JJ'), ('they', 'PRP'), ('also', 'RB'), ('have', 'VBP'), ('more', 'JJR'), ('convenient', 'JJ'), ('hours', 'NNS'), ('as', 'IN'), ('those', 'DT'), ('drive', 'JJ'), ('thru', 'NN'), ('is', 'VBZ'), ('operating', 'VBG'), ('while', 'IN'), ('i', 'PRP'), ('sat', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('BankB', 'NNP'), ('parking', 'NN'), ('lot', 'NN'), ('for', 'IN'), ('minutes', 'NNS'), ('waiting', 'VBG'), ('for', 'IN'), ('the', 'DT'), ('branch', 'NN'), ('to', 'TO'), ('open', 'VB'), ('hopefully', 'RB'), ('if', 'IN'), ('enough', 'JJ'), ('people', 'NNS'), ('leave', 'VBP'), ('your', 'PRP$'), ('company', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('these', 'DT'), ('decisions', 'NNS'), ('BankB', 'NNP'), ('will', 'MD'), ('return', 'VB'), ('to', 'TO'), ('the', 'DT'), ('way', 'NN'), ('it', 'PRP'), ('used', 'VBD'), ('to', 'TO'), ('be', 'VB')]
#
# a couple weeks ago i open a new BankB account within a few days they closed my account with no notice notification nothing can i have a direct deposit over  there i had the time i realize its closed i went to the bank and speak to the customer service live alone day having a stupid conversation their answer was completely rude and unprofessional and one of the ladies on the phoneoh yeah we send you a letter three days days after we closed your accountwhich i didnt receive yet because this recently just opened an account after waiting a whole week to get paid now i have to wait another week or over to return the payment to the sender and get paid again which would mean late on my bills not going to work because i dont have money for gas during that time looking for a lawyer hopefully will not charge me up front for all the mess BankB put me through
# [('a', 'DT'), ('couple', 'NN'), ('weeks', 'NNS'), ('ago', 'IN'), ('i', 'PRP'), ('open', 'VBP'), ('a', 'DT'), ('new', 'JJ'), ('BankB', 'NNP'), ('account', 'NN'), ('within', 'IN'), ('a', 'DT'), ('few', 'JJ'), ('days', 'NNS'), ('they', 'PRP'), ('closed', 'VBD'), ('my', 'PRP$'), ('account', 'NN'), ('with', 'IN'), ('no', 'DT'), ('notice', 'NN'), ('notification', 'NN'), ('nothing', 'NN'), ('can', 'MD'), ('i', 'VB'), ('have', 'VBP'), ('a', 'DT'), ('direct', 'JJ'), ('deposit', 'NN'), ('over', 'IN'), ('there', 'EX'), ('i', 'PRP'), ('had', 'VBD'), ('the', 'DT'), ('time', 'NN'), ('i', 'PRP'), ('realize', 'VBP'), ('its', 'PRP$'), ('closed', 'VBN'), ('i', 'PRP'), ('went', 'VBD'), ('to', 'TO'), ('the', 'DT'), ('bank', 'NN'), ('and', 'CC'), ('speak', 'VB'), ('to', 'TO'), ('the', 'DT'), ('customer', 'NN'), ('service', 'NN'), ('live', 'VBP'), ('alone', 'RB'), ('day', 'NN'), ('having', 'VBG'), ('a', 'DT'), ('stupid', 'JJ'), ('conversation', 'NN'), ('their', 'PRP$'), ('answer', 'NN'), ('was', 'VBD'), ('completely', 'RB'), ('rude', 'JJ'), ('and', 'CC'), ('unprofessional', 'JJ'), ('and', 'CC'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('ladies', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('phoneoh', 'NN'), ('yeah', 'NN'), ('we', 'PRP'), ('send', 'VBP'), ('you', 'PRP'), ('a', 'DT'), ('letter', 'NN'), ('three', 'CD'), ('days', 'NNS'), ('days', 'NNS'), ('after', 'IN'), ('we', 'PRP'), ('closed', 'VBD'), ('your', 'PRP$'), ('accountwhich', 'NN'), ('i', 'PRP'), ('didnt', 'VBP'), ('receive', 'JJ'), ('yet', 'NN'), ('because', 'IN'), ('this', 'DT'), ('recently', 'RB'), ('just', 'RB'), ('opened', 'VBD'), ('an', 'DT'), ('account', 'NN'), ('after', 'IN'), ('waiting', 'VBG'), ('a', 'DT'), ('whole', 'JJ'), ('week', 'NN'), ('to', 'TO'), ('get', 'VB'), ('paid', 'VBN'), ('now', 'RB'), ('i', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('wait', 'VB'), ('another', 'DT'), ('week', 'NN'), ('or', 'CC'), ('over', 'IN'), ('to', 'TO'), ('return', 'VB'), ('the', 'DT'), ('payment', 'NN'), ('to', 'TO'), ('the', 'DT'), ('sender', 'NN'), ('and', 'CC'), ('get', 'VB'), ('paid', 'VBN'), ('again', 'RB'), ('which', 'WDT'), ('would', 'MD'), ('mean', 'VB'), ('late', 'JJ'), ('on', 'IN'), ('my', 'PRP$'), ('bills', 'NNS'), ('not', 'RB'), ('going', 'VBG'), ('to', 'TO'), ('work', 'VB'), ('because', 'IN'), ('i', 'PRP'), ('dont', 'VBP'), ('have', 'VBP'), ('money', 'NN'), ('for', 'IN'), ('gas', 'NN'), ('during', 'IN'), ('that', 'DT'), ('time', 'NN'), ('looking', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('lawyer', 'NN'), ('hopefully', 'RB'), ('will', 'MD'), ('not', 'RB'), ('charge', 'VB'), ('me', 'PRP'), ('up', 'RP'), ('front', 'JJ'), ('for', 'IN'), ('all', 'DT'), ('the', 'DT'), ('mess', 'NN'), ('BankB', 'NNP'), ('put', 'VBD'), ('me', 'PRP'), ('through', 'IN')]
#
# after i called BankB and could get a person i tried online chat and had to answer a thousand security questions and wait minutes in between responses i wrote them this dear BankB i originbanke tried to call but your automated service would not transfer me to an actual person i am very dissatisfied with BankBs customer service not because of the people who work for you but because of the way you treat your customers like idiots and we should talk to computers and machines all day and go online to solve our problems you make a lot of money why cant you afford to pay real people to help your very real customers no one likes talking to machines no one bankes are doing so much more to satisfy their customers and that includes talking to a real person you may be up now but that can always change if you dont start treating your customers like real people and stop treating us like dollar signs
# [('after', 'IN'), ('i', 'PRP'), ('called', 'VBD'), ('BankB', 'NNP'), ('and', 'CC'), ('could', 'MD'), ('get', 'VB'), ('a', 'DT'), ('person', 'NN'), ('i', 'PRP'), ('tried', 'VBD'), ('online', 'NN'), ('chat', 'IN'), ('and', 'CC'), ('had', 'VBD'), ('to', 'TO'), ('answer', 'VB'), ('a', 'DT'), ('thousand', 'NN'), ('security', 'NN'), ('questions', 'NNS'), ('and', 'CC'), ('wait', 'VB'), ('minutes', 'NNS'), ('in', 'IN'), ('between', 'IN'), ('responses', 'NNS'), ('i', 'PRP'), ('wrote', 'VBD'), ('them', 'PRP'), ('this', 'DT'), ('dear', 'NN'), ('BankB', 'NNP'), ('i', 'PRP'), ('originbanke', 'VBP'), ('tried', 'VBD'), ('to', 'TO'), ('call', 'VB'), ('but', 'CC'), ('your', 'PRP$'), ('automated', 'VBN'), ('service', 'NN'), ('would', 'MD'), ('not', 'RB'), ('transfer', 'VB'), ('me', 'PRP'), ('to', 'TO'), ('an', 'DT'), ('actual', 'JJ'), ('person', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('very', 'RB'), ('dissatisfied', 'VBN'), ('with', 'IN'), ('BankBs', 'NNP'), ('customer', 'NN'), ('service', 'NN'), ('not', 'RB'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('people', 'NNS'), ('who', 'WP'), ('work', 'NN'), ('for', 'IN'), ('you', 'PRP'), ('but', 'CC'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('way', 'NN'), ('you', 'PRP'), ('treat', 'VBD'), ('your', 'PRP$'), ('customers', 'NNS'), ('like', 'IN'), ('idiots', 'NNS'), ('and', 'CC'), ('we', 'PRP'), ('should', 'MD'), ('talk', 'VB'), ('to', 'TO'), ('computers', 'NNS'), ('and', 'CC'), ('machines', 'NNS'), ('all', 'DT'), ('day', 'NN'), ('and', 'CC'), ('go', 'VB'), ('online', 'NN'), ('to', 'TO'), ('solve', 'VB'), ('our', 'PRP$'), ('problems', 'NNS'), ('you', 'PRP'), ('make', 'VBP'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('money', 'NN'), ('why', 'WRB'), ('cant', 'JJ'), ('you', 'PRP'), ('afford', 'VBD'), ('to', 'TO'), ('pay', 'VB'), ('real', 'JJ'), ('people', 'NNS'), ('to', 'TO'), ('help', 'VB'), ('your', 'PRP$'), ('very', 'NN'), ('real', 'JJ'), ('customers', 'NNS'), ('no', 'DT'), ('one', 'NN'), ('likes', 'VBZ'), ('talking', 'VBG'), ('to', 'TO'), ('machines', 'NNS'), ('no', 'DT'), ('one', 'NN'), ('bankes', 'VBZ'), ('are', 'VBP'), ('doing', 'VBG'), ('so', 'RB'), ('much', 'RB'), ('more', 'RBR'), ('to', 'TO'), ('satisfy', 'VB'), ('their', 'PRP$'), ('customers', 'NNS'), ('and', 'CC'), ('that', 'IN'), ('includes', 'NNS'), ('talking', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('real', 'JJ'), ('person', 'NN'), ('you', 'PRP'), ('may', 'MD'), ('be', 'VB'), ('up', 'RP'), ('now', 'RB'), ('but', 'CC'), ('that', 'IN'), ('can', 'MD'), ('always', 'RB'), ('change', 'VB'), ('if', 'IN'), ('you', 'PRP'), ('dont', 'VBP'), ('start', 'NN'), ('treating', 'VBG'), ('your', 'PRP$'), ('customers', 'NNS'), ('like', 'IN'), ('real', 'JJ'), ('people', 'NNS'), ('and', 'CC'), ('stop', 'VB'), ('treating', 'VBG'), ('us', 'PRP'), ('like', 'IN'), ('dollar', 'NN'), ('signs', 'NNS')]
#
# after my dealings with BankC us i have closed my account due to how i was treated by one of your customer service representatives i know bankes will love to have the business BankC had from me
# [('after', 'IN'), ('my', 'PRP$'), ('dealings', 'NNS'), ('with', 'IN'), ('BankC', 'NNP'), ('us', 'PRP'), ('i', 'PRP'), ('have', 'VBP'), ('closed', 'VBN'), ('my', 'PRP$'), ('account', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('how', 'WRB'), ('i', 'PRP'), ('was', 'VBD'), ('treated', 'VBN'), ('by', 'IN'), ('one', 'CD'), ('of', 'IN'), ('your', 'PRP$'), ('customer', 'NN'), ('service', 'NN'), ('representatives', 'NNS'), ('i', 'PRP'), ('know', 'VBP'), ('bankes', 'NNS'), ('will', 'MD'), ('love', 'VB'), ('to', 'TO'), ('have', 'VB'), ('the', 'DT'), ('business', 'NN'), ('BankC', 'NNP'), ('had', 'VBD'), ('from', 'IN'), ('me', 'PRP')]
#
# an associate with BankB technical support Name just hung up on me because she apparently couldnt answer my question where is your customer service
# [('an', 'DT'), ('associate', 'NN'), ('with', 'IN'), ('BankB', 'NNP'), ('technical', 'JJ'), ('support', 'NN'), ('Name', 'NNP'), ('just', 'RB'), ('hung', 'JJ'), ('up', 'RP'), ('on', 'IN'), ('me', 'PRP'), ('because', 'IN'), ('she', 'PRP'), ('apparently', 'RB'), ('couldnt', 'JJ'), ('answer', 'NN'), ('my', 'PRP$'), ('question', 'NN'), ('where', 'WRB'), ('is', 'VBZ'), ('your', 'PRP$'), ('customer', 'NN'), ('service', 'NN')]
#
# another reason BankB is the worse bank in america charging me  convenience fee to cash a check from one of their account because i dont have an account with them even the manager would not waive the fee instead he asked if i cared to open an account with them extremely horrible customer service
# [('another', 'DT'), ('reason', 'NN'), ('BankB', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('worse', 'NN'), ('bank', 'NN'), ('in', 'IN'), ('america', 'NN'), ('charging', 'VBG'), ('me', 'PRP'), ('convenience', 'NN'), ('fee', 'NN'), ('to', 'TO'), ('cash', 'NN'), ('a', 'DT'), ('check', 'NN'), ('from', 'IN'), ('one', 'CD'), ('of', 'IN'), ('their', 'PRP$'), ('account', 'NN'), ('because', 'IN'), ('i', 'PRP'), ('dont', 'VBP'), ('have', 'VBP'), ('an', 'DT'), ('account', 'NN'), ('with', 'IN'), ('them', 'PRP'), ('even', 'RB'), ('the', 'DT'), ('manager', 'NN'), ('would', 'MD'), ('not', 'RB'), ('waive', 'VB'), ('the', 'DT'), ('fee', 'NN'), ('instead', 'RB'), ('he', 'PRP'), ('asked', 'VBD'), ('if', 'IN'), ('i', 'PRP'), ('cared', 'VBD'), ('to', 'TO'), ('open', 'VB'), ('an', 'DT'), ('account', 'NN'), ('with', 'IN'), ('them', 'PRP'), ('extremely', 'RB'), ('horrible', 'JJ'), ('customer', 'NN'), ('service', 'NN')]
#
# BankB college branch in california has the worst customer service its not the tellers fault or should i say teller only  window open   other people in the office i only use this branch because its close to where i work you would think a busy area like this you would have more tellers available try to force everyone to use atm machine or bank online Name sick and tired of this
# [('BankB', 'NNP'), ('college', 'NN'), ('branch', 'NN'), ('in', 'IN'), ('california', 'NN'), ('has', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('customer', 'NN'), ('service', 'NN'), ('its', 'PRP$'), ('not', 'RB'), ('the', 'DT'), ('tellers', 'NNS'), ('fault', 'VBP'), ('or', 'CC'), ('should', 'MD'), ('i', 'VB'), ('say', 'VB'), ('teller', 'JJR'), ('only', 'RB'), ('window', 'VBP'), ('open', 'JJ'), ('other', 'JJ'), ('people', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('office', 'NN'), ('i', 'PRP'), ('only', 'RB'), ('use', 'VBP'), ('this', 'DT'), ('branch', 'NN'), ('because', 'IN'), ('its', 'PRP$'), ('close', 'NN'), ('to', 'TO'), ('where', 'WRB'), ('i', 'PRP'), ('work', 'VBP'), ('you', 'PRP'), ('would', 'MD'), ('think', 'VB'), ('a', 'DT'), ('busy', 'NN'), ('area', 'NN'), ('like', 'IN'), ('this', 'DT'), ('you', 'PRP'), ('would', 'MD'), ('have', 'VB'), ('more', 'JJR'), ('tellers', 'NNS'), ('available', 'JJ'), ('try', 'NN'), ('to', 'TO'), ('force', 'VB'), ('everyone', 'NN'), ('to', 'TO'), ('use', 'VB'), ('atm', 'NN'), ('machine', 'NN'), ('or', 'CC'), ('bank', 'NN'), ('online', 'NN'), ('Name', 'NNP'), ('sick', 'NN'), ('and', 'CC'), ('tired', 'VBD'), ('of', 'IN'), ('this', 'DT')]
#
# BankB customer service sucks week of thanksgiving and my bank calls for funds availability and BankB is the only bank who will not help thanks a lot Name glad i am with Name because they are a customer oriented bank
# [('BankB', 'NNP'), ('customer', 'NN'), ('service', 'NN'), ('sucks', 'NNS'), ('week', 'VBP'), ('of', 'IN'), ('thanksgiving', 'VBG'), ('and', 'CC'), ('my', 'PRP$'), ('bank', 'NN'), ('calls', 'NNS'), ('for', 'IN'), ('funds', 'NNS'), ('availability', 'NN'), ('and', 'CC'), ('BankB', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('only', 'JJ'), ('bank', 'NN'), ('who', 'WP'), ('will', 'MD'), ('not', 'RB'), ('help', 'VB'), ('thanks', 'NNS'), ('a', 'DT'), ('lot', 'NN'), ('Name', 'NNP'), ('glad', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('with', 'IN'), ('Name', 'NNP'), ('because', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ('a', 'DT'), ('customer', 'NN'), ('oriented', 'VBN'), ('bank', 'NN')]
#
# BankB has the worst customer service ever they will take your money and not post it to your account and tell you that is your problem they will cancel you account due to a security breach and then all of your regular postings will not work i have spent hours trying to fix this problem and i still have no satisfaction all i have asked for is a  gift card compensation for my time they cant do this i m done with BankBn   years as a customer i am done
# [('BankB', 'NNP'), ('has', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('customer', 'NN'), ('service', 'NN'), ('ever', 'RB'), ('they', 'PRP'), ('will', 'MD'), ('take', 'VB'), ('your', 'PRP$'), ('money', 'NN'), ('and', 'CC'), ('not', 'RB'), ('post', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('your', 'PRP$'), ('account', 'NN'), ('and', 'CC'), ('tell', 'NN'), ('you', 'PRP'), ('that', 'IN'), ('is', 'VBZ'), ('your', 'PRP$'), ('problem', 'NN'), ('they', 'PRP'), ('will', 'MD'), ('cancel', 'VB'), ('you', 'PRP'), ('account', 'VBP'), ('due', 'JJ'), ('to', 'TO'), ('a', 'DT'), ('security', 'NN'), ('breach', 'NN'), ('and', 'CC'), ('then', 'RB'), ('all', 'DT'), ('of', 'IN'), ('your', 'PRP$'), ('regular', 'JJ'), ('postings', 'NNS'), ('will', 'MD'), ('not', 'RB'), ('work', 'VB'), ('i', 'PRP'), ('have', 'VBP'), ('spent', 'VBN'), ('hours', 'NNS'), ('trying', 'VBG'), ('to', 'TO'), ('fix', 'VB'), ('this', 'DT'), ('problem', 'NN'), ('and', 'CC'), ('i', 'PRP'), ('still', 'RB'), ('have', 'VBP'), ('no', 'DT'), ('satisfaction', 'NN'), ('all', 'DT'), ('i', 'PRP'), ('have', 'VBP'), ('asked', 'VBN'), ('for', 'IN'), ('is', 'VBZ'), ('a', 'DT'), ('gift', 'NN'), ('card', 'NN'), ('compensation', 'NN'), ('for', 'IN'), ('my', 'PRP$'), ('time', 'NN'), ('they', 'PRP'), ('cant', 'VBP'), ('do', 'VBP'), ('this', 'DT'), ('i', 'PRP'), ('m', 'VBP'), ('done', 'NN'), ('with', 'IN'), ('BankBn', 'NNP'), ('years', 'NNS'), ('as', 'IN'), ('a', 'DT'), ('customer', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('done', 'NN')]
#
# BankB is the worst bank i have ever been with i just got a phone call at am saying my debit card is locked the problem here besides the obvious calling me at am is the fact that in september i went into one of your branches and closed my account and the consultant took my debit card a month later i got another statement saying my account was overdrawn i called your customer service and they assured me my account would be closed and they even sent me a cashiers check for a balance that was remaining why Name i getting phone calls about a bank account i closed  months ago you need to fix this and fix it now if my credit gets messed up because of this BankB will have a law suit on their hands you people rebanke need to learn some customer service
# [('BankB', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('bank', 'NN'), ('i', 'PRP'), ('have', 'VBP'), ('ever', 'RB'), ('been', 'VBN'), ('with', 'IN'), ('i', 'PRP'), ('just', 'RB'), ('got', 'VBD'), ('a', 'DT'), ('phone', 'NN'), ('call', 'NN'), ('at', 'IN'), ('am', 'NN'), ('saying', 'VBG'), ('my', 'PRP$'), ('debit', 'NN'), ('card', 'NN'), ('is', 'VBZ'), ('locked', 'VBN'), ('the', 'DT'), ('problem', 'NN'), ('here', 'RB'), ('besides', 'VBZ'), ('the', 'DT'), ('obvious', 'JJ'), ('calling', 'NN'), ('me', 'PRP'), ('at', 'IN'), ('am', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('fact', 'NN'), ('that', 'IN'), ('in', 'IN'), ('september', 'NN'), ('i', 'PRP'), ('went', 'VBD'), ('into', 'IN'), ('one', 'CD'), ('of', 'IN'), ('your', 'PRP$'), ('branches', 'NNS'), ('and', 'CC'), ('closed', 'VBD'), ('my', 'PRP$'), ('account', 'NN'), ('and', 'CC'), ('the', 'DT'), ('consultant', 'NN'), ('took', 'VBD'), ('my', 'PRP$'), ('debit', 'NN'), ('card', 'NN'), ('a', 'DT'), ('month', 'NN'), ('later', 'JJ'), ('i', 'PRP'), ('got', 'VBD'), ('another', 'DT'), ('statement', 'NN'), ('saying', 'VBG'), ('my', 'PRP$'), ('account', 'NN'), ('was', 'VBD'), ('overdrawn', 'VBN'), ('i', 'PRP'), ('called', 'VBN'), ('your', 'PRP$'), ('customer', 'NN'), ('service', 'NN'), ('and', 'CC'), ('they', 'PRP'), ('assured', 'VBD'), ('me', 'PRP'), ('my', 'PRP$'), ('account', 'NN'), ('would', 'MD'), ('be', 'VB'), ('closed', 'VBN'), ('and', 'CC'), ('they', 'PRP'), ('even', 'RB'), ('sent', 'VBN'), ('me', 'PRP'), ('a', 'DT'), ('cashiers', 'NNS'), ('check', 'VBP'), ('for', 'IN'), ('a', 'DT'), ('balance', 'NN'), ('that', 'WDT'), ('was', 'VBD'), ('remaining', 'VBG'), ('why', 'WRB'), ('Name', 'NNP'), ('i', 'PRP'), ('getting', 'VBG'), ('phone', 'NN'), ('calls', 'NNS'), ('about', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('account', 'NN'), ('i', 'PRP'), ('closed', 'VBD'), ('months', 'NNS'), ('ago', 'RB'), ('you', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('fix', 'VB'), ('this', 'DT'), ('and', 'CC'), ('fix', 'CD'), ('it', 'PRP'), ('now', 'RB'), ('if', 'IN'), ('my', 'PRP$'), ('credit', 'NN'), ('gets', 'NNS'), ('messed', 'VBN'), ('up', 'RP'), ('because', 'IN'), ('of', 'IN'), ('this', 'DT'), ('BankB', 'NNP'), ('will', 'MD'), ('have', 'VB'), ('a', 'DT'), ('law', 'NN'), ('suit', 'NN'), ('on', 'IN'), ('their', 'PRP$'), ('hands', 'NNS'), ('you', 'PRP'), ('people', 'NNS'), ('rebanke', 'VBP'), ('need', 'VBP'), ('to', 'TO'), ('learn', 'VB'), ('some', 'DT'), ('customer', 'NN'), ('service', 'NN')]
#
# BankB is the worst customer service in bakersfield california massive line out the door on the st of month and have  tellers hate this bank no i dont have an account because u suck
# [('BankB', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('customer', 'NN'), ('service', 'NN'), ('in', 'IN'), ('bakersfield', 'NN'), ('california', 'NN'), ('massive', 'NN'), ('line', 'NN'), ('out', 'IN'), ('the', 'DT'), ('door', 'NN'), ('on', 'IN'), ('the', 'DT'), ('st', 'NN'), ('of', 'IN'), ('month', 'NN'), ('and', 'CC'), ('have', 'VB'), ('tellers', 'NNS'), ('hate', 'VB'), ('this', 'DT'), ('bank', 'NN'), ('no', 'DT'), ('i', 'PRP'), ('dont', 'VBP'), ('have', 'VBP'), ('an', 'DT'), ('account', 'NN'), ('because', 'IN'), ('u', 'NN'), ('suck', 'NN')]
#
# BankB is the worst i am closing my account because they charge you a fortune for every little thing and have some of the worst customer service reps i have ever encountered i am so done with this bank and would never ever recommend anyone use their services i will be posting on twitter and other social media sites to ensure no one else gets caught up in their Name
# [('BankB', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('i', 'PRP'), ('am', 'VBP'), ('closing', 'VBG'), ('my', 'PRP$'), ('account', 'NN'), ('because', 'IN'), ('they', 'PRP'), ('charge', 'VBP'), ('you', 'PRP'), ('a', 'DT'), ('fortune', 'NN'), ('for', 'IN'), ('every', 'DT'), ('little', 'JJ'), ('thing', 'NN'), ('and', 'CC'), ('have', 'VB'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('worst', 'JJS'), ('customer', 'NN'), ('service', 'NN'), ('reps', 'NNS'), ('i', 'PRP'), ('have', 'VBP'), ('ever', 'RB'), ('encountered', 'VBN'), ('i', 'PRP'), ('am', 'VBP'), ('so', 'RB'), ('done', 'VBN'), ('with', 'IN'), ('this', 'DT'), ('bank', 'NN'), ('and', 'CC'), ('would', 'MD'), ('never', 'RB'), ('ever', 'RB'), ('recommend', 'VBP'), ('anyone', 'NN'), ('use', 'NN'), ('their', 'PRP$'), ('services', 'NNS'), ('i', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('posting', 'VBG'), ('on', 'IN'), ('twitter', 'NN'), ('and', 'CC'), ('other', 'JJ'), ('social', 'JJ'), ('media', 'NNS'), ('sites', 'VBZ'), ('to', 'TO'), ('ensure', 'VB'), ('no', 'DT'), ('one', 'NN'), ('else', 'NN'), ('gets', 'VBZ'), ('caught', 'VBN'), ('up', 'RP'), ('in', 'IN'), ('their', 'PRP$'), ('Name', 'NNP')]
#
# BankB sucks because they transferred  a week to one person for  year i call to the customer services they dont know nothing now Name closing my account
# [('BankB', 'NNP'), ('sucks', 'NNS'), ('because', 'IN'), ('they', 'PRP'), ('transferred', 'VBD'), ('a', 'DT'), ('week', 'NN'), ('to', 'TO'), ('one', 'CD'), ('person', 'NN'), ('for', 'IN'), ('year', 'NN'), ('i', 'PRP'), ('call', 'VBP'), ('to', 'TO'), ('the', 'DT'), ('customer', 'NN'), ('services', 'NNS'), ('they', 'PRP'), ('dont', 'VBP'), ('know', 'VBP'), ('nothing', 'NN'), ('now', 'RB'), ('Name', 'NNP'), ('closing', 'NN'), ('my', 'PRP$'), ('account', 'NN')]
#
# BankB u suck card was cutoff due to fraud needed to go to a branch to get a temp card but needed an appointment branches booked had to drive around to find a branch actubanke want to help me seriously thinking moving to a new bank no canned responses needed thank you customer service is truly dead
# [('BankB', 'NNP'), ('u', 'VBD'), ('suck', 'NN'), ('card', 'NN'), ('was', 'VBD'), ('cutoff', 'IN'), ('due', 'JJ'), ('to', 'TO'), ('fraud', 'VB'), ('needed', 'VBN'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('a', 'DT'), ('branch', 'NN'), ('to', 'TO'), ('get', 'VB'), ('a', 'DT'), ('temp', 'NN'), ('card', 'NN'), ('but', 'CC'), ('needed', 'VBN'), ('an', 'DT'), ('appointment', 'NN'), ('branches', 'VBZ'), ('booked', 'VBN'), ('had', 'VBD'), ('to', 'TO'), ('drive', 'VB'), ('around', 'IN'), ('to', 'TO'), ('find', 'VB'), ('a', 'DT'), ('branch', 'NN'), ('actubanke', 'NN'), ('want', 'NN'), ('to', 'TO'), ('help', 'VB'), ('me', 'PRP'), ('seriously', 'RB'), ('thinking', 'VBG'), ('moving', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('new', 'JJ'), ('bank', 'NN'), ('no', 'DT'), ('canned', 'VBN'), ('responses', 'NNS'), ('needed', 'VBN'), ('thank', 'NN'), ('you', 'PRP'), ('customer', 'NN'), ('service', 'NN'), ('is', 'VBZ'), ('truly', 'RB'), ('dead', 'JJ')]
#
# BankB where do i start since your customer service reps cant answer my questions since you lock my account all the time because i bought a pack of cigarettes at a gas station now my account is completely frozen cant access it i have bills to pay i have paychecks to deposit yes that plural thats how long this has been im going to miss a payment on my snap on tools loan tomorrow so there goes my credit this is unfair i want answers
# [('BankB', 'NNP'), ('where', 'WRB'), ('do', 'VBP'), ('i', 'PRP'), ('start', 'VB'), ('since', 'IN'), ('your', 'PRP$'), ('customer', 'NN'), ('service', 'NN'), ('reps', 'NNS'), ('cant', 'VBP'), ('answer', 'JJR'), ('my', 'PRP$'), ('questions', 'NNS'), ('since', 'IN'), ('you', 'PRP'), ('lock', 'VBP'), ('my', 'PRP$'), ('account', 'NN'), ('all', 'DT'), ('the', 'DT'), ('time', 'NN'), ('because', 'IN'), ('i', 'PRP'), ('bought', 'VBD'), ('a', 'DT'), ('pack', 'NN'), ('of', 'IN'), ('cigarettes', 'NNS'), ('at', 'IN'), ('a', 'DT'), ('gas', 'NN'), ('station', 'NN'), ('now', 'RB'), ('my', 'PRP$'), ('account', 'NN'), ('is', 'VBZ'), ('completely', 'RB'), ('frozen', 'VBN'), ('cant', 'JJ'), ('access', 'NN'), ('it', 'PRP'), ('i', 'PRP'), ('have', 'VBP'), ('bills', 'NNS'), ('to', 'TO'), ('pay', 'VB'), ('i', 'PRP'), ('have', 'VBP'), ('paychecks', 'NNS'), ('to', 'TO'), ('deposit', 'VB'), ('yes', 'NNS'), ('that', 'WDT'), ('plural', 'JJ'), ('thats', 'NNS'), ('how', 'WRB'), ('long', 'JJ'), ('this', 'DT'), ('has', 'VBZ'), ('been', 'VBN'), ('im', 'JJ'), ('going', 'NN'), ('to', 'TO'), ('miss', 'NNS'), ('a', 'DT'), ('payment', 'NN'), ('on', 'IN'), ('my', 'PRP$'), ('snap', 'NN'), ('on', 'IN'), ('tools', 'NNS'), ('loan', 'NN'), ('tomorrow', 'NN'), ('so', 'RB'), ('there', 'RB'), ('goes', 'VBZ'), ('my', 'PRP$'), ('credit', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('unfair', 'JJ'), ('i', 'NN'), ('want', 'VBP'), ('answers', 'NNS')]
#
# BankB is such a joke when you pay your credit card online it doesnt tell you it was played so it went through  times now i have a negative  balance i tried calling all weekend and nobody answers now Name at work and finbanke got through but now they want my checking a count routing number to credit me BankB  if you answered the Name phone when i was home i would have had the info why do you allow overpayment to a card then expect your customers to carry around routing info from their checks while at work because you are to cheep to hire customer service reps because you ripped off people and got sued for billions pay up crooks
# [('BankB', 'NNP'), ('is', 'VBZ'), ('such', 'JJ'), ('a', 'DT'), ('joke', 'NN'), ('when', 'WRB'), ('you', 'PRP'), ('pay', 'VBP'), ('your', 'PRP$'), ('credit', 'NN'), ('card', 'NN'), ('online', 'NN'), ('it', 'PRP'), ('doesnt', 'VBD'), ('tell', 'RB'), ('you', 'PRP'), ('it', 'PRP'), ('was', 'VBD'), ('played', 'VBN'), ('so', 'RB'), ('it', 'PRP'), ('went', 'VBD'), ('through', 'IN'), ('times', 'NNS'), ('now', 'RB'), ('i', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('negative', 'JJ'), ('balance', 'NN'), ('i', 'PRP'), ('tried', 'VBD'), ('calling', 'VBG'), ('all', 'DT'), ('weekend', 'NN'), ('and', 'CC'), ('nobody', 'NN'), ('answers', 'NNS'), ('now', 'RB'), ('Name', 'NNP'), ('at', 'IN'), ('work', 'NN'), ('and', 'CC'), ('finbanke', 'VB'), ('got', 'VBD'), ('through', 'IN'), ('but', 'CC'), ('now', 'RB'), ('they', 'PRP'), ('want', 'VBP'), ('my', 'PRP$'), ('checking', 'NN'), ('a', 'DT'), ('count', 'NN'), ('routing', 'VBG'), ('number', 'NN'), ('to', 'TO'), ('credit', 'NN'), ('me', 'PRP'), ('BankB', 'NNP'), ('if', 'IN'), ('you', 'PRP'), ('answered', 'VBD'), ('the', 'DT'), ('Name', 'NNP'), ('phone', 'NN'), ('when', 'WRB'), ('i', 'PRP'), ('was', 'VBD'), ('home', 'RB'), ('i', 'PRP'), ('would', 'MD'), ('have', 'VB'), ('had', 'VBD'), ('the', 'DT'), ('info', 'NN'), ('why', 'WRB'), ('do', 'VBP'), ('you', 'PRP'), ('allow', 'VB'), ('overpayment', 'JJ'), ('to', 'TO'), ('a', 'DT'), ('card', 'NN'), ('then', 'RB'), ('expect', 'VBP'), ('your', 'PRP$'), ('customers', 'NNS'), ('to', 'TO'), ('carry', 'VB'), ('around', 'IN'), ('routing', 'VBG'), ('info', 'NN'), ('from', 'IN'), ('their', 'PRP$'), ('checks', 'NNS'), ('while', 'IN'), ('at', 'IN'), ('work', 'NN'), ('because', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('to', 'TO'), ('cheep', 'VB'), ('to', 'TO'), ('hire', 'VB'), ('customer', 'NN'), ('service', 'NN'), ('reps', 'NNS'), ('because', 'IN'), ('you', 'PRP'), ('ripped', 'VBD'), ('off', 'RP'), ('people', 'NNS'), ('and', 'CC'), ('got', 'VBD'), ('sued', 'VBN'), ('for', 'IN'), ('billions', 'NNS'), ('pay', 'VBP'), ('up', 'RP'), ('crooks', 'NNS')]
#
# basiBankC anke you cant because BankA customer service is extremely misinformed im dealing with the same issues myself
# [('basiBankC', 'NNP'), ('anke', 'VBP'), ('you', 'PRP'), ('cant', 'VBP'), ('because', 'IN'), ('BankA', 'NNP'), ('customer', 'NN'), ('service', 'NN'), ('is', 'VBZ'), ('extremely', 'RB'), ('misinformed', 'VBN'), ('im', 'NN'), ('dealing', 'VBG'), ('with', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('issues', 'NNS'), ('myself', 'PRP')]
#
# because this is literbanke the worst bankive ever had to deal with in my life not only did i call customer service to be placed on hold to be placed on hold again then to be hung up on then to have to call BankB  then to be told i dont rebanke get my money for maybe  to  hours this is extremely unacceptable for a bank to do to people considering its their money not the banks money i hope anybody that is banking with BankC will reconsider banking with them now and maybe they should start thinking with somebody else i honestly bank with BankD bank and havent had issues with them taking my money and not giving it to me thanks BankC for being the worst customer care center Name ever dealt with
# [('because', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('literbanke', 'NN'), ('the', 'DT'), ('worst', 'JJS'), ('bankive', 'JJ'), ('ever', 'RB'), ('had', 'VBD'), ('to', 'TO'), ('deal', 'VB'), ('with', 'IN'), ('in', 'IN'), ('my', 'PRP$'), ('life', 'NN'), ('not', 'RB'), ('only', 'RB'), ('did', 'VBD'), ('i', 'PRP'), ('call', 'VBP'), ('customer', 'NN'), ('service', 'NN'), ('to', 'TO'), ('be', 'VB'), ('placed', 'VBN'), ('on', 'IN'), ('hold', 'JJ'), ('to', 'TO'), ('be', 'VB'), ('placed', 'VBN'), ('on', 'IN'), ('hold', 'JJ'), ('again', 'NN'), ('then', 'RB'), ('to', 'TO'), ('be', 'VB'), ('hung', 'VBN'), ('up', 'RP'), ('on', 'IN'), ('then', 'RB'), ('to', 'TO'), ('have', 'VB'), ('to', 'TO'), ('call', 'VB'), ('BankB', 'NNP'), ('then', 'RB'), ('to', 'TO'), ('be', 'VB'), ('told', 'VBN'), ('i', 'PRP'), ('dont', 'VBP'), ('rebanke', 'JJ'), ('get', 'NN'), ('my', 'PRP$'), ('money', 'NN'), ('for', 'IN'), ('maybe', 'RB'), ('to', 'TO'), ('hours', 'NNS'), ('this', 'DT'), ('is', 'VBZ'), ('extremely', 'RB'), ('unacceptable', 'JJ'), ('for', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('to', 'TO'), ('do', 'VB'), ('to', 'TO'), ('people', 'VB'), ('considering', 'JJ'), ('its', 'PRP$'), ('their', 'PRP$'), ('money', 'NN'), ('not', 'RB'), ('the', 'DT'), ('banks', 'NNS'), ('money', 'NN'), ('i', 'PRP'), ('hope', 'VBP'), ('anybody', 'NN'), ('that', 'IN'), ('is', 'VBZ'), ('banking', 'VBG'), ('with', 'IN'), ('BankC', 'NNP'), ('will', 'MD'), ('reconsider', 'VB'), ('banking', 'NN'), ('with', 'IN'), ('them', 'PRP'), ('now', 'RB'), ('and', 'CC'), ('maybe', 'VB'), ('they', 'PRP'), ('should', 'MD'), ('start', 'VB'), ('thinking', 'VBG'), ('with', 'IN'), ('somebody', 'NN'), ('else', 'RB'), ('i', 'PRP'), ('honestly', 'RB'), ('bank', 'VBP'), ('with', 'IN'), ('BankD', 'NNP'), ('bank', 'NN'), ('and', 'CC'), ('havent', 'NN'), ('had', 'VBD'), ('issues', 'NNS'), ('with', 'IN'), ('them', 'PRP'), ('taking', 'VBG'), ('my', 'PRP$'), ('money', 'NN'), ('and', 'CC'), ('not', 'RB'), ('giving', 'VBG'), ('it', 'PRP'), ('to', 'TO'), ('me', 'PRP'), ('thanks', 'VBZ'), ('BankC', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('the', 'DT'), ('worst', 'JJS'), ('customer', 'NN'), ('care', 'NN'), ('center', 'NN'), ('Name', 'NNP'), ('ever', 'RB'), ('dealt', 'VBD'), ('with', 'IN')]
#
# been waiting at the bank for over  minutes to get a simple print out because for the new year they BankB cut staff by over half and are telling people to use the atm for everything f this you cannot do everything through an atm only  teller per branch and one person at a desk i call Name customer service for s t
# [('been', 'VBN'), ('waiting', 'VBG'), ('at', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('for', 'IN'), ('over', 'IN'), ('minutes', 'NNS'), ('to', 'TO'), ('get', 'VB'), ('a', 'DT'), ('simple', 'JJ'), ('print', 'NN'), ('out', 'IN'), ('because', 'IN'), ('for', 'IN'), ('the', 'DT'), ('new', 'JJ'), ('year', 'NN'), ('they', 'PRP'), ('BankB', 'NNP'), ('cut', 'VBD'), ('staff', 'NN'), ('by', 'IN'), ('over', 'IN'), ('half', 'DT'), ('and', 'CC'), ('are', 'VBP'), ('telling', 'VBG'), ('people', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('the', 'DT'), ('atm', 'NN'), ('for', 'IN'), ('everything', 'NN'), ('f', 'NN'), ('this', 'DT'), ('you', 'PRP'), ('cannot', 'VBD'), ('do', 'VBP'), ('everything', 'NN'), ('through', 'IN'), ('an', 'DT'), ('atm', 'NN'), ('only', 'RB'), ('teller', 'JJR'), ('per', 'IN'), ('branch', 'NN'), ('and', 'CC'), ('one', 'CD'), ('person', 'NN'), ('at', 'IN'), ('a', 'DT'), ('desk', 'NN'), ('i', 'PRP'), ('call', 'VBP'), ('Name', 'NNP'), ('customer', 'NN'), ('service', 'NN'), ('for', 'IN'), ('s', 'NNS'), ('t', 'VBP')]
#
# been with BankA for  years when it was Name bank got the absolutely worse possible customer service possible customer service by phone today possible i couldnt go in to a branch because Name on bed rest a few more days it was pitiful when you do good i praise when you do crappy i will sing it loud get better help or at least let the crap in the call center go home so customes dont have to deal with them Name rather be on hold for  minutes waiting on good help than  work with an idiot like today Name Name summed up my experience with BankA today good grief
# [('been', 'VBN'), ('with', 'IN'), ('BankA', 'NNP'), ('for', 'IN'), ('years', 'NNS'), ('when', 'WRB'), ('it', 'PRP'), ('was', 'VBD'), ('Name', 'NNP'), ('bank', 'NN'), ('got', 'VBD'), ('the', 'DT'), ('absolutely', 'RB'), ('worse', 'JJR'), ('possible', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('possible', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('by', 'IN'), ('phone', 'NN'), ('today', 'NN'), ('possible', 'JJ'), ('i', 'PRP'), ('couldnt', 'VBP'), ('go', 'RB'), ('in', 'IN'), ('to', 'TO'), ('a', 'DT'), ('branch', 'NN'), ('because', 'IN'), ('Name', 'NNP'), ('on', 'IN'), ('bed', 'VBN'), ('rest', 'NN'), ('a', 'DT'), ('few', 'JJ'), ('more', 'RBR'), ('days', 'NNS'), ('it', 'PRP'), ('was', 'VBD'), ('pitiful', 'JJ'), ('when', 'WRB'), ('you', 'PRP'), ('do', 'VBP'), ('good', 'JJ'), ('i', 'PRP'), ('praise', 'VBP'), ('when', 'WRB'), ('you', 'PRP'), ('do', 'VBP'), ('crappy', 'JJ'), ('i', 'PRP'), ('will', 'MD'), ('sing', 'VB'), ('it', 'PRP'), ('loud', 'VB'), ('get', 'NN'), ('better', 'RBR'), ('help', 'NN'), ('or', 'CC'), ('at', 'IN'), ('least', 'JJS'), ('let', 'VB'), ('the', 'DT'), ('crap', 'NN'), ('in', 'IN'), ('the', 'DT'), ('call', 'NN'), ('center', 'NN'), ('go', 'NN'), ('home', 'NN'), ('so', 'RB'), ('customes', 'VBZ'), ('dont', 'NN'), ('have', 'VBP'), ('to', 'TO'), ('deal', 'VB'), ('with', 'IN'), ('them', 'PRP'), ('Name', 'NNP'), ('rather', 'RB'), ('be', 'VB'), ('on', 'IN'), ('hold', 'NN'), ('for', 'IN'), ('minutes', 'NNS'), ('waiting', 'VBG'), ('on', 'IN'), ('good', 'JJ'), ('help', 'NN'), ('than', 'IN'), ('work', 'NN'), ('with', 'IN'), ('an', 'DT'), ('idiot', 'NN'), ('like', 'IN'), ('today', 'NN'), ('Name', 'NNP'), ('Name', 'NNP'), ('summed', 'VBD'), ('up', 'RP'), ('my', 'PRP$'), ('experience', 'NN'), ('with', 'IN'), ('BankA', 'NNP'), ('today', 'NN'), ('good', 'VBD'), ('grief', 'NN')]
#
# beware of BankBs fees someone deposited money to my account from a teller and i was charged  because it involved a human then i had to pay another  to transfer the money out of my BankB account Name  i called to complaint and was told its not personal you bet its personal and its poor customer service service since i have been a loyal customer BankB sucks
# [('beware', 'NN'), ('of', 'IN'), ('BankBs', 'NNP'), ('fees', 'NNS'), ('someone', 'NN'), ('deposited', 'VBD'), ('money', 'NN'), ('to', 'TO'), ('my', 'PRP$'), ('account', 'NN'), ('from', 'IN'), ('a', 'DT'), ('teller', 'NN'), ('and', 'CC'), ('i', 'PRP'), ('was', 'VBD'), ('charged', 'VBN'), ('because', 'IN'), ('it', 'PRP'), ('involved', 'VBD'), ('a', 'DT'), ('human', 'JJ'), ('then', 'RB'), ('i', 'PRP'), ('had', 'VBD'), ('to', 'TO'), ('pay', 'VB'), ('another', 'DT'), ('to', 'TO'), ('transfer', 'VB'), ('the', 'DT'), ('money', 'NN'), ('out', 'IN'), ('of', 'IN'), ('my', 'PRP$'), ('BankB', 'NNP'), ('account', 'NN'), ('Name', 'NNP'), ('i', 'PRP'), ('called', 'VBD'), ('to', 'TO'), ('complaint', 'VB'), ('and', 'CC'), ('was', 'VBD'), ('told', 'VBN'), ('its', 'PRP$'), ('not', 'RB'), ('personal', 'JJ'), ('you', 'PRP'), ('bet', 'VBP'), ('its', 'PRP$'), ('personal', 'JJ'), ('and', 'CC'), ('its', 'PRP$'), ('poor', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('service', 'NN'), ('since', 'IN'), ('i', 'PRP'), ('have', 'VBP'), ('been', 'VBN'), ('a', 'DT'), ('loyal', 'JJ'), ('customer', 'NN'), ('BankB', 'NNP'), ('sucks', 'NNS')]
#
# business owner friends Name do you bank with do you use a credit card machine pros cons i am having a terrible time with my banks Name switching from BankA because my credit card processing fees were astronomical so i switched to BankD and they wont deposit my money until tomorroBankA rom last thursday i spoke with their advanced customer service specialist and they offered me no options i need a real bank that cares about their customers
# [('business', 'NN'), ('owner', 'NN'), ('friends', 'NNS'), ('Name', 'NNP'), ('do', 'VBP'), ('you', 'PRP'), ('bank', 'VB'), ('with', 'IN'), ('do', 'VB'), ('you', 'PRP'), ('use', 'VB'), ('a', 'DT'), ('credit', 'NN'), ('card', 'NN'), ('machine', 'NN'), ('pros', 'NNS'), ('cons', 'NNS'), ('i', 'PRP'), ('am', 'VBP'), ('having', 'VBG'), ('a', 'DT'), ('terrible', 'JJ'), ('time', 'NN'), ('with', 'IN'), ('my', 'PRP$'), ('banks', 'NNS'), ('Name', 'NNP'), ('switching', 'NN'), ('from', 'IN'), ('BankA', 'NNP'), ('because', 'IN'), ('my', 'PRP$'), ('credit', 'NN'), ('card', 'NN'), ('processing', 'NN'), ('fees', 'NNS'), ('were', 'VBD'), ('astronomical', 'JJ'), ('so', 'RB'), ('i', 'PRP'), ('switched', 'VBD'), ('to', 'TO'), ('BankD', 'NNP'), ('and', 'CC'), ('they', 'PRP'), ('wont', 'VBP'), ('deposit', 'NN'), ('my', 'PRP$'), ('money', 'NN'), ('until', 'IN'), ('tomorroBankA', 'NNP'), ('rom', 'IN'), ('last', 'JJ'), ('thursday', 'NN'), ('i', 'PRP'), ('spoke', 'VBP'), ('with', 'IN'), ('their', 'PRP$'), ('advanced', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('specialist', 'NN'), ('and', 'CC'), ('they', 'PRP'), ('offered', 'VBD'), ('me', 'PRP'), ('no', 'DT'), ('options', 'NNS'), ('i', 'PRP'), ('need', 'VBP'), ('a', 'DT'), ('real', 'JJ'), ('bank', 'NN'), ('that', 'WDT'), ('cares', 'VBZ'), ('about', 'IN'), ('their', 'PRP$'), ('customers', 'NNS')]
#
# BankD banking is the worse ever i will never do buisness with them again due to poor customer service lack of training i guess
# [('BankD', 'NNP'), ('banking', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('worse', 'NN'), ('ever', 'RB'), ('i', 'PRP'), ('will', 'MD'), ('never', 'RB'), ('do', 'VB'), ('buisness', 'NN'), ('with', 'IN'), ('them', 'PRP'), ('again', 'RB'), ('due', 'JJ'), ('to', 'TO'), ('poor', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('lack', 'NN'), ('of', 'IN'), ('training', 'NN'), ('i', 'PRP'), ('guess', 'VBZ')]
#
# BankD has the absolute worst customer service Name been with this bank for years and my account is always in good standing this month due to financial trouble my account was overdrawn BankD continued to withdraBankA und from the account and approve transactions when i had a negative balance i was hit with   insufficient funds fees in less than two weeks i had previously signed documentation with BankD stating to decline any purBankDs that could not be funded i called customer service today to ask about waiving the fees and they told me there was nothing they could do i asked for a manager and she waived one rebanke isnt this what BankD recently got sued for if i dont have them money and someone tried to cash an old check or an auto payment tries to come out deny it now i cant deposit my paycheck into my account because it will all go to those fees and i wont be able to pay my bills i would appreciate some assistance from someone who can actually help me no wonder i keep getting notices to joint class action law suites against BankD
# [('BankD', 'NNP'), ('has', 'VBZ'), ('the', 'DT'), ('absolute', 'JJ'), ('worst', 'NN'), ('customer', 'NN'), ('service', 'NN'), ('Name', 'NNP'), ('been', 'VBN'), ('with', 'IN'), ('this', 'DT'), ('bank', 'NN'), ('for', 'IN'), ('years', 'NNS'), ('and', 'CC'), ('my', 'PRP$'), ('account', 'NN'), ('is', 'VBZ'), ('always', 'RB'), ('in', 'IN'), ('good', 'JJ'), ('standing', 'NN'), ('this', 'DT'), ('month', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('financial', 'JJ'), ('trouble', 'NN'), ('my', 'PRP$'), ('account', 'NN'), ('was', 'VBD'), ('overdrawn', 'VBN'), ('BankD', 'NNP'), ('continued', 'VBD'), ('to', 'TO'), ('withdraBankA', 'NNP'), ('und', 'NN'), ('from', 'IN'), ('the', 'DT'), ('account', 'NN'), ('and', 'CC'), ('approve', 'VB'), ('transactions', 'NNS'), ('when', 'WRB'), ('i', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('negative', 'JJ'), ('balance', 'NN'), ('i', 'PRP'), ('was', 'VBD'), ('hit', 'VBN'), ('with', 'IN'), ('insufficient', 'NN'), ('funds', 'NNS'), ('fees', 'NNS'), ('in', 'IN'), ('less', 'JJR'), ('than', 'IN'), ('two', 'CD'), ('weeks', 'NNS'), ('i', 'PRP'), ('had', 'VBD'), ('previously', 'RB'), ('signed', 'VBN'), ('documentation', 'NN'), ('with', 'IN'), ('BankD', 'NNP'), ('stating', 'VBG'), ('to', 'TO'), ('decline', 'VB'), ('any', 'DT'), ('purBankDs', 'NNP'), ('that', 'IN'), ('could', 'MD'), ('not', 'RB'), ('be', 'VB'), ('funded', 'VBN'), ('i', 'PRP'), ('called', 'VBN'), ('customer', 'NN'), ('service', 'NN'), ('today', 'NN'), ('to', 'TO'), ('ask', 'VB'), ('about', 'IN'), ('waiving', 'VBG'), ('the', 'DT'), ('fees', 'NNS'), ('and', 'CC'), ('they', 'PRP'), ('told', 'VBD'), ('me', 'PRP'), ('there', 'RB'), ('was', 'VBD'), ('nothing', 'NN'), ('they', 'PRP'), ('could', 'MD'), ('do', 'VB'), ('i', 'PRP'), ('asked', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('manager', 'NN'), ('and', 'CC'), ('she', 'PRP'), ('waived', 'VBD'), ('one', 'CD'), ('rebanke', 'NN'), ('isnt', 'NN'), ('this', 'DT'), ('what', 'WP'), ('BankD', 'NNP'), ('recently', 'RB'), ('got', 'VBD'), ('sued', 'VBN'), ('for', 'IN'), ('if', 'IN'), ('i', 'PRP'), ('dont', 'VBP'), ('have', 'VBP'), ('them', 'PRP'), ('money', 'NN'), ('and', 'CC'), ('someone', 'NN'), ('tried', 'VBD'), ('to', 'TO'), ('cash', 'NN'), ('an', 'DT'), ('old', 'JJ'), ('check', 'NN'), ('or', 'CC'), ('an', 'DT'), ('auto', 'NN'), ('payment', 'NN'), ('tries', 'NNS'), ('to', 'TO'), ('come', 'VB'), ('out', 'RP'), ('deny', 'JJ'), ('it', 'PRP'), ('now', 'RB'), ('i', 'PRP'), ('cant', 'VBP'), ('deposit', 'NN'), ('my', 'PRP$'), ('paycheck', 'NN'), ('into', 'IN'), ('my', 'PRP$'), ('account', 'NN'), ('because', 'IN'), ('it', 'PRP'), ('will', 'MD'), ('all', 'VB'), ('go', 'VB'), ('to', 'TO'), ('those', 'DT'), ('fees', 'NNS'), ('and', 'CC'), ('i', 'PRP'), ('wont', 'VBP'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('pay', 'VB'), ('my', 'PRP$'), ('bills', 'NNS'), ('i', 'PRP'), ('would', 'MD'), ('appreciate', 'VB'), ('some', 'DT'), ('assistance', 'NN'), ('from', 'IN'), ('someone', 'NN'), ('who', 'WP'), ('can', 'MD'), ('actually', 'RB'), ('help', 'VB'), ('me', 'PRP'), ('no', 'DT'), ('wonder', 'NN'), ('i', 'PRP'), ('keep', 'VBP'), ('getting', 'VBG'), ('notices', 'NNS'), ('to', 'TO'), ('joint', 'VB'), ('class', 'NN'), ('action', 'NN'), ('law', 'NN'), ('suites', 'VBZ'), ('against', 'IN'), ('BankD', 'NNP')]
#
# customer service fails again i left BankA after  years because of problems and tried today to get my statements even though i am willing to pay and even though they have sent them to me before via email without payment they flat out lied and said there was no way to do that because they cant take my payment a bank cant take a debit card over the phone Name you rebanke expect me to believe that i miss Name and their great customer service and attitude
# [('customer', 'NN'), ('service', 'NN'), ('fails', 'VBZ'), ('again', 'RB'), ('i', 'PRP'), ('left', 'VBD'), ('BankA', 'NNP'), ('after', 'IN'), ('years', 'NNS'), ('because', 'IN'), ('of', 'IN'), ('problems', 'NNS'), ('and', 'CC'), ('tried', 'VBD'), ('today', 'NN'), ('to', 'TO'), ('get', 'VB'), ('my', 'PRP$'), ('statements', 'NNS'), ('even', 'RB'), ('though', 'IN'), ('i', 'PRP'), ('am', 'VBP'), ('willing', 'JJ'), ('to', 'TO'), ('pay', 'VB'), ('and', 'CC'), ('even', 'RB'), ('though', 'IN'), ('they', 'PRP'), ('have', 'VBP'), ('sent', 'VBN'), ('them', 'PRP'), ('to', 'TO'), ('me', 'PRP'), ('before', 'IN'), ('via', 'IN'), ('email', 'NN'), ('without', 'IN'), ('payment', 'NN'), ('they', 'PRP'), ('flat', 'VBP'), ('out', 'RP'), ('lied', 'VBN'), ('and', 'CC'), ('said', 'VBD'), ('there', 'RB'), ('was', 'VBD'), ('no', 'DT'), ('way', 'NN'), ('to', 'TO'), ('do', 'VB'), ('that', 'DT'), ('because', 'IN'), ('they', 'PRP'), ('cant', 'VBP'), ('take', 'VBP'), ('my', 'PRP$'), ('payment', 'NN'), ('a', 'DT'), ('bank', 'NN'), ('cant', 'NN'), ('take', 'VB'), ('a', 'DT'), ('debit', 'NN'), ('card', 'NN'), ('over', 'IN'), ('the', 'DT'), ('phone', 'NN'), ('Name', 'NNP'), ('you', 'PRP'), ('rebanke', 'VBP'), ('expect', 'VBP'), ('me', 'PRP'), ('to', 'TO'), ('believe', 'VB'), ('that', 'IN'), ('i', 'PRP'), ('miss', 'VBP'), ('Name', 'NNP'), ('and', 'CC'), ('their', 'PRP$'), ('great', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('and', 'CC'), ('attitude', 'VB')]
#
# dont ever use your bank card in mexico because when you do not get money out of the atm BankB will charge you and tell you that you need to go after the bank on your own great customer servicenot
# [('dont', 'NN'), ('ever', 'RB'), ('use', 'VBP'), ('your', 'PRP$'), ('bank', 'NN'), ('card', 'NN'), ('in', 'IN'), ('mexico', 'NN'), ('because', 'IN'), ('when', 'WRB'), ('you', 'PRP'), ('do', 'VBP'), ('not', 'RB'), ('get', 'VB'), ('money', 'NN'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), ('atm', 'NN'), ('BankB', 'NNP'), ('will', 'MD'), ('charge', 'VB'), ('you', 'PRP'), ('and', 'CC'), ('tell', 'VBP'), ('you', 'PRP'), ('that', 'IN'), ('you', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('go', 'VB'), ('after', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('on', 'IN'), ('your', 'PRP$'), ('own', 'JJ'), ('great', 'JJ'), ('customer', 'NN'), ('servicenot', 'NN')]
#
# enjoy your day Name and know this im in a small town and am in good standing with the folks here word gets around quick and i intend on using social media to let as many ppl who care to know what BankA calls customer service and that they should be careful and even chose bankeing institution who doesnt penalize those who tried to do good by them like i said i could have paid the  bucks and opened an account closer to my home but i wanted that bank in particular because i knew the tellers and they treated my mom good when she was alive now theres nothing there
# ...
#
# sure i contacted BankA in regards to a stop payment on a check i did give them the right check number wrong store and wrong ammountill take that thought the right check number would be goodeither way when check cleared called customer service waited on hold for manager  min was told by manager that it eild be resolved in  days but more likely that  days called BankB  to follow up today due to more charges csr said at first could not find notes  min later he told me  days minimum so my frustrations are on multi level  if someone git my check book and was writing checks you could not stop then with a check number  manager world rather calm me down with less then truthfully answers now my payroll will hit and a large  will be gone do to the issue my being resolved then csr informed online i could so payment with only check number but calling you does nit work like that
# [('sure', 'RB'), ('i', 'PRP'), ('contacted', 'VBD'), ('BankA', 'NNP'), ('in', 'IN'), ('regards', 'NNS'), ('to', 'TO'), ('a', 'DT'), ('stop', 'NN'), ('payment', 'NN'), ('on', 'IN'), ('a', 'DT'), ('check', 'NN'), ('i', 'PRP'), ('did', 'VBD'), ('give', 'JJ'), ('them', 'PRP'), ('the', 'DT'), ('right', 'NN'), ('check', 'NN'), ('number', 'NN'), ('wrong', 'IN'), ('store', 'NN'), ('and', 'CC'), ('wrong', 'JJ'), ('ammountill', 'NN'), ('take', 'NN'), ('that', 'WDT'), ('thought', 'VBD'), ('the', 'DT'), ('right', 'NN'), ('check', 'NN'), ('number', 'NN'), ('would', 'MD'), ('be', 'VB'), ('goodeither', 'RB'), ('way', 'NN'), ('when', 'WRB'), ('check', 'NN'), ('cleared', 'VBN'), ('called', 'VBN'), ('customer', 'NN'), ('service', 'NN'), ('waited', 'VBD'), ('on', 'IN'), ('hold', 'NN'), ('for', 'IN'), ('manager', 'NN'), ('min', 'NN'), ('was', 'VBD'), ('told', 'VBN'), ('by', 'IN'), ('manager', 'NN'), ('that', 'IN'), ('it', 'PRP'), ('eild', 'VBD'), ('be', 'VB'), ('resolved', 'VBN'), ('in', 'IN'), ('days', 'NNS'), ('but', 'CC'), ('more', 'RBR'), ('likely', 'JJ'), ('that', 'IN'), ('days', 'NNS'), ('called', 'VBN'), ('BankB', 'NNP'), ('to', 'TO'), ('follow', 'VB'), ('up', 'RP'), ('today', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('more', 'RBR'), ('charges', 'NNS'), ('csr', 'VBP'), ('said', 'VBN'), ('at', 'IN'), ('first', 'JJ'), ('could', 'MD'), ('not', 'RB'), ('find', 'VB'), ('notes', 'NNS'), ('min', 'IN'), ('later', 'JJ'), ('he', 'PRP'), ('told', 'VBD'), ('me', 'PRP'), ('days', 'NNS'), ('minimum', 'VBP'), ('so', 'RB'), ('my', 'PRP$'), ('frustrations', 'NNS'), ('are', 'VBP'), ('on', 'IN'), ('multi', 'NN'), ('level', 'NN'), ('if', 'IN'), ('someone', 'NN'), ('git', 'NN'), ('my', 'PRP$'), ('check', 'NN'), ('book', 'NN'), ('and', 'CC'), ('was', 'VBD'), ('writing', 'VBG'), ('checks', 'NNS'), ('you', 'PRP'), ('could', 'MD'), ('not', 'RB'), ('stop', 'VB'), ('then', 'RB'), ('with', 'IN'), ('a', 'DT'), ('check', 'NN'), ('number', 'NN'), ('manager', 'NN'), ('world', 'NN'), ('rather', 'RB'), ('calm', 'VB'), ('me', 'PRP'), ('down', 'IN'), ('with', 'IN'), ('less', 'JJR'), ('then', 'RB'), ('truthfully', 'RB'), ('answers', 'NNS'), ('now', 'RB'), ('my', 'PRP$'), ('payroll', 'NN'), ('will', 'MD'), ('hit', 'VB'), ('and', 'CC'), ('a', 'DT'), ('large', 'JJ'), ('will', 'MD'), ('be', 'VB'), ('gone', 'VBN'), ('do', 'VB'), ('to', 'TO'), ('the', 'DT'), ('issue', 'NN'), ('my', 'PRP$'), ('being', 'VBG'), ('resolved', 'VBN'), ('then', 'RB'), ('csr', 'JJ'), ('informed', 'VBN'), ('online', 'NN'), ('i', 'PRP'), ('could', 'MD'), ('so', 'RB'), ('payment', 'VB'), ('with', 'IN'), ('only', 'RB'), ('check', 'VBP'), ('number', 'NN'), ('but', 'CC'), ('calling', 'VBG'), ('you', 'PRP'), ('does', 'VBZ'), ('nit', 'NN'), ('work', 'NN'), ('like', 'IN'), ('that', 'DT')]
#
# thanks BankA for blocking my husbands debit card and causing him great embarrassment at the drugstore i appreciate your fraud departments concern due to the chick Name a security breach but shouldnt you contact your customer instead of just suddenly putting a block on his card without notice to your customer i am sure his  of suspicious activity at his regular stops was quite alarming customer service fail BankA bank
# [('thanks', 'NNS'), ('BankA', 'VBP'), ('for', 'IN'), ('blocking', 'VBG'), ('my', 'PRP$'), ('husbands', 'NNS'), ('debit', 'NN'), ('card', 'NN'), ('and', 'CC'), ('causing', 'VBG'), ('him', 'PRP'), ('great', 'JJ'), ('embarrassment', 'NN'), ('at', 'IN'), ('the', 'DT'), ('drugstore', 'NN'), ('i', 'PRP'), ('appreciate', 'VBP'), ('your', 'PRP$'), ('fraud', 'NN'), ('departments', 'NNS'), ('concern', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('chick', 'NN'), ('Name', 'NNP'), ('a', 'DT'), ('security', 'NN'), ('breach', 'NN'), ('but', 'CC'), ('shouldnt', 'NN'), ('you', 'PRP'), ('contact', 'VBP'), ('your', 'PRP$'), ('customer', 'NN'), ('instead', 'RB'), ('of', 'IN'), ('just', 'RB'), ('suddenly', 'RB'), ('putting', 'VBG'), ('a', 'DT'), ('block', 'NN'), ('on', 'IN'), ('his', 'PRP$'), ('card', 'NN'), ('without', 'IN'), ('notice', 'NN'), ('to', 'TO'), ('your', 'PRP$'), ('customer', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('sure', 'JJ'), ('his', 'PRP$'), ('of', 'IN'), ('suspicious', 'JJ'), ('activity', 'NN'), ('at', 'IN'), ('his', 'PRP$'), ('regular', 'JJ'), ('stops', 'NNS'), ('was', 'VBD'), ('quite', 'RB'), ('alarming', 'VBG'), ('customer', 'NN'), ('service', 'NN'), ('fail', 'NN'), ('BankA', 'NNP'), ('bank', 'NN')]
#
# Name the worst bank ever they close my account due to some bull shit they sent in the mail now my job direct deposit my pay into that account tell me why they dont want to give me my money then the customer service sucks they so rude lost prevention is even worse they have no good communication skills BankA bank is a rip off so i rebanke want to tell them to fuck off you stupid financial institutions you need to treat your family as you all put it right our money and business is what keeps you going asshole
# [('Name', 'NNP'), ('the', 'DT'), ('worst', 'JJS'), ('bank', 'NN'), ('ever', 'RB'), ('they', 'PRP'), ('close', 'VBP'), ('my', 'PRP$'), ('account', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('some', 'DT'), ('bull', 'NN'), ('shit', 'NN'), ('they', 'PRP'), ('sent', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('mail', 'NN'), ('now', 'RB'), ('my', 'PRP$'), ('job', 'NN'), ('direct', 'NN'), ('deposit', 'NN'), ('my', 'PRP$'), ('pay', 'NN'), ('into', 'IN'), ('that', 'DT'), ('account', 'NN'), ('tell', 'NN'), ('me', 'PRP'), ('why', 'WRB'), ('they', 'PRP'), ('dont', 'VBP'), ('want', 'JJ'), ('to', 'TO'), ('give', 'VB'), ('me', 'PRP'), ('my', 'PRP$'), ('money', 'NN'), ('then', 'RB'), ('the', 'DT'), ('customer', 'NN'), ('service', 'NN'), ('sucks', 'NNS'), ('they', 'PRP'), ('so', 'RB'), ('rude', 'VBP'), ('lost', 'VBN'), ('prevention', 'NN'), ('is', 'VBZ'), ('even', 'RB'), ('worse', 'JJR'), ('they', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('good', 'JJ'), ('communication', 'NN'), ('skills', 'NNS'), ('BankA', 'NNP'), ('bank', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('rip', 'NN'), ('off', 'RP'), ('so', 'RB'), ('i', 'PRP'), ('rebanke', 'VBP'), ('want', 'JJ'), ('to', 'TO'), ('tell', 'VB'), ('them', 'PRP'), ('to', 'TO'), ('fuck', 'VB'), ('off', 'RP'), ('you', 'PRP'), ('stupid', 'VBD'), ('financial', 'JJ'), ('institutions', 'NNS'), ('you', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('treat', 'VB'), ('your', 'PRP$'), ('family', 'NN'), ('as', 'IN'), ('you', 'PRP'), ('all', 'DT'), ('put', 'VBD'), ('it', 'PRP'), ('right', 'RB'), ('our', 'PRP$'), ('money', 'NN'), ('and', 'CC'), ('business', 'NN'), ('is', 'VBZ'), ('what', 'WP'), ('keeps', 'NNS'), ('you', 'PRP'), ('going', 'VBG'), ('asshole', 'NN')]
#
# the worst customer service ever so disgusted you all need to check into your customer services reps she encouraged me to leave BankA and to create another account with a different bank because she did not feel like addressing the problem
# [('the', 'DT'), ('worst', 'JJS'), ('customer', 'NN'), ('service', 'NN'), ('ever', 'RB'), ('so', 'RB'), ('disgusted', 'VBN'), ('you', 'PRP'), ('all', 'DT'), ('need', 'VBP'), ('to', 'TO'), ('check', 'VB'), ('into', 'IN'), ('your', 'PRP$'), ('customer', 'NN'), ('services', 'NNS'), ('reps', 'NNS'), ('she', 'PRP'), ('encouraged', 'VBD'), ('me', 'PRP'), ('to', 'TO'), ('leave', 'VB'), ('BankA', 'NNP'), ('and', 'CC'), ('to', 'TO'), ('create', 'VB'), ('another', 'DT'), ('account', 'NN'), ('with', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('bank', 'NN'), ('because', 'IN'), ('she', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('feel', 'VB'), ('like', 'IN'), ('addressing', 'NN'), ('the', 'DT'), ('problem', 'NN')]
#
# this bank is the worst bank they do not have any security at all my account info had been stolen and this bank do no have insurance for your money BankD bank bank has insurance if your money get stolen at BankD they will refund you the next day banke waits  days to refund and its not definitely i will be closing my account with this bank because their security is very poor and customer service is a bunch of half train people not even students
# [('this', 'DT'), ('bank', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('worst', 'JJS'), ('bank', 'NN'), ('they', 'PRP'), ('do', 'VBP'), ('not', 'RB'), ('have', 'VB'), ('any', 'DT'), ('security', 'NN'), ('at', 'IN'), ('all', 'DT'), ('my', 'PRP$'), ('account', 'NN'), ('info', 'NN'), ('had', 'VBD'), ('been', 'VBN'), ('stolen', 'VBN'), ('and', 'CC'), ('this', 'DT'), ('bank', 'NN'), ('do', 'VBP'), ('no', 'DT'), ('have', 'VB'), ('insurance', 'NN'), ('for', 'IN'), ('your', 'PRP$'), ('money', 'NN'), ('BankD', 'NNP'), ('bank', 'NN'), ('bank', 'NN'), ('has', 'VBZ'), ('insurance', 'NN'), ('if', 'IN'), ('your', 'PRP$'), ('money', 'NN'), ('get', 'NN'), ('stolen', 'IN'), ('at', 'IN'), ('BankD', 'NNP'), ('they', 'PRP'), ('will', 'MD'), ('refund', 'VB'), ('you', 'PRP'), ('the', 'DT'), ('next', 'JJ'), ('day', 'NN'), ('banke', 'NN'), ('waits', 'NNS'), ('days', 'NNS'), ('to', 'TO'), ('refund', 'VB'), ('and', 'CC'), ('its', 'PRP$'), ('not', 'RB'), ('definitely', 'RB'), ('i', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('closing', 'VBG'), ('my', 'PRP$'), ('account', 'NN'), ('with', 'IN'), ('this', 'DT'), ('bank', 'NN'), ('because', 'IN'), ('their', 'PRP$'), ('security', 'NN'), ('is', 'VBZ'), ('very', 'RB'), ('poor', 'JJ'), ('and', 'CC'), ('customer', 'NN'), ('service', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('bunch', 'NN'), ('of', 'IN'), ('half', 'PDT'), ('train', 'NN'), ('people', 'NNS'), ('not', 'RB'), ('even', 'RB'), ('students', 'NNS')]
#
# this Name pay center is joke Name been trying to use this for almost a month and just doesnt work the first issue was because i was not even able to open the Name pay center due an error it took almost two weeks for BankB get this fixed and now i my checking account is not linked so i still not able to use the service i tried to call the customer service but got the following error your call could not be completed try again unbelievable
# [('this', 'DT'), ('Name', 'NNP'), ('pay', 'NN'), ('center', 'NN'), ('is', 'VBZ'), ('joke', 'NN'), ('Name', 'NNP'), ('been', 'NN'), ('trying', 'VBG'), ('to', 'TO'), ('use', 'VB'), ('this', 'DT'), ('for', 'IN'), ('almost', 'RB'), ('a', 'DT'), ('month', 'NN'), ('and', 'CC'), ('just', 'RB'), ('doesnt', 'JJ'), ('work', 'NN'), ('the', 'DT'), ('first', 'JJ'), ('issue', 'NN'), ('was', 'VBD'), ('because', 'IN'), ('i', 'PRP'), ('was', 'VBD'), ('not', 'RB'), ('even', 'RB'), ('able', 'JJ'), ('to', 'TO'), ('open', 'JJ'), ('the', 'DT'), ('Name', 'NNP'), ('pay', 'NN'), ('center', 'NN'), ('due', 'JJ'), ('an', 'DT'), ('error', 'NN'), ('it', 'PRP'), ('took', 'VBD'), ('almost', 'RB'), ('two', 'CD'), ('weeks', 'NNS'), ('for', 'IN'), ('BankB', 'NNP'), ('get', 'NN'), ('this', 'DT'), ('fixed', 'VBN'), ('and', 'CC'), ('now', 'RB'), ('i', 'PRP'), ('my', 'PRP$'), ('checking', 'NN'), ('account', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('linked', 'VBN'), ('so', 'RB'), ('i', 'PRP'), ('still', 'RB'), ('not', 'RB'), ('able', 'JJ'), ('to', 'TO'), ('use', 'VB'), ('the', 'DT'), ('service', 'NN'), ('i', 'PRP'), ('tried', 'VBD'), ('to', 'TO'), ('call', 'VB'), ('the', 'DT'), ('customer', 'NN'), ('service', 'NN'), ('but', 'CC'), ('got', 'VBD'), ('the', 'DT'), ('following', 'VBG'), ('error', 'NN'), ('your', 'PRP$'), ('call', 'NN'), ('could', 'MD'), ('not', 'RB'), ('be', 'VB'), ('completed', 'VBN'), ('try', 'NN'), ('again', 'RB'), ('unbelievable', 'JJ')]
#
# this is absolutely ridiculous BankBs customer service has reached a new low they dont have available attendants in there call center after  pm i have an emergency and now will probably get charged because of their insolence
# [('this', 'DT'), ('is', 'VBZ'), ('absolutely', 'RB'), ('ridiculous', 'JJ'), ('BankBs', 'NNS'), ('customer', 'NN'), ('service', 'NN'), ('has', 'VBZ'), ('reached', 'VBN'), ('a', 'DT'), ('new', 'JJ'), ('low', 'JJ'), ('they', 'PRP'), ('dont', 'VBP'), ('have', 'VBP'), ('available', 'JJ'), ('attendants', 'NNS'), ('in', 'IN'), ('there', 'EX'), ('call', 'NN'), ('center', 'NN'), ('after', 'IN'), ('pm', 'NN'), ('i', 'PRP'), ('have', 'VBP'), ('an', 'DT'), ('emergency', 'NN'), ('and', 'CC'), ('now', 'RB'), ('will', 'MD'), ('probably', 'RB'), ('get', 'VB'), ('charged', 'VBN'), ('because', 'IN'), ('of', 'IN'), ('their', 'PRP$'), ('insolence', 'NN')]
#
# today i received a BankA customer service survey from morpace that seemed like a phishing scam email because it was not sent to my primary email address but to my secondary email address which should only be used for high priority issues not cool
# [('today', 'NN'), ('i', 'PRP'), ('received', 'VBD'), ('a', 'DT'), ('BankA', 'NNP'), ('customer', 'NN'), ('service', 'NN'), ('survey', 'NN'), ('from', 'IN'), ('morpace', 'NN'), ('that', 'IN'), ('seemed', 'VBD'), ('like', 'IN'), ('a', 'DT'), ('phishing', 'NN'), ('scam', 'NN'), ('email', 'NN'), ('because', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('not', 'RB'), ('sent', 'VBN'), ('to', 'TO'), ('my', 'PRP$'), ('primary', 'JJ'), ('email', 'NN'), ('address', 'NN'), ('but', 'CC'), ('to', 'TO'), ('my', 'PRP$'), ('secondary', 'JJ'), ('email', 'NN'), ('address', 'NN'), ('which', 'WDT'), ('should', 'MD'), ('only', 'RB'), ('be', 'VB'), ('used', 'VBN'), ('for', 'IN'), ('high', 'JJ'), ('priority', 'NN'), ('issues', 'NNS'), ('not', 'RB'), ('cool', 'JJ')]

# %%
# customer service
fd1 = nltk.FreqDist([adj[0] if len(adj) > 0 else '' for adj in adj_phrases])
fd1.most_common()
# Out:
# [('worst', 165),
#  ('worse', 36),
#  ('happy', 33),
#  ('able', 33),
#  ('best', 33),
#  ('due', 28),
#  ('open', 24),
#  ('better', 23),
#  ('sure', 22),
#  ('wont', 22),
#  ('rude', 22),
#  ('good', 21),
#  ('new', 20),
#  ('horrible', 18),
#  ('terrible', 18),
#  ('bad', 17),
#  ('close', 15),
#  ('ridiculous', 14),
#  ('nice', 14),
#  ('such', 13),
#  ('sorry', 13),
#  ('personal', 13),
#  ('sad', 12),
#  ('helpful', 12),
#  ('wrong', 12),
#  ('long', 11),
#  ('ill', 11),
#  ('amazing', 10),
#  ('ready', 10),
#  ('full', 9),
#  ('willing', 9),
#  ('longer', 7),
#  ('different', 7),
#  ('possible', 7),
#  ('poor', 7),
#  ('awesome', 7),
#  ('great', 7),
#  ('sick', 7),
#  ('available', 7),
#  ('quick', 6),
#  ('negative', 6),
#  ('glad', 6),
#  ('absolute', 6),
#  ('professional', 6),
#  ('clear', 6),
#  ('real', 6),
#  ('thankful', 5),
#  ('stupid', 5),
#  ('higher', 5),
#  ('grateful', 5),
#  ('big', 5),
#  ('unhappy', 5),
#  ('free', 5),
#  ('true', 4),
#  ('easy', 4),
#  ('everyday', 4),
#  ('worthless', 4),
#  ('own', 4),
#  ('correct', 4),
#  ('welcome', 4),
#  ('human', 4),
#  ('angry', 4),
#  ('pathetic', 4),
#  ('closest', 4),
#  ('difficult', 4),
#  ('mad', 4),
#  ('convenient', 4),
#  ('useless', 4),
#  ('main', 4),
#  ('unable', 4),
#  ('disappointing', 4),
#  ('unbelievable', 3),
#  ('overseas', 3),
#  ('okay', 3),
#  ('monthly', 3),
#  ('simple', 3),
#  ('local', 3),
#  ('old', 3),
#  ('biggest', 3),
#  ('unwilling', 3),
#  ('commercial', 3),
#  ('hard', 3),
#  ('crazy', 3),
#  ('unprofessional', 3),
#  ('excellent', 3),
#  ('frustrating', 3),
#  ('super', 3),
#  ('important', 3),
#  ('bigger', 3),
#  ('aware', 3),
#  ('ashamed', 3),
#  ('late', 3),
#  ('august', 3),
#  ('incompetent', 3),
#  ('largest', 3),
#  ('public', 3),
#  ('wise', 3),
#  ('afraid', 3),
#  ('unacceptable', 3),
#  ('polite', 3),
#  ('lower', 3),
#  ('knowledgeable', 3),
#  ('south', 3),
#  ('sudden', 3),
#  ('fair', 2),
#  ('corporate', 2),
#  ('obvious', 2),
#  ('prompt', 2),
#  ('worth', 2),
#  ('unreliable', 2),
#  ('careful', 2),
#  ('illegal', 2),
#  ('elderly', 2),
#  ('low', 2),
#  ('likely', 2),
#  ('whole', 2),
#  ('clean', 2),
#  ('special', 2),
#  ('senior', 2),
#  ('small', 2),
#  ('rid', 2),
#  ('slowest', 2),
#  ('criminal', 2),
#  ('trying', 2),
#  ('existent', 2),
#  ('progressive', 2),
#  ('comfortable', 2),
#  ('famous', 2),
#  ('smaller', 2),
#  ('easier', 2),
#  ('unresolved', 2),
#  ('slow', 2),
#  ('needless', 2),
#  ('obnoxious', 2),
#  ('pleasant', 2),
#  ('direct', 2),
#  ('complete', 2),
#  ('unsure', 2),
#  ('associate', 2),
#  ('careless', 2),
#  ('serious', 2),
#  ('responsible', 2),
#  ('annoying', 2),
#  ('reliable', 2),
#  ('reasonable', 2),
#  ('international', 2),
#  ('absurd', 2),
#  ('flat', 2),
#  ('calm', 2),
#  ('gay', 2),
#  ('shocking', 2),
#  ('inconvenient', 2),
#  ('wonderful', 2),
#  ('little', 2),
#  ('cool', 2),
#  ('large', 2),
#  ('dead', 2),
#  ('double', 2),
#  ('extra', 2),
#  ('unfriendly', 2),
#  ('safe', 2),
#  ('appreciative', 1),
#  ('attendant', 1),
#  ('unpaid', 1),
#  ('strong', 1),
#  ('apologetic', 1),
#  ('silly', 1),
#  ('reluctant', 1),
#  ('initial', 1),
#  ('unsatisfactory', 1),
#  ('colder', 1),
#  ('entire', 1),
#  ('hungry', 1),
#  ('medical', 1),
#  ('active', 1),
#  ('dumb', 1),
#  ('shoddy', 1),
#  ('alive', 1),
#  ('practical', 1),
#  ('minimum', 1),
#  ('nonexistent', 1),
#  ('offensive', 1),
#  ('cute', 1),
#  ('temporary', 1),
#  ('national', 1),
#  ('federal', 1),
#  ('quarterly', 1),
#  ('false', 1),
#  ('disgusting', 1),
#  ('using', 1),
#  ('deficient', 1),
#  ('cautious', 1),
#  ('deceitful', 1),
#  ('ideal', 1),
#  ('round', 1),
#  ('western', 1),
#  ('shady', 1),
#  ('lazy', 1),
#  ('principal', 1),
#  ('harder', 1),
#  ('dear', 1),
#  ('certain', 1),
#  ('short', 1),
#  ('happiest', 1),
#  ('happier', 1),
#  ('slick', 1),
#  ('moving', 1),
#  ('friendly', 1),
#  ('obscene', 1),
#  ('unusual', 1),
#  ('cheery', 1),
#  ('loud', 1),
#  ('impersonal', 1),
#  ('further', 1),
#  ('overall', 1),
#  ('adamant', 1),
#  ('blue', 1),
#  ('mobile', 1),
#  ('blind', 1),
#  ('busy', 1),
#  ('irate', 1),
#  ('unsuccessful', 1),
#  ('breezy', 1),
#  ('consistent', 1),
#  ('sweet', 1),
#  ('private', 1),
#  ('cherry', 1),
#  ('unappreciated', 1),
#  ('healthier', 1),
#  ('live', 1),
#  ('permanent', 1),
#  ('later', 1),
#  ('ignorant', 1),
#  ('particular', 1),
#  ('alert', 1),
#  ('regional', 1),
#  ('curious', 1),
#  ('infuriating', 1),
#  ('horrid', 1),
#  ('poorest', 1),
#  ('horrifying', 1),
#  ('prohibitive', 1),
#  ('undesirable', 1),
#  ('deeper', 1),
#  ('nighted', 1),
#  ('older', 1),
#  ('total', 1),
#  ('honest', 1),
#  ('damn', 1),
#  ('opposite', 1),
#  ('modern', 1),
#  ('exact', 1),
#  ('vigilant', 1),
#  ('loose', 1),
#  ('astronomical', 1),
#  ('similar', 1),
#  ('necessary', 1),
#  ('rotten', 1),
#  ('loyal', 1),
#  ('profitable', 1),
#  ('sensitive', 1),
#  ('official', 1),
#  ('mediocre', 1),
#  ('greater', 1),
#  ('dangerous', 1),
#  ('common', 1),
#  ('highest', 1),
#  ('lousy', 1),
#  ('ethical', 1),
#  ('boundless', 1),
#  ('early', 1),
#  ('giant', 1),
#  ('multiple', 1),
#  ('effective', 1),
#  ('lowest', 1),
#  ('unclear', 1),
#  ('superior', 1),
#  ('uneducated', 1),
#  ('slower', 1),
#  ('wretched', 1),
#  ('questionable', 1),
#  ('corrupt', 1),
#  ('random', 1),
#  ('pitiful', 1),
#  ('successful', 1),
#  ('heartless', 1),
#  ('high', 1),
#  ('untrue', 1),
#  ('interesting', 1),
#  ('normal', 1),
#  ('sneaky', 1),
#  ('fine', 1),
#  ('proper', 1),
#  ('empty', 1),
#  ('nearest', 1),
#  ('cold', 1),
#  ('unavailable', 1),
#  ('generous', 1),
#  ('regular', 1),
#  ('overwhelming', 1),
#  ('arrogant', 1),
#  ('exceptional', 1),
#  ('legal', 1),
#  ('comparable', 1),
#  ('vocal', 1),
#  ('disinterested', 1)]

# %%
# close account
fd1 = nltk.FreqDist([adj[0] if len(adj) > 0 else '' for adj in adj_phrases])
fd1.most_common()
# Out:
# [('worst', 165),
#  ('worse', 36),
#  ('happy', 33),
#  ('able', 33),
#  ('best', 33),
#  ('due', 28),
#  ('open', 24),
#  ('better', 23),
#  ('sure', 22),
#  ('wont', 22),
#  ('rude', 22),
#  ('good', 21),
#  ('new', 20),
#  ('horrible', 18),
#  ('terrible', 18),
#  ('bad', 17),
#  ('close', 15),
#  ('ridiculous', 14),
#  ('nice', 14),
#  ('such', 13),
#  ('sorry', 13),
#  ('personal', 13),
#  ('sad', 12),
#  ('helpful', 12),
#  ('wrong', 12),
#  ('long', 11),
#  ('ill', 11),
#  ('amazing', 10),
#  ('ready', 10),
#  ('full', 9),
#  ('willing', 9),
#  ('longer', 7),
#  ('different', 7),
#  ('possible', 7),
#  ('poor', 7),
#  ('awesome', 7),
#  ('great', 7),
#  ('sick', 7),
#  ('available', 7),
#  ('quick', 6),
#  ('negative', 6),
#  ('glad', 6),
#  ('absolute', 6),
#  ('professional', 6),
#  ('clear', 6),
#  ('real', 6),
#  ('thankful', 5),
#  ('stupid', 5),
#  ('higher', 5),
#  ('grateful', 5),
#  ('big', 5),
#  ('unhappy', 5),
#  ('free', 5),
#  ('true', 4),
#  ('easy', 4),
#  ('everyday', 4),
#  ('worthless', 4),
#  ('own', 4),
#  ('correct', 4),
#  ('welcome', 4),
#  ('human', 4),
#  ('angry', 4),
#  ('pathetic', 4),
#  ('closest', 4),
#  ('difficult', 4),
#  ('mad', 4),
#  ('convenient', 4),
#  ('useless', 4),
#  ('main', 4),
#  ('unable', 4),
#  ('disappointing', 4),
#  ('unbelievable', 3),
#  ('overseas', 3),
#  ('okay', 3),
#  ('monthly', 3),
#  ('simple', 3),
#  ('local', 3),
#  ('old', 3),
#  ('biggest', 3),
#  ('unwilling', 3),
#  ('commercial', 3),
#  ('hard', 3),
#  ('crazy', 3),
#  ('unprofessional', 3),
#  ('excellent', 3),
#  ('frustrating', 3),
#  ('super', 3),
#  ('important', 3),
#  ('bigger', 3),
#  ('aware', 3),
#  ('ashamed', 3),
#  ('late', 3),
#  ('august', 3),
#  ('incompetent', 3),
#  ('largest', 3),
#  ('public', 3),
#  ('wise', 3),
#  ('afraid', 3),
#  ('unacceptable', 3),
#  ('polite', 3),
#  ('lower', 3),
#  ('knowledgeable', 3),
#  ('south', 3),
#  ('sudden', 3),
#  ('fair', 2),
#  ('corporate', 2),
#  ('obvious', 2),
#  ('prompt', 2),
#  ('worth', 2),
#  ('unreliable', 2),
#  ('careful', 2),
#  ('illegal', 2),
#  ('elderly', 2),
#  ('low', 2),
#  ('likely', 2),
#  ('whole', 2),
#  ('clean', 2),
#  ('special', 2),
#  ('senior', 2),
#  ('small', 2),
#  ('rid', 2),
#  ('slowest', 2),
#  ('criminal', 2),
#  ('trying', 2),
#  ('existent', 2),
#  ('progressive', 2),
#  ('comfortable', 2),
#  ('famous', 2),
#  ('smaller', 2),
#  ('easier', 2),
#  ('unresolved', 2),
#  ('slow', 2),
#  ('needless', 2),
#  ('obnoxious', 2),
#  ('pleasant', 2),
#  ('direct', 2),
#  ('complete', 2),
#  ('unsure', 2),
#  ('associate', 2),
#  ('careless', 2),
#  ('serious', 2),
#  ('responsible', 2),
#  ('annoying', 2),
#  ('reliable', 2),
#  ('reasonable', 2),
#  ('international', 2),
#  ('absurd', 2),
#  ('flat', 2),
#  ('calm', 2),
#  ('gay', 2),
#  ('shocking', 2),
#  ('inconvenient', 2),
#  ('wonderful', 2),
#  ('little', 2),
#  ('cool', 2),
#  ('large', 2),
#  ('dead', 2),
#  ('double', 2),
#  ('extra', 2),
#  ('unfriendly', 2),
#  ('safe', 2),
#  ('appreciative', 1),
#  ('attendant', 1),
#  ('unpaid', 1),
#  ('strong', 1),
#  ('apologetic', 1),
#  ('silly', 1),
#  ('reluctant', 1),
#  ('initial', 1),
#  ('unsatisfactory', 1),
#  ('colder', 1),
#  ('entire', 1),
#  ('hungry', 1),
#  ('medical', 1),
#  ('active', 1),
#  ('dumb', 1),
#  ('shoddy', 1),
#  ('alive', 1),
#  ('practical', 1),
#  ('minimum', 1),
#  ('nonexistent', 1),
#  ('offensive', 1),
#  ('cute', 1),
#  ('temporary', 1),
#  ('national', 1),
#  ('federal', 1),
#  ('quarterly', 1),
#  ('false', 1),
#  ('disgusting', 1),
#  ('using', 1),
#  ('deficient', 1),
#  ('cautious', 1),
#  ('deceitful', 1),
#  ('ideal', 1),
#  ('round', 1),
#  ('western', 1),
#  ('shady', 1),
#  ('lazy', 1),
#  ('principal', 1),
#  ('harder', 1),
#  ('dear', 1),
#  ('certain', 1),
#  ('short', 1),
#  ('happiest', 1),
#  ('happier', 1),
#  ('slick', 1),
#  ('moving', 1),
#  ('friendly', 1),
#  ('obscene', 1),
#  ('unusual', 1),
#  ('cheery', 1),
#  ('loud', 1),
#  ('impersonal', 1),
#  ('further', 1),
#  ('overall', 1),
#  ('adamant', 1),
#  ('blue', 1),
#  ('mobile', 1),
#  ('blind', 1),
#  ('busy', 1),
#  ('irate', 1),
#  ('unsuccessful', 1),
#  ('breezy', 1),
#  ('consistent', 1),
#  ('sweet', 1),
#  ('private', 1),
#  ('cherry', 1),
#  ('unappreciated', 1),
#  ('healthier', 1),
#  ('live', 1),
#  ('permanent', 1),
#  ('later', 1),
#  ('ignorant', 1),
#  ('particular', 1),
#  ('alert', 1),
#  ('regional', 1),
#  ('curious', 1),
#  ('infuriating', 1),
#  ('horrid', 1),
#  ('poorest', 1),
#  ('horrifying', 1),
#  ('prohibitive', 1),
#  ('undesirable', 1),
#  ('deeper', 1),
#  ('nighted', 1),
#  ('older', 1),
#  ('total', 1),
#  ('honest', 1),
#  ('damn', 1),
#  ('opposite', 1),
#  ('modern', 1),
#  ('exact', 1),
#  ('vigilant', 1),
#  ('loose', 1),
#  ('astronomical', 1),
#  ('similar', 1),
#  ('necessary', 1),
#  ('rotten', 1),
#  ('loyal', 1),
#  ('profitable', 1),
#  ('sensitive', 1),
#  ('official', 1),
#  ('mediocre', 1),
#  ('greater', 1),
#  ('dangerous', 1),
#  ('common', 1),
#  ('highest', 1),
#  ('lousy', 1),
#  ('ethical', 1),
#  ('boundless', 1),
#  ('early', 1),
#  ('giant', 1),
#  ('multiple', 1),
#  ('effective', 1),
#  ('lowest', 1),
#  ('unclear', 1),
#  ('superior', 1),
#  ('uneducated', 1),
#  ('slower', 1),
#  ('wretched', 1),
#  ('questionable', 1),
#  ('corrupt', 1),
#  ('random', 1),
#  ('pitiful', 1),
#  ('successful', 1),
#  ('heartless', 1),
#  ('high', 1),
#  ('untrue', 1),
#  ('interesting', 1),
#  ('normal', 1),
#  ('sneaky', 1),
#  ('fine', 1),
#  ('proper', 1),
#  ('empty', 1),
#  ('nearest', 1),
#  ('cold', 1),
#  ('unavailable', 1),
#  ('generous', 1),
#  ('regular', 1),
#  ('overwhelming', 1),
#  ('arrogant', 1),
#  ('exceptional', 1),
#  ('legal', 1),
#  ('comparable', 1),
#  ('vocal', 1),
#  ('disinterested', 1)]

# %%
# new bank
fd3 = nltk.FreqDist([adj[0] if len(adj) > 0 else '' for adj in adj_phrases])
fd3.most_common()
# Out:
# [('worst', 165),
#  ('worse', 36),
#  ('happy', 33),
#  ('able', 33),
#  ('best', 33),
#  ('due', 28),
#  ('open', 24),
#  ('better', 23),
#  ('sure', 22),
#  ('wont', 22),
#  ('rude', 22),
#  ('good', 21),
#  ('new', 20),
#  ('horrible', 18),
#  ('terrible', 18),
#  ('bad', 17),
#  ('close', 15),
#  ('ridiculous', 14),
#  ('nice', 14),
#  ('such', 13),
#  ('sorry', 13),
#  ('personal', 13),
#  ('sad', 12),
#  ('helpful', 12),
#  ('wrong', 12),
#  ('long', 11),
#  ('ill', 11),
#  ('amazing', 10),
#  ('ready', 10),
#  ('full', 9),
#  ('willing', 9),
#  ('longer', 7),
#  ('different', 7),
#  ('possible', 7),
#  ('poor', 7),
#  ('awesome', 7),
#  ('great', 7),
#  ('sick', 7),
#  ('available', 7),
#  ('quick', 6),
#  ('negative', 6),
#  ('glad', 6),
#  ('absolute', 6),
#  ('professional', 6),
#  ('clear', 6),
#  ('real', 6),
#  ('thankful', 5),
#  ('stupid', 5),
#  ('higher', 5),
#  ('grateful', 5),
#  ('big', 5),
#  ('unhappy', 5),
#  ('free', 5),
#  ('true', 4),
#  ('easy', 4),
#  ('everyday', 4),
#  ('worthless', 4),
#  ('own', 4),
#  ('correct', 4),
#  ('welcome', 4),
#  ('human', 4),
#  ('angry', 4),
#  ('pathetic', 4),
#  ('closest', 4),
#  ('difficult', 4),
#  ('mad', 4),
#  ('convenient', 4),
#  ('useless', 4),
#  ('main', 4),
#  ('unable', 4),
#  ('disappointing', 4),
#  ('unbelievable', 3),
#  ('overseas', 3),
#  ('okay', 3),
#  ('monthly', 3),
#  ('simple', 3),
#  ('local', 3),
#  ('old', 3),
#  ('biggest', 3),
#  ('unwilling', 3),
#  ('commercial', 3),
#  ('hard', 3),
#  ('crazy', 3),
#  ('unprofessional', 3),
#  ('excellent', 3),
#  ('frustrating', 3),
#  ('super', 3),
#  ('important', 3),
#  ('bigger', 3),
#  ('aware', 3),
#  ('ashamed', 3),
#  ('late', 3),
#  ('august', 3),
#  ('incompetent', 3),
#  ('largest', 3),
#  ('public', 3),
#  ('wise', 3),
#  ('afraid', 3),
#  ('unacceptable', 3),
#  ('polite', 3),
#  ('lower', 3),
#  ('knowledgeable', 3),
#  ('south', 3),
#  ('sudden', 3),
#  ('fair', 2),
#  ('corporate', 2),
#  ('obvious', 2),
#  ('prompt', 2),
#  ('worth', 2),
#  ('unreliable', 2),
#  ('careful', 2),
#  ('illegal', 2),
#  ('elderly', 2),
#  ('low', 2),
#  ('likely', 2),
#  ('whole', 2),
#  ('clean', 2),
#  ('special', 2),
#  ('senior', 2),
#  ('small', 2),
#  ('rid', 2),
#  ('slowest', 2),
#  ('criminal', 2),
#  ('trying', 2),
#  ('existent', 2),
#  ('progressive', 2),
#  ('comfortable', 2),
#  ('famous', 2),
#  ('smaller', 2),
#  ('easier', 2),
#  ('unresolved', 2),
#  ('slow', 2),
#  ('needless', 2),
#  ('obnoxious', 2),
#  ('pleasant', 2),
#  ('direct', 2),
#  ('complete', 2),
#  ('unsure', 2),
#  ('associate', 2),
#  ('careless', 2),
#  ('serious', 2),
#  ('responsible', 2),
#  ('annoying', 2),
#  ('reliable', 2),
#  ('reasonable', 2),
#  ('international', 2),
#  ('absurd', 2),
#  ('flat', 2),
#  ('calm', 2),
#  ('gay', 2),
#  ('shocking', 2),
#  ('inconvenient', 2),
#  ('wonderful', 2),
#  ('little', 2),
#  ('cool', 2),
#  ('large', 2),
#  ('dead', 2),
#  ('double', 2),
#  ('extra', 2),
#  ('unfriendly', 2),
#  ('safe', 2),
#  ('appreciative', 1),
#  ('attendant', 1),
#  ('unpaid', 1),
#  ('strong', 1),
#  ('apologetic', 1),
#  ('silly', 1),
#  ('reluctant', 1),
#  ('initial', 1),
#  ('unsatisfactory', 1),
#  ('colder', 1),
#  ('entire', 1),
#  ('hungry', 1),
#  ('medical', 1),
#  ('active', 1),
#  ('dumb', 1),
#  ('shoddy', 1),
#  ('alive', 1),
#  ('practical', 1),
#  ('minimum', 1),
#  ('nonexistent', 1),
#  ('offensive', 1),
#  ('cute', 1),
#  ('temporary', 1),
#  ('national', 1),
#  ('federal', 1),
#  ('quarterly', 1),
#  ('false', 1),
#  ('disgusting', 1),
#  ('using', 1),
#  ('deficient', 1),
#  ('cautious', 1),
#  ('deceitful', 1),
#  ('ideal', 1),
#  ('round', 1),
#  ('western', 1),
#  ('shady', 1),
#  ('lazy', 1),
#  ('principal', 1),
#  ('harder', 1),
#  ('dear', 1),
#  ('certain', 1),
#  ('short', 1),
#  ('happiest', 1),
#  ('happier', 1),
#  ('slick', 1),
#  ('moving', 1),
#  ('friendly', 1),
#  ('obscene', 1),
#  ('unusual', 1),
#  ('cheery', 1),
#  ('loud', 1),
#  ('impersonal', 1),
#  ('further', 1),
#  ('overall', 1),
#  ('adamant', 1),
#  ('blue', 1),
#  ('mobile', 1),
#  ('blind', 1),
#  ('busy', 1),
#  ('irate', 1),
#  ('unsuccessful', 1),
#  ('breezy', 1),
#  ('consistent', 1),
#  ('sweet', 1),
#  ('private', 1),
#  ('cherry', 1),
#  ('unappreciated', 1),
#  ('healthier', 1),
#  ('live', 1),
#  ('permanent', 1),
#  ('later', 1),
#  ('ignorant', 1),
#  ('particular', 1),
#  ('alert', 1),
#  ('regional', 1),
#  ('curious', 1),
#  ('infuriating', 1),
#  ('horrid', 1),
#  ('poorest', 1),
#  ('horrifying', 1),
#  ('prohibitive', 1),
#  ('undesirable', 1),
#  ('deeper', 1),
#  ('nighted', 1),
#  ('older', 1),
#  ('total', 1),
#  ('honest', 1),
#  ('damn', 1),
#  ('opposite', 1),
#  ('modern', 1),
#  ('exact', 1),
#  ('vigilant', 1),
#  ('loose', 1),
#  ('astronomical', 1),
#  ('similar', 1),
#  ('necessary', 1),
#  ('rotten', 1),
#  ('loyal', 1),
#  ('profitable', 1),
#  ('sensitive', 1),
#  ('official', 1),
#  ('mediocre', 1),
#  ('greater', 1),
#  ('dangerous', 1),
#  ('common', 1),
#  ('highest', 1),
#  ('lousy', 1),
#  ('ethical', 1),
#  ('boundless', 1),
#  ('early', 1),
#  ('giant', 1),
#  ('multiple', 1),
#  ('effective', 1),
#  ('lowest', 1),
#  ('unclear', 1),
#  ('superior', 1),
#  ('uneducated', 1),
#  ('slower', 1),
#  ('wretched', 1),
#  ('questionable', 1),
#  ('corrupt', 1),
#  ('random', 1),
#  ('pitiful', 1),
#  ('successful', 1),
#  ('heartless', 1),
#  ('high', 1),
#  ('untrue', 1),
#  ('interesting', 1),
#  ('normal', 1),
#  ('sneaky', 1),
#  ('fine', 1),
#  ('proper', 1),
#  ('empty', 1),
#  ('nearest', 1),
#  ('cold', 1),
#  ('unavailable', 1),
#  ('generous', 1),
#  ('regular', 1),
#  ('overwhelming', 1),
#  ('arrogant', 1),
#  ('exceptional', 1),
#  ('legal', 1),
#  ('comparable', 1),
#  ('vocal', 1),
#  ('disinterested', 1)]

# %% [markdown]
# ## Bank Advisory Services

# %%
df_bank_advising = pd.read_csv("data/advising.csv", index_col="AutoID")
print(df_bank_advising.describe())
df_bank_advising.head()
# Out:
#               Year      Month
# count    80.000000  80.000000
# mean   2014.287500   7.775000
# std       0.455452   3.939334
# min    2014.000000   1.000000
# 25%    2014.000000   3.000000
# 50%    2014.000000   9.000000
# 75%    2015.000000  11.000000
# max    2015.000000  12.000000
#               Date  Year  Month MediaType  \
# AutoID
# 61278    8/28/2014  2014      8  facebook
# 62051    2/10/2015  2015      2  facebook
# 68422     8/5/2014  2014      8  facebook
# 68850   12/26/2014  2014     12  facebook
# 70330   11/22/2014  2014     11  facebook
#
#                                                  FullText
# AutoID
# 61278   customers in line and  bank teller i hate Bank...
# 62051   Name you Nameor Namea bank teller Name reminds...
# 68422   anyone interested in a  hr bank teller positio...
# 68850   apparently eating a sweet potato while driving...
# 70330   at BankB line is almost out the door been stan...

# %%
for text in df_bank_advising["FullText"].iloc[:100]:
    print(text.strip())
    print(nltk.pos_tag(text.strip().split()))
    print()
# Out:
# customers in line and  bank teller i hate BankB in wilmington
# [('customers', 'NNS'), ('in', 'IN'), ('line', 'NN'), ('and', 'CC'), ('bank', 'NN'), ('teller', 'NN'), ('i', 'PRP'), ('hate', 'VBP'), ('BankB', 'NNP'), ('in', 'IN'), ('wilmington', 'NN')]
#
# Name you Nameor Namea bank teller Name reminds me of BankD and Name bank days community  Name you Nameor Namea bank teller community  Name you Nameor Namea bank teller
# [('Name', 'NNP'), ('you', 'PRP'), ('Nameor', 'NNP'), ('Namea', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('Name', 'NNP'), ('reminds', 'NNS'), ('me', 'PRP'), ('of', 'IN'), ('BankD', 'NNP'), ('and', 'CC'), ('Name', 'NNP'), ('bank', 'NN'), ('days', 'NNS'), ('community', 'NN'), ('Name', 'NNP'), ('you', 'PRP'), ('Nameor', 'NNP'), ('Namea', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('community', 'NN'), ('Name', 'NNP'), ('you', 'PRP'), ('Nameor', 'NNP'), ('Namea', 'NNP'), ('bank', 'NN'), ('teller', 'NN')]
#
# anyone interested in a  hr bank teller position for BankD bank message me asap thanks
# [('anyone', 'NN'), ('interested', 'VBD'), ('in', 'IN'), ('a', 'DT'), ('hr', 'NN'), ('bank', 'NN'), ('teller', 'NN'), ('position', 'NN'), ('for', 'IN'), ('BankD', 'NNP'), ('bank', 'NN'), ('message', 'NN'), ('me', 'PRP'), ('asap', 'VB'), ('thanks', 'NNS')]
#
# apparently eating a sweet potato while driving is not a common thing went to deposit our christmas gifts into BankDs truck fund account and the bank teller gave me a strange look and asked if i had a sweet potato on a plate ummm yes of course i do healthy fast food from home and my absolute favorite thing to eat this girl isnt gaining a pound this holiday season
# [('apparently', 'RB'), ('eating', 'VBG'), ('a', 'DT'), ('sweet', 'JJ'), ('potato', 'NN'), ('while', 'IN'), ('driving', 'VBG'), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('common', 'JJ'), ('thing', 'NN'), ('went', 'NN'), ('to', 'TO'), ('deposit', 'VB'), ('our', 'PRP$'), ('christmas', 'NNS'), ('gifts', 'NNS'), ('into', 'IN'), ('BankDs', 'NNP'), ('truck', 'NN'), ('fund', 'NN'), ('account', 'NN'), ('and', 'CC'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('gave', 'VBD'), ('me', 'PRP'), ('a', 'DT'), ('strange', 'NN'), ('look', 'NN'), ('and', 'CC'), ('asked', 'VBD'), ('if', 'IN'), ('i', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('sweet', 'JJ'), ('potato', 'NN'), ('on', 'IN'), ('a', 'DT'), ('plate', 'NN'), ('ummm', 'NN'), ('yes', 'NNS'), ('of', 'IN'), ('course', 'NN'), ('i', 'PRP'), ('do', 'VBP'), ('healthy', 'JJ'), ('fast', 'NN'), ('food', 'NN'), ('from', 'IN'), ('home', 'NN'), ('and', 'CC'), ('my', 'PRP$'), ('absolute', 'NN'), ('favorite', 'NN'), ('thing', 'NN'), ('to', 'TO'), ('eat', 'VB'), ('this', 'DT'), ('girl', 'NN'), ('isnt', 'NN'), ('gaining', 'VBG'), ('a', 'DT'), ('pound', 'NN'), ('this', 'DT'), ('holiday', 'NN'), ('season', 'NN')]
#
# at BankB line is almost out the door been standing in line for  minutes watching one bank teller work and two tellers walk around the line asking if people are ok what can i help you with does that make good business since why not all three behind the counter
# [('at', 'IN'), ('BankB', 'NNP'), ('line', 'NN'), ('is', 'VBZ'), ('almost', 'RB'), ('out', 'IN'), ('the', 'DT'), ('door', 'NN'), ('been', 'VBN'), ('standing', 'VBG'), ('in', 'IN'), ('line', 'NN'), ('for', 'IN'), ('minutes', 'NNS'), ('watching', 'VBG'), ('one', 'CD'), ('bank', 'NN'), ('teller', 'NN'), ('work', 'NN'), ('and', 'CC'), ('two', 'CD'), ('tellers', 'NNS'), ('walk', 'VBP'), ('around', 'IN'), ('the', 'DT'), ('line', 'NN'), ('asking', 'VBG'), ('if', 'IN'), ('people', 'NNS'), ('are', 'VBP'), ('ok', 'JJ'), ('what', 'WP'), ('can', 'MD'), ('i', 'VB'), ('help', 'VB'), ('you', 'PRP'), ('with', 'IN'), ('does', 'VBZ'), ('that', 'IN'), ('make', 'VB'), ('good', 'JJ'), ('business', 'NN'), ('since', 'IN'), ('why', 'WRB'), ('not', 'RB'), ('all', 'DT'), ('three', 'CD'), ('behind', 'IN'), ('the', 'DT'), ('counter', 'NN')]
#
# bank teller at BankA i can tell your in sales by the way you dress volada
# [('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('i', 'PRP'), ('can', 'MD'), ('tell', 'VB'), ('your', 'PRP$'), ('in', 'IN'), ('sales', 'NNS'), ('by', 'IN'), ('the', 'DT'), ('way', 'NN'), ('you', 'PRP'), ('dress', 'VBZ'), ('volada', 'NN')]
#
# bank teller at BankA is a moron who cashes an insurance claims check in all s
# [('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('moron', 'NN'), ('who', 'WP'), ('cashes', 'NNS'), ('an', 'DT'), ('insurance', 'NN'), ('claims', 'VBZ'), ('check', 'NN'), ('in', 'IN'), ('all', 'DT'), ('s', 'NNS')]
#
# bank teller at BankA just flirted with me and then followed up by giving me a blue raspberry dumdum husbandmaterial orhethinksimalittlegirl
# [('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('just', 'RB'), ('flirted', 'VBD'), ('with', 'IN'), ('me', 'PRP'), ('and', 'CC'), ('then', 'RB'), ('followed', 'VBD'), ('up', 'RP'), ('by', 'IN'), ('giving', 'NN'), ('me', 'PRP'), ('a', 'DT'), ('blue', 'JJ'), ('raspberry', 'NN'), ('dumdum', 'NN'), ('husbandmaterial', 'NN'), ('orhethinksimalittlegirl', 'NN')]
#
# bank teller at BankA tryna flirt lol
# [('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('tryna', 'NN'), ('flirt', 'NN'), ('lol', 'NN')]
#
# beware of the translators or bank tellers in general working at this bank undoubtedly they allow thier employees to exchange numbers and hookup with customers i am speaking from personal experience the father of my child a spanish manName manuel melendez  keep in mind i am pregnant with another one of our children he met a woman a tellersummer kuzmawho translates at BankA on edgewater and pass rd in biloxi ms he gave her his number and they began to communicate several times a day when he then broke off our relationship i obtained her number from his phone and confronted her she put a different spin on it she lied to her employer they are supposed to be doing a clearly non existent investigation she also has obtained another customerName floresnumber she lied and said she was ministering to Name rebanke everyday  times a day shevis a single parent to  children  of which she cares for and works as a translator at boost mobile as well oh and she is a white american girl so i am just saying ladies if you have any question about the banke of your boyfriends fiances or husbands this company is not professional i would keep your business to bankes this one does not care about thier employees looking to fornicate with your loved ones
# [('beware', 'NN'), ('of', 'IN'), ('the', 'DT'), ('translators', 'NNS'), ('or', 'CC'), ('bank', 'NN'), ('tellers', 'NNS'), ('in', 'IN'), ('general', 'JJ'), ('working', 'NN'), ('at', 'IN'), ('this', 'DT'), ('bank', 'NN'), ('undoubtedly', 'RB'), ('they', 'PRP'), ('allow', 'VBP'), ('thier', 'RBR'), ('employees', 'NNS'), ('to', 'TO'), ('exchange', 'VB'), ('numbers', 'NNS'), ('and', 'CC'), ('hookup', 'VB'), ('with', 'IN'), ('customers', 'NNS'), ('i', 'PRP'), ('am', 'VBP'), ('speaking', 'VBG'), ('from', 'IN'), ('personal', 'JJ'), ('experience', 'NN'), ('the', 'DT'), ('father', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('child', 'NN'), ('a', 'DT'), ('spanish', 'JJ'), ('manName', 'NNP'), ('manuel', 'NN'), ('melendez', 'NN'), ('keep', 'VB'), ('in', 'IN'), ('mind', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('pregnant', 'JJ'), ('with', 'IN'), ('another', 'DT'), ('one', 'CD'), ('of', 'IN'), ('our', 'PRP$'), ('children', 'NNS'), ('he', 'PRP'), ('met', 'VBD'), ('a', 'DT'), ('woman', 'NN'), ('a', 'DT'), ('tellersummer', 'NN'), ('kuzmawho', 'WP'), ('translates', 'NNS'), ('at', 'IN'), ('BankA', 'NNP'), ('on', 'IN'), ('edgewater', 'NN'), ('and', 'CC'), ('pass', 'NN'), ('rd', 'NN'), ('in', 'IN'), ('biloxi', 'NN'), ('ms', 'NNS'), ('he', 'PRP'), ('gave', 'VBD'), ('her', 'PRP'), ('his', 'PRP$'), ('number', 'NN'), ('and', 'CC'), ('they', 'PRP'), ('began', 'VBD'), ('to', 'TO'), ('communicate', 'VB'), ('several', 'JJ'), ('times', 'NNS'), ('a', 'DT'), ('day', 'NN'), ('when', 'WRB'), ('he', 'PRP'), ('then', 'RB'), ('broke', 'VB'), ('off', 'RP'), ('our', 'PRP$'), ('relationship', 'NN'), ('i', 'PRP'), ('obtained', 'VBD'), ('her', 'PRP'), ('number', 'NN'), ('from', 'IN'), ('his', 'PRP$'), ('phone', 'NN'), ('and', 'CC'), ('confronted', 'VBD'), ('her', 'PRP'), ('she', 'PRP'), ('put', 'VBD'), ('a', 'DT'), ('different', 'JJ'), ('spin', 'NN'), ('on', 'IN'), ('it', 'PRP'), ('she', 'PRP'), ('lied', 'VBD'), ('to', 'TO'), ('her', 'PRP$'), ('employer', 'NN'), ('they', 'PRP'), ('are', 'VBP'), ('supposed', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('doing', 'VBG'), ('a', 'DT'), ('clearly', 'RB'), ('non', 'NN'), ('existent', 'NN'), ('investigation', 'NN'), ('she', 'PRP'), ('also', 'RB'), ('has', 'VBZ'), ('obtained', 'VBN'), ('another', 'DT'), ('customerName', 'NNP'), ('floresnumber', 'NN'), ('she', 'PRP'), ('lied', 'VBD'), ('and', 'CC'), ('said', 'VBD'), ('she', 'PRP'), ('was', 'VBD'), ('ministering', 'VBG'), ('to', 'TO'), ('Name', 'NNP'), ('rebanke', 'NN'), ('everyday', 'NN'), ('times', 'NNS'), ('a', 'DT'), ('day', 'NN'), ('shevis', 'VBZ'), ('a', 'DT'), ('single', 'JJ'), ('parent', 'NN'), ('to', 'TO'), ('children', 'NNS'), ('of', 'IN'), ('which', 'WDT'), ('she', 'PRP'), ('cares', 'VBZ'), ('for', 'IN'), ('and', 'CC'), ('works', 'NNS'), ('as', 'IN'), ('a', 'DT'), ('translator', 'NN'), ('at', 'IN'), ('boost', 'NN'), ('mobile', 'NN'), ('as', 'IN'), ('well', 'RB'), ('oh', 'JJ'), ('and', 'CC'), ('she', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('white', 'JJ'), ('american', 'NN'), ('girl', 'NN'), ('so', 'RB'), ('i', 'PRP'), ('am', 'VBP'), ('just', 'RB'), ('saying', 'VBG'), ('ladies', 'NNS'), ('if', 'IN'), ('you', 'PRP'), ('have', 'VBP'), ('any', 'DT'), ('question', 'NN'), ('about', 'IN'), ('the', 'DT'), ('banke', 'NN'), ('of', 'IN'), ('your', 'PRP$'), ('boyfriends', 'NNS'), ('fiances', 'NNS'), ('or', 'CC'), ('husbands', 'NNS'), ('this', 'DT'), ('company', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('professional', 'JJ'), ('i', 'PRP'), ('would', 'MD'), ('keep', 'VB'), ('your', 'PRP$'), ('business', 'NN'), ('to', 'TO'), ('bankes', 'NNS'), ('this', 'DT'), ('one', 'CD'), ('does', 'VBZ'), ('not', 'RB'), ('care', 'VB'), ('about', 'IN'), ('thier', 'JJR'), ('employees', 'NNS'), ('looking', 'VBG'), ('to', 'TO'), ('fornicate', 'VB'), ('with', 'IN'), ('your', 'PRP$'), ('loved', 'VBN'), ('ones', 'NNS')]
#
# Name faces tough new broadband tests bit ly Name faces tough new broadband tests BankD asset management stockport financial advisers  wealth managers
# [('Name', 'NNP'), ('faces', 'NNS'), ('tough', 'IN'), ('new', 'JJ'), ('broadband', 'NN'), ('tests', 'NNS'), ('bit', 'NN'), ('ly', 'RB'), ('Name', 'NNP'), ('faces', 'NNS'), ('tough', 'IN'), ('new', 'JJ'), ('broadband', 'NN'), ('tests', 'NNS'), ('BankD', 'NNP'), ('asset', 'NN'), ('management', 'NN'), ('stockport', 'NN'), ('financial', 'JJ'), ('advisers', 'NNS'), ('wealth', 'NN'), ('managers', 'NNS')]
#
# can anyone please get me donny bravos number it confirmed that BankB is next with id fraud Name they want me to confess more about lissette i forget her last name she does have a masters degree from phoenix university university no one would hire her and i did also why does antique Name make  million as a hsbc bank teller tell people please contact me on facebook
# [('can', 'MD'), ('anyone', 'NN'), ('please', 'VB'), ('get', 'NN'), ('me', 'PRP'), ('donny', 'VBP'), ('bravos', 'NNS'), ('number', 'NN'), ('it', 'PRP'), ('confirmed', 'VBD'), ('that', 'IN'), ('BankB', 'NNP'), ('is', 'VBZ'), ('next', 'JJ'), ('with', 'IN'), ('id', 'JJ'), ('fraud', 'NN'), ('Name', 'NNP'), ('they', 'PRP'), ('want', 'VBP'), ('me', 'PRP'), ('to', 'TO'), ('confess', 'VB'), ('more', 'JJR'), ('about', 'IN'), ('lissette', 'JJ'), ('i', 'NN'), ('forget', 'NN'), ('her', 'PRP$'), ('last', 'JJ'), ('name', 'NN'), ('she', 'PRP'), ('does', 'VBZ'), ('have', 'VB'), ('a', 'DT'), ('masters', 'NNS'), ('degree', 'VBP'), ('from', 'IN'), ('phoenix', 'CD'), ('university', 'NN'), ('university', 'NN'), ('no', 'DT'), ('one', 'NN'), ('would', 'MD'), ('hire', 'VB'), ('her', 'PRP'), ('and', 'CC'), ('i', 'PRP'), ('did', 'VBD'), ('also', 'RB'), ('why', 'WRB'), ('does', 'VBZ'), ('antique', 'JJ'), ('Name', 'NNP'), ('make', 'VBP'), ('million', 'CD'), ('as', 'IN'), ('a', 'DT'), ('hsbc', 'NN'), ('bank', 'NN'), ('teller', 'NN'), ('tell', 'NN'), ('people', 'NNS'), ('please', 'VB'), ('contact', 'NN'), ('me', 'PRP'), ('on', 'IN'), ('facebook', 'NN')]
#
# cant sleep Name applied for bank teller positions at both banke and BankB
# [('cant', 'NN'), ('sleep', 'NN'), ('Name', 'NNP'), ('applied', 'VBD'), ('for', 'IN'), ('bank', 'NN'), ('teller', 'NN'), ('positions', 'NNS'), ('at', 'IN'), ('both', 'DT'), ('banke', 'NN'), ('and', 'CC'), ('BankB', 'NNP')]
#
# BankD interview customer service representative service representative BankD interview customer service representative service representative we speak with a BankD bank teller about working at BankD and interviewing for a  read more
# [('BankD', 'NNP'), ('interview', 'VBD'), ('customer', 'NN'), ('service', 'NN'), ('representative', 'NN'), ('service', 'NN'), ('representative', 'NN'), ('BankD', 'NNP'), ('interview', 'NN'), ('customer', 'NN'), ('service', 'NN'), ('representative', 'NN'), ('service', 'NN'), ('representative', 'NN'), ('we', 'PRP'), ('speak', 'VBP'), ('with', 'IN'), ('a', 'DT'), ('BankD', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('about', 'IN'), ('working', 'VBG'), ('at', 'IN'), ('BankD', 'NNP'), ('and', 'CC'), ('interviewing', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('read', 'NN'), ('more', 'RBR')]
#
# BankD rebanke has to step their game up i just left a BankB and they have this atm bank teller machine that helps you and it is pretty awesome
# [('BankD', 'NNP'), ('rebanke', 'VBP'), ('has', 'VBZ'), ('to', 'TO'), ('step', 'VB'), ('their', 'PRP$'), ('game', 'NN'), ('up', 'RP'), ('i', 'PRP'), ('just', 'RB'), ('left', 'VBD'), ('a', 'DT'), ('BankB', 'NNP'), ('and', 'CC'), ('they', 'PRP'), ('have', 'VBP'), ('this', 'DT'), ('atm', 'NN'), ('bank', 'NN'), ('teller', 'NN'), ('machine', 'NN'), ('that', 'WDT'), ('helps', 'VBZ'), ('you', 'PRP'), ('and', 'CC'), ('it', 'PRP'), ('is', 'VBZ'), ('pretty', 'RB'), ('awesome', 'RB')]
#
# every time a  k run comes up i get selfconscious most of the time it just further prooves how out of shape i rebanke am for instance last time i ran it was for a  k little Name the bank teller know i only had  k in my account after a critical error on their part and me screaming ha ha the jokes on you fuckers not only did i successfully nail the  Name but had a sprint race out of BankA into the parking lot you shouldve seen it i looked like a white paraplegic girl hurtling the shrubbery as if somebody just said there is a pumpkin spice latte shortage in the middle of october needless to say i got my car fixed but if i had known the motherfucker was going to blow up a month later the only thing i would have ran was my piece of shit jeep into a pole
# [('every', 'DT'), ('time', 'NN'), ('a', 'DT'), ('k', 'NN'), ('run', 'VBN'), ('comes', 'NNS'), ('up', 'IN'), ('i', 'PRP'), ('get', 'VBP'), ('selfconscious', 'JJ'), ('most', 'JJS'), ('of', 'IN'), ('the', 'DT'), ('time', 'NN'), ('it', 'PRP'), ('just', 'RB'), ('further', 'RB'), ('prooves', 'VBZ'), ('how', 'WRB'), ('out', 'RP'), ('of', 'IN'), ('shape', 'NN'), ('i', 'PRP'), ('rebanke', 'VBP'), ('am', 'VBP'), ('for', 'IN'), ('instance', 'NN'), ('last', 'JJ'), ('time', 'NN'), ('i', 'PRP'), ('ran', 'VBD'), ('it', 'PRP'), ('was', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('k', 'NN'), ('little', 'NN'), ('Name', 'NNP'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('know', 'VB'), ('i', 'PRP'), ('only', 'RB'), ('had', 'VBD'), ('k', 'NN'), ('in', 'IN'), ('my', 'PRP$'), ('account', 'NN'), ('after', 'IN'), ('a', 'DT'), ('critical', 'JJ'), ('error', 'NN'), ('on', 'IN'), ('their', 'PRP$'), ('part', 'NN'), ('and', 'CC'), ('me', 'PRP'), ('screaming', 'VBG'), ('ha', 'NN'), ('ha', 'NN'), ('the', 'DT'), ('jokes', 'NNS'), ('on', 'IN'), ('you', 'PRP'), ('fuckers', 'NNS'), ('not', 'RB'), ('only', 'RB'), ('did', 'VBD'), ('i', 'PRP'), ('successfully', 'RB'), ('nail', 'JJ'), ('the', 'DT'), ('Name', 'NNP'), ('but', 'CC'), ('had', 'VBD'), ('a', 'DT'), ('sprint', 'NN'), ('race', 'NN'), ('out', 'IN'), ('of', 'IN'), ('BankA', 'NNP'), ('into', 'IN'), ('the', 'DT'), ('parking', 'NN'), ('lot', 'NN'), ('you', 'PRP'), ('shouldve', 'VBP'), ('seen', 'VBN'), ('it', 'PRP'), ('i', 'PRP'), ('looked', 'VBD'), ('like', 'IN'), ('a', 'DT'), ('white', 'JJ'), ('paraplegic', 'NN'), ('girl', 'NN'), ('hurtling', 'VBG'), ('the', 'DT'), ('shrubbery', 'NN'), ('as', 'IN'), ('if', 'IN'), ('somebody', 'NN'), ('just', 'RB'), ('said', 'VBD'), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('pumpkin', 'NN'), ('spice', 'NN'), ('latte', 'NN'), ('shortage', 'NN'), ('in', 'IN'), ('the', 'DT'), ('middle', 'NN'), ('of', 'IN'), ('october', 'NN'), ('needless', 'NN'), ('to', 'TO'), ('say', 'VB'), ('i', 'PRP'), ('got', 'VBD'), ('my', 'PRP$'), ('car', 'NN'), ('fixed', 'VBN'), ('but', 'CC'), ('if', 'IN'), ('i', 'PRP'), ('had', 'VBD'), ('known', 'VBN'), ('the', 'DT'), ('motherfucker', 'NN'), ('was', 'VBD'), ('going', 'VBG'), ('to', 'TO'), ('blow', 'VB'), ('up', 'RP'), ('a', 'DT'), ('month', 'NN'), ('later', 'JJ'), ('the', 'DT'), ('only', 'JJ'), ('thing', 'NN'), ('i', 'PRP'), ('would', 'MD'), ('have', 'VB'), ('ran', 'JJ'), ('was', 'NNS'), ('my', 'PRP$'), ('piece', 'NN'), ('of', 'IN'), ('shit', 'NN'), ('jeep', 'NN'), ('into', 'IN'), ('a', 'DT'), ('pole', 'JJ')]
#
# exunited boss sir Name Name raked in more than    m last year in his role as global ambassador bit ly Name boss sir Name Name raked in more than    m last year in his role as global ambassador BankD asset management stockport financial advisers  wealth managers
# [('exunited', 'VBD'), ('boss', 'NNS'), ('sir', 'VBP'), ('Name', 'NNP'), ('Name', 'NNP'), ('raked', 'VBD'), ('in', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('m', 'NN'), ('last', 'JJ'), ('year', 'NN'), ('in', 'IN'), ('his', 'PRP$'), ('role', 'NN'), ('as', 'IN'), ('global', 'JJ'), ('ambassador', 'NN'), ('bit', 'NN'), ('ly', 'RB'), ('Name', 'NNP'), ('boss', 'NN'), ('sir', 'NN'), ('Name', 'NNP'), ('Name', 'NNP'), ('raked', 'VBD'), ('in', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('m', 'NN'), ('last', 'JJ'), ('year', 'NN'), ('in', 'IN'), ('his', 'PRP$'), ('role', 'NN'), ('as', 'IN'), ('global', 'JJ'), ('ambassador', 'NN'), ('BankD', 'NNP'), ('asset', 'NN'), ('management', 'NN'), ('stockport', 'NN'), ('financial', 'JJ'), ('advisers', 'NNS'), ('wealth', 'NN'), ('managers', 'NNS')]
#
# f BankD worst customer service ever im so annoyed im going corporate only cause the supposed manager lied to me he was a bank teller grr thats why i love my BankAwhatever going to the kern this weekend woo that should relieve some stress
# [('f', 'NN'), ('BankD', 'NNP'), ('worst', 'NN'), ('customer', 'NN'), ('service', 'NN'), ('ever', 'RB'), ('im', 'VB'), ('so', 'RB'), ('annoyed', 'VBN'), ('im', 'NN'), ('going', 'VBG'), ('corporate', 'JJ'), ('only', 'RB'), ('cause', 'VBP'), ('the', 'DT'), ('supposed', 'VBN'), ('manager', 'NN'), ('lied', 'VBN'), ('to', 'TO'), ('me', 'PRP'), ('he', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('grr', 'NN'), ('thats', 'NNS'), ('why', 'WRB'), ('i', 'PRP'), ('love', 'VBP'), ('my', 'PRP$'), ('BankAwhatever', 'NNP'), ('going', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('kern', 'NN'), ('this', 'DT'), ('weekend', 'NN'), ('woo', 'NN'), ('that', 'WDT'), ('should', 'MD'), ('relieve', 'VB'), ('some', 'DT'), ('stress', 'NN')]
#
# got bad news and good news today my sisters gift was lost in delivery         but i hooked an interview with BankA  for a bank teller position   hopefully everyone will be getting better gifts if this case runs by smoothly lol pray for me you guys pray blessed fingerscrossed
# [('got', 'VBD'), ('bad', 'JJ'), ('news', 'NN'), ('and', 'CC'), ('good', 'JJ'), ('news', 'NN'), ('today', 'NN'), ('my', 'PRP$'), ('sisters', 'NNS'), ('gift', 'NN'), ('was', 'VBD'), ('lost', 'VBN'), ('in', 'IN'), ('delivery', 'NN'), ('but', 'CC'), ('i', 'PRP'), ('hooked', 'VBD'), ('an', 'DT'), ('interview', 'NN'), ('with', 'IN'), ('BankA', 'NNP'), ('for', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('position', 'NN'), ('hopefully', 'RB'), ('everyone', 'NN'), ('will', 'MD'), ('be', 'VB'), ('getting', 'VBG'), ('better', 'JJR'), ('gifts', 'NNS'), ('if', 'IN'), ('this', 'DT'), ('case', 'NN'), ('runs', 'VBZ'), ('by', 'IN'), ('smoothly', 'RB'), ('lol', 'NN'), ('pray', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('you', 'PRP'), ('guys', 'VBZ'), ('pray', 'VBP'), ('blessed', 'VBN'), ('fingerscrossed', 'VBN')]
#
# guess whos ur next BankA bank teller hhahaha so freakin happy november is the best month of  so far
# [('guess', 'NN'), ('whos', 'NNS'), ('ur', 'VBP'), ('next', 'JJ'), ('BankA', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('hhahaha', 'NN'), ('so', 'RB'), ('freakin', 'IN'), ('happy', 'JJ'), ('november', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('month', 'NN'), ('of', 'IN'), ('so', 'RB'), ('far', 'RB')]
#
# Name secures tenant for  Name court bit ly Name secures tenant for  Name court BankD asset management stockport financial advisers  wealth managers
# [('Name', 'NNP'), ('secures', 'NNS'), ('tenant', 'VBP'), ('for', 'IN'), ('Name', 'NNP'), ('court', 'NN'), ('bit', 'NN'), ('ly', 'RB'), ('Name', 'NNP'), ('secures', 'NNS'), ('tenant', 'VBP'), ('for', 'IN'), ('Name', 'NNP'), ('court', 'NN'), ('BankD', 'NNP'), ('asset', 'NN'), ('management', 'NN'), ('stockport', 'NN'), ('financial', 'JJ'), ('advisers', 'NNS'), ('wealth', 'NN'), ('managers', 'NNS')]
#
# help for the corry family Name you would like to donate to the corry family you can either visit a BankA location and or transfer money donations online using the following account and Name Name account  and routing  if you visit a BankA location the bank teller will be able to identify the account as the Name  Name corry donation fund fund
# [('help', 'NN'), ('for', 'IN'), ('the', 'DT'), ('corry', 'NN'), ('family', 'NN'), ('Name', 'NNP'), ('you', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('donate', 'VB'), ('to', 'TO'), ('the', 'DT'), ('corry', 'NN'), ('family', 'NN'), ('you', 'PRP'), ('can', 'MD'), ('either', 'VB'), ('visit', 'NN'), ('a', 'DT'), ('BankA', 'NNP'), ('location', 'NN'), ('and', 'CC'), ('or', 'CC'), ('transfer', 'VB'), ('money', 'NN'), ('donations', 'NNS'), ('online', 'VBP'), ('using', 'VBG'), ('the', 'DT'), ('following', 'VBG'), ('account', 'NN'), ('and', 'CC'), ('Name', 'NNP'), ('Name', 'NNP'), ('account', 'NN'), ('and', 'CC'), ('routing', 'VBG'), ('if', 'IN'), ('you', 'PRP'), ('visit', 'VBP'), ('a', 'DT'), ('BankA', 'NNP'), ('location', 'NN'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('will', 'MD'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('identify', 'VB'), ('the', 'DT'), ('account', 'NN'), ('as', 'IN'), ('the', 'DT'), ('Name', 'NNP'), ('Name', 'NNP'), ('corry', 'NN'), ('donation', 'NN'), ('fund', 'NN'), ('fund', 'NN')]
#
# hi Name gone to  different BankB atms and have asked the bank teller for help as well but to no successthey said their machines cant read the chip and can only process withdrawals with cards with magnetic strip how then help
# [('hi', 'NN'), ('Name', 'NNP'), ('gone', 'NN'), ('to', 'TO'), ('different', 'JJ'), ('BankB', 'NNP'), ('atms', 'NNS'), ('and', 'CC'), ('have', 'VBP'), ('asked', 'VBN'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('for', 'IN'), ('help', 'NN'), ('as', 'IN'), ('well', 'RB'), ('but', 'CC'), ('to', 'TO'), ('no', 'DT'), ('successthey', 'NN'), ('said', 'VBD'), ('their', 'PRP$'), ('machines', 'NNS'), ('cant', 'VBP'), ('read', 'JJ'), ('the', 'DT'), ('chip', 'NN'), ('and', 'CC'), ('can', 'MD'), ('only', 'RB'), ('process', 'VB'), ('withdrawals', 'NNS'), ('with', 'IN'), ('cards', 'NNS'), ('with', 'IN'), ('magnetic', 'JJ'), ('strip', 'NN'), ('how', 'WRB'), ('then', 'RB'), ('help', 'VB')]
#
# i feel very good about one of ourBankDbanks which is located on country club drive in palm Name Name it is just down the street from us i have been saving all my pocket change foryears now carol and i decided to deposit Name all of it into a savings account we knew it would be a job Name labor to roll it all up when we told the bank teller about the problem she said since we had an account in good standing they would do it for us for free so we took it all Name and deposited into a new savings account this is a personal thanks you to everyone at that branch goodbye BankB BankD Name it better coin star sucks they take   away to be able to use their service which cheats
# [('i', 'PRP'), ('feel', 'VBP'), ('very', 'RB'), ('good', 'JJ'), ('about', 'IN'), ('one', 'CD'), ('of', 'IN'), ('ourBankDbanks', 'NNP'), ('which', 'WDT'), ('is', 'VBZ'), ('located', 'VBN'), ('on', 'IN'), ('country', 'NN'), ('club', 'NN'), ('drive', 'VBP'), ('in', 'IN'), ('palm', 'NN'), ('Name', 'NNP'), ('Name', 'NNP'), ('it', 'PRP'), ('is', 'VBZ'), ('just', 'RB'), ('down', 'RB'), ('the', 'DT'), ('street', 'NN'), ('from', 'IN'), ('us', 'PRP'), ('i', 'PRP'), ('have', 'VBP'), ('been', 'VBN'), ('saving', 'VBG'), ('all', 'DT'), ('my', 'PRP$'), ('pocket', 'NN'), ('change', 'NN'), ('foryears', 'NNS'), ('now', 'RB'), ('carol', 'NN'), ('and', 'CC'), ('i', 'PRP'), ('decided', 'VBD'), ('to', 'TO'), ('deposit', 'VB'), ('Name', 'NNP'), ('all', 'DT'), ('of', 'IN'), ('it', 'PRP'), ('into', 'IN'), ('a', 'DT'), ('savings', 'NNS'), ('account', 'NN'), ('we', 'PRP'), ('knew', 'VBD'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('a', 'DT'), ('job', 'NN'), ('Name', 'NNP'), ('labor', 'NN'), ('to', 'TO'), ('roll', 'VB'), ('it', 'PRP'), ('all', 'DT'), ('up', 'RP'), ('when', 'WRB'), ('we', 'PRP'), ('told', 'VBD'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('about', 'IN'), ('the', 'DT'), ('problem', 'NN'), ('she', 'PRP'), ('said', 'VBD'), ('since', 'IN'), ('we', 'PRP'), ('had', 'VBD'), ('an', 'DT'), ('account', 'NN'), ('in', 'IN'), ('good', 'JJ'), ('standing', 'NN'), ('they', 'PRP'), ('would', 'MD'), ('do', 'VB'), ('it', 'PRP'), ('for', 'IN'), ('us', 'PRP'), ('for', 'IN'), ('free', 'RB'), ('so', 'RB'), ('we', 'PRP'), ('took', 'VBD'), ('it', 'PRP'), ('all', 'RB'), ('Name', 'NNP'), ('and', 'CC'), ('deposited', 'VBD'), ('into', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('savings', 'NNS'), ('account', 'VBP'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('personal', 'JJ'), ('thanks', 'NNS'), ('you', 'PRP'), ('to', 'TO'), ('everyone', 'VB'), ('at', 'IN'), ('that', 'DT'), ('branch', 'NN'), ('goodbye', 'NN'), ('BankB', 'NNP'), ('BankD', 'NNP'), ('Name', 'NNP'), ('it', 'PRP'), ('better', 'JJR'), ('coin', 'NN'), ('star', 'NN'), ('sucks', 'NNS'), ('they', 'PRP'), ('take', 'VBP'), ('away', 'RP'), ('to', 'TO'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('use', 'VB'), ('their', 'PRP$'), ('service', 'NN'), ('which', 'WDT'), ('cheats', 'NNS')]
#
# i have service with BankA for many years and service is great but when u get to the point of apply for a car loan or house one is sad that ur own bank teller send u to a different one because ur own rates are to high san i had an account for so long and i couldnt get a good deal i had to open an account in a banke and get everything faster and cheaper disappointed
# [('i', 'PRP'), ('have', 'VBP'), ('service', 'NN'), ('with', 'IN'), ('BankA', 'NNP'), ('for', 'IN'), ('many', 'JJ'), ('years', 'NNS'), ('and', 'CC'), ('service', 'NN'), ('is', 'VBZ'), ('great', 'JJ'), ('but', 'CC'), ('when', 'WRB'), ('u', 'NN'), ('get', 'NN'), ('to', 'TO'), ('the', 'DT'), ('point', 'NN'), ('of', 'IN'), ('apply', 'RB'), ('for', 'IN'), ('a', 'DT'), ('car', 'NN'), ('loan', 'NN'), ('or', 'CC'), ('house', 'NN'), ('one', 'CD'), ('is', 'VBZ'), ('sad', 'JJ'), ('that', 'IN'), ('ur', 'NN'), ('own', 'JJ'), ('bank', 'NN'), ('teller', 'NN'), ('send', 'NN'), ('u', 'NN'), ('to', 'TO'), ('a', 'DT'), ('different', 'JJ'), ('one', 'CD'), ('because', 'IN'), ('ur', 'NN'), ('own', 'JJ'), ('rates', 'NNS'), ('are', 'VBP'), ('to', 'TO'), ('high', 'JJ'), ('san', 'NN'), ('i', 'PRP'), ('had', 'VBD'), ('an', 'DT'), ('account', 'NN'), ('for', 'IN'), ('so', 'RB'), ('long', 'RB'), ('and', 'CC'), ('i', 'PRP'), ('couldnt', 'VBP'), ('get', 'VB'), ('a', 'DT'), ('good', 'JJ'), ('deal', 'NN'), ('i', 'PRP'), ('had', 'VBD'), ('to', 'TO'), ('open', 'VB'), ('an', 'DT'), ('account', 'NN'), ('in', 'IN'), ('a', 'DT'), ('banke', 'NN'), ('and', 'CC'), ('get', 'VB'), ('everything', 'NN'), ('faster', 'JJR'), ('and', 'CC'), ('cheaper', 'JJR'), ('disappointed', 'JJ')]
#
# i just got hit on by a bank teller BankA  lol
# [('i', 'PRP'), ('just', 'RB'), ('got', 'VBD'), ('hit', 'VBN'), ('on', 'IN'), ('by', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('BankA', 'NNP'), ('lol', 'NN')]
#
# i kick it for fun i smile cause i be happy but the real Name i work for them crackers i have my own Name an i got plenty knowledge grandirmsga raised me she dead now so i missed out Name learning Name but thanks to god an my teachers Name i gave hell to every min on the clock til the bell ring til they kicked me out without my book bag lmao when i see them they said Name u got kids Name lord hope they dont be like Name was lmao but i said that to say this i got an interview this morning as a bank teller for BankD on university Name to scared to go Name Name the devil trying to kill Name u know god damn well them niggas robbing the bank i was just filling out application to try a neBankA ield in life an they called lmaooo its at  Name Name wants to play like they Name me an get the job cause i Name dare just Name Name stressful looking out for robberies
# [('i', 'PRP'), ('kick', 'VBP'), ('it', 'PRP'), ('for', 'IN'), ('fun', 'NN'), ('i', 'PRP'), ('smile', 'VBP'), ('cause', 'NN'), ('i', 'PRP'), ('be', 'VB'), ('happy', 'JJ'), ('but', 'CC'), ('the', 'DT'), ('real', 'JJ'), ('Name', 'NNP'), ('i', 'PRP'), ('work', 'VBP'), ('for', 'IN'), ('them', 'PRP'), ('crackers', 'NNS'), ('i', 'PRP'), ('have', 'VBP'), ('my', 'PRP$'), ('own', 'JJ'), ('Name', 'NNP'), ('an', 'DT'), ('i', 'PRP'), ('got', 'VBD'), ('plenty', 'JJ'), ('knowledge', 'NN'), ('grandirmsga', 'NN'), ('raised', 'VBD'), ('me', 'PRP'), ('she', 'PRP'), ('dead', 'VBD'), ('now', 'RB'), ('so', 'RB'), ('i', 'PRP'), ('missed', 'VBD'), ('out', 'RP'), ('Name', 'NNP'), ('learning', 'NN'), ('Name', 'NNP'), ('but', 'CC'), ('thanks', 'VBZ'), ('to', 'TO'), ('god', 'VB'), ('an', 'DT'), ('my', 'PRP$'), ('teachers', 'NNS'), ('Name', 'NNP'), ('i', 'PRP'), ('gave', 'VBD'), ('hell', 'RB'), ('to', 'TO'), ('every', 'DT'), ('min', 'NN'), ('on', 'IN'), ('the', 'DT'), ('clock', 'NN'), ('til', 'NN'), ('the', 'DT'), ('bell', 'NN'), ('ring', 'VBG'), ('til', 'NN'), ('they', 'PRP'), ('kicked', 'VBD'), ('me', 'PRP'), ('out', 'IN'), ('without', 'IN'), ('my', 'PRP$'), ('book', 'NN'), ('bag', 'NN'), ('lmao', 'NN'), ('when', 'WRB'), ('i', 'PRP'), ('see', 'VBP'), ('them', 'PRP'), ('they', 'PRP'), ('said', 'VBD'), ('Name', 'NNP'), ('u', 'NN'), ('got', 'VBD'), ('kids', 'NNS'), ('Name', 'NNP'), ('lord', 'NN'), ('hope', 'NN'), ('they', 'PRP'), ('dont', 'VBP'), ('be', 'VB'), ('like', 'IN'), ('Name', 'NNP'), ('was', 'VBD'), ('lmao', 'RB'), ('but', 'CC'), ('i', 'PRP'), ('said', 'VBD'), ('that', 'IN'), ('to', 'TO'), ('say', 'VB'), ('this', 'DT'), ('i', 'PRP'), ('got', 'VBD'), ('an', 'DT'), ('interview', 'NN'), ('this', 'DT'), ('morning', 'NN'), ('as', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('for', 'IN'), ('BankD', 'NNP'), ('on', 'IN'), ('university', 'NN'), ('Name', 'NNP'), ('to', 'TO'), ('scared', 'VBD'), ('to', 'TO'), ('go', 'VB'), ('Name', 'NNP'), ('Name', 'NNP'), ('the', 'DT'), ('devil', 'NN'), ('trying', 'VBG'), ('to', 'TO'), ('kill', 'VB'), ('Name', 'NNP'), ('u', 'NN'), ('know', 'VB'), ('god', 'NN'), ('damn', 'RB'), ('well', 'RB'), ('them', 'PRP'), ('niggas', 'VBZ'), ('robbing', 'VBG'), ('the', 'DT'), ('bank', 'NN'), ('i', 'PRP'), ('was', 'VBD'), ('just', 'RB'), ('filling', 'VBG'), ('out', 'RP'), ('application', 'NN'), ('to', 'TO'), ('try', 'VB'), ('a', 'DT'), ('neBankA', 'NNP'), ('ield', 'NN'), ('in', 'IN'), ('life', 'NN'), ('an', 'DT'), ('they', 'PRP'), ('called', 'VBD'), ('lmaooo', 'RB'), ('its', 'PRP$'), ('at', 'IN'), ('Name', 'NNP'), ('Name', 'NNP'), ('wants', 'VBZ'), ('to', 'TO'), ('play', 'VB'), ('like', 'IN'), ('they', 'PRP'), ('Name', 'NNP'), ('me', 'PRP'), ('an', 'DT'), ('get', 'NN'), ('the', 'DT'), ('job', 'NN'), ('cause', 'NN'), ('i', 'PRP'), ('Name', 'NNP'), ('dare', 'VBP'), ('just', 'RB'), ('Name', 'NNP'), ('Name', 'NNP'), ('stressful', 'JJ'), ('looking', 'VBG'), ('out', 'RP'), ('for', 'IN'), ('robberies', 'NNS')]
#
# i was called for jury duty and landed a check kiting case once i explained that i used to be a bank teller the defense couldnt kick me out fast enough thank you BankA
# [('i', 'PRP'), ('was', 'VBD'), ('called', 'VBN'), ('for', 'IN'), ('jury', 'NN'), ('duty', 'NN'), ('and', 'CC'), ('landed', 'VBD'), ('a', 'DT'), ('check', 'NN'), ('kiting', 'VBG'), ('case', 'NN'), ('once', 'RB'), ('i', 'PRP'), ('explained', 'VBD'), ('that', 'IN'), ('i', 'PRP'), ('used', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('the', 'DT'), ('defense', 'NN'), ('couldnt', 'NN'), ('kick', 'NN'), ('me', 'PRP'), ('out', 'RP'), ('fast', 'RB'), ('enough', 'RB'), ('thank', 'VB'), ('you', 'PRP'), ('BankA', 'NNP')]
#
# i went to BankD earlier to cash my check n y da bank teller wuz helping me the banke teller who takes care of da drive thru who was beautiful was just looking at me so i smiled at her and as soon as i smiled at her she started flirting with me i knew i could of got da number but since Name talking to somebody i didnt bother asking or even flirt BankB  Name getting old but i still got it
# [('i', 'PRP'), ('went', 'VBD'), ('to', 'TO'), ('BankD', 'NNP'), ('earlier', 'JJR'), ('to', 'TO'), ('cash', 'NN'), ('my', 'PRP$'), ('check', 'NN'), ('n', 'NN'), ('y', 'NN'), ('da', 'NN'), ('bank', 'NN'), ('teller', 'NN'), ('wuz', 'NN'), ('helping', 'VBG'), ('me', 'PRP'), ('the', 'DT'), ('banke', 'NN'), ('teller', 'NN'), ('who', 'WP'), ('takes', 'VBZ'), ('care', 'VBP'), ('of', 'IN'), ('da', 'NN'), ('drive', 'JJ'), ('thru', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('beautiful', 'JJ'), ('was', 'VBD'), ('just', 'RB'), ('looking', 'VBG'), ('at', 'IN'), ('me', 'PRP'), ('so', 'RB'), ('i', 'PRP'), ('smiled', 'VBD'), ('at', 'IN'), ('her', 'PRP$'), ('and', 'CC'), ('as', 'IN'), ('soon', 'RB'), ('as', 'IN'), ('i', 'PRP'), ('smiled', 'VBD'), ('at', 'IN'), ('her', 'PRP$'), ('she', 'PRP'), ('started', 'VBD'), ('flirting', 'VBG'), ('with', 'IN'), ('me', 'PRP'), ('i', 'PRP'), ('knew', 'VBD'), ('i', 'PRP'), ('could', 'MD'), ('of', 'IN'), ('got', 'NN'), ('da', 'NN'), ('number', 'NN'), ('but', 'CC'), ('since', 'IN'), ('Name', 'NNP'), ('talking', 'NN'), ('to', 'TO'), ('somebody', 'NN'), ('i', 'PRP'), ('didnt', 'VBP'), ('bother', 'RB'), ('asking', 'VBG'), ('or', 'CC'), ('even', 'RB'), ('flirt', 'NN'), ('BankB', 'NNP'), ('Name', 'NNP'), ('getting', 'VBG'), ('old', 'JJ'), ('but', 'CC'), ('i', 'PRP'), ('still', 'RB'), ('got', 'VBD'), ('it', 'PRP')]
#
# i wouldnt wanna be a bank teller right now at BankD downtown lmao
# [('i', 'PRP'), ('wouldnt', 'VBP'), ('wanna', 'NNS'), ('be', 'VB'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('right', 'RB'), ('now', 'RB'), ('at', 'IN'), ('BankD', 'NNP'), ('downtown', 'NN'), ('lmao', 'NN')]
#
# if i come into some real cash i am going to deposit in BankA and get with your financial advisers
# [('if', 'IN'), ('i', 'PRP'), ('come', 'VBP'), ('into', 'IN'), ('some', 'DT'), ('real', 'JJ'), ('cash', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('deposit', 'VB'), ('in', 'IN'), ('BankA', 'NNP'), ('and', 'CC'), ('get', 'VB'), ('with', 'IN'), ('your', 'PRP$'), ('financial', 'JJ'), ('advisers', 'NNS')]
#
# if you ever need excuse to fire victoria Name a bank teller in mn this is it she was unprofessional needs extra training gives BankA bad reputation
# [('if', 'IN'), ('you', 'PRP'), ('ever', 'RB'), ('need', 'VBP'), ('excuse', 'NN'), ('to', 'TO'), ('fire', 'VB'), ('victoria', 'NNS'), ('Name', 'NNP'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('in', 'IN'), ('mn', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('it', 'PRP'), ('she', 'PRP'), ('was', 'VBD'), ('unprofessional', 'JJ'), ('needs', 'NNS'), ('extra', 'JJ'), ('training', 'NN'), ('gives', 'VBZ'), ('BankA', 'NNP'), ('bad', 'JJ'), ('reputation', 'NN')]
#
# Name at BankA in naples and Name been offered a bottle water by three different employees Name in shock over how outgoing and polite these tellers are never in my  years with banks in Name Name has any bank teller there offered me a bottled water step up your game home team
# [('Name', 'NNP'), ('at', 'IN'), ('BankA', 'NNP'), ('in', 'IN'), ('naples', 'NNS'), ('and', 'CC'), ('Name', 'NNP'), ('been', 'IN'), ('offered', 'VBN'), ('a', 'DT'), ('bottle', 'NN'), ('water', 'NN'), ('by', 'IN'), ('three', 'CD'), ('different', 'JJ'), ('employees', 'NNS'), ('Name', 'NNP'), ('in', 'IN'), ('shock', 'NN'), ('over', 'IN'), ('how', 'WRB'), ('outgoing', 'VBG'), ('and', 'CC'), ('polite', 'JJ'), ('these', 'DT'), ('tellers', 'NNS'), ('are', 'VBP'), ('never', 'RB'), ('in', 'IN'), ('my', 'PRP$'), ('years', 'NNS'), ('with', 'IN'), ('banks', 'NNS'), ('in', 'IN'), ('Name', 'NNP'), ('Name', 'NNP'), ('has', 'VBZ'), ('any', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('there', 'EX'), ('offered', 'VBD'), ('me', 'PRP'), ('a', 'DT'), ('bottled', 'JJ'), ('water', 'NN'), ('step', 'NN'), ('up', 'IN'), ('your', 'PRP$'), ('game', 'NN'), ('home', 'NN'), ('team', 'NN')]
#
# Name pissed so all this time they been looking for the cali bandit he robs a bank gives the bank teller a note telling her this is no joke and i have a gun she gives him watt he want he leaves in a taxi the police get info hes in a taxi so during there BankD bank robber pushes the taxi driver out and he continues his BankD crashes the taxi hurts and injuries ppl in other car and tries to run did the police pulled there weapons out no was he shot no armed bank robber rite he wasnt shot because they never seen a gun mmmmm
# [('Name', 'NNP'), ('pissed', 'VBD'), ('so', 'RB'), ('all', 'DT'), ('this', 'DT'), ('time', 'NN'), ('they', 'PRP'), ('been', 'VBP'), ('looking', 'VBG'), ('for', 'IN'), ('the', 'DT'), ('cali', 'NN'), ('bandit', 'NN'), ('he', 'PRP'), ('robs', 'VBZ'), ('a', 'DT'), ('bank', 'NN'), ('gives', 'VBZ'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('a', 'DT'), ('note', 'NN'), ('telling', 'VBG'), ('her', 'PRP'), ('this', 'DT'), ('is', 'VBZ'), ('no', 'DT'), ('joke', 'NN'), ('and', 'CC'), ('i', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('gun', 'NN'), ('she', 'PRP'), ('gives', 'VBZ'), ('him', 'PRP'), ('watt', 'VBP'), ('he', 'PRP'), ('want', 'VBP'), ('he', 'PRP'), ('leaves', 'VBZ'), ('in', 'IN'), ('a', 'DT'), ('taxi', 'NN'), ('the', 'DT'), ('police', 'NN'), ('get', 'NN'), ('info', 'NN'), ('hes', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('taxi', 'NN'), ('so', 'IN'), ('during', 'IN'), ('there', 'EX'), ('BankD', 'NNP'), ('bank', 'NN'), ('robber', 'NN'), ('pushes', 'VBZ'), ('the', 'DT'), ('taxi', 'NN'), ('driver', 'NN'), ('out', 'IN'), ('and', 'CC'), ('he', 'PRP'), ('continues', 'VBZ'), ('his', 'PRP$'), ('BankD', 'NNP'), ('crashes', 'VBZ'), ('the', 'DT'), ('taxi', 'NN'), ('hurts', 'NNS'), ('and', 'CC'), ('injuries', 'NNS'), ('ppl', 'VBP'), ('in', 'IN'), ('other', 'JJ'), ('car', 'NN'), ('and', 'CC'), ('tries', 'NNS'), ('to', 'TO'), ('run', 'VB'), ('did', 'JJ'), ('the', 'DT'), ('police', 'NN'), ('pulled', 'VBD'), ('there', 'EX'), ('weapons', 'NNS'), ('out', 'IN'), ('no', 'DT'), ('was', 'VBD'), ('he', 'PRP'), ('shot', 'VBD'), ('no', 'DT'), ('armed', 'VBN'), ('bank', 'NN'), ('robber', 'NN'), ('rite', 'NN'), ('he', 'PRP'), ('wasnt', 'VBD'), ('shot', 'RB'), ('because', 'IN'), ('they', 'PRP'), ('never', 'RB'), ('seen', 'VBN'), ('a', 'DT'), ('gun', 'NN'), ('mmmmm', 'NN')]
#
# Name seriously thinking about making the switch from telecom marketing marketing to banking can you see Name as a bank teller i at BankA i can ha
# [('Name', 'NNP'), ('seriously', 'RB'), ('thinking', 'VBG'), ('about', 'IN'), ('making', 'VBG'), ('the', 'DT'), ('switch', 'NN'), ('from', 'IN'), ('telecom', 'NN'), ('marketing', 'NN'), ('marketing', 'NN'), ('to', 'TO'), ('banking', 'NN'), ('can', 'MD'), ('you', 'PRP'), ('see', 'VB'), ('Name', 'NNP'), ('as', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('i', 'PRP'), ('at', 'IN'), ('BankA', 'NNP'), ('i', 'PRP'), ('can', 'MD'), ('ha', 'VB')]
#
# Name thinking of being a bank teller at BankD
# [('Name', 'NNP'), ('thinking', 'NN'), ('of', 'IN'), ('being', 'VBG'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankD', 'NNP')]
#
# it seems like every BankA location i go into the bank tellers have a attitude problem even the managers called the customer service line line heard nothing BankB
# [('it', 'PRP'), ('seems', 'VBZ'), ('like', 'IN'), ('every', 'DT'), ('BankA', 'NNP'), ('location', 'NN'), ('i', 'PRP'), ('go', 'VBP'), ('into', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('tellers', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('attitude', 'NN'), ('problem', 'NN'), ('even', 'RB'), ('the', 'DT'), ('managers', 'NNS'), ('called', 'VBN'), ('the', 'DT'), ('customer', 'NN'), ('service', 'NN'), ('line', 'NN'), ('line', 'NN'), ('heard', 'NN'), ('nothing', 'NN'), ('BankB', 'NNP')]
#
# just schooled my bank teller in math typical BankA BankA of lancaster
# [('just', 'RB'), ('schooled', 'VBD'), ('my', 'PRP$'), ('bank', 'NN'), ('teller', 'NN'), ('in', 'IN'), ('math', 'NN'), ('typical', 'JJ'), ('BankA', 'NNP'), ('BankA', 'NNP'), ('of', 'IN'), ('lancaster', 'NN')]
#
# life of a bank teller at BankA life of a bank teller at BankAy modern videos
# [('life', 'NN'), ('of', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('life', 'NN'), ('of', 'IN'), ('a', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankAy', 'NNP'), ('modern', 'JJ'), ('videos', 'NNS')]
#
# Name i have no chill i strbankeht up asked the bank teller at BankD if he knows anything about their part in accepting slaves as collateral  he told me all he knows is that the guy on the monopoly game is based on BankD  Name BankD  that he had ties to Name  e  ford  so cuz they had so much money they opened a bank then i read him the article i found  together we solved the mystery lmao so now were both comfortable w BankD
# [('Name', 'NNP'), ('i', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('chill', 'NN'), ('i', 'PRP'), ('strbankeht', 'VBP'), ('up', 'RP'), ('asked', 'VBN'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankD', 'NNP'), ('if', 'IN'), ('he', 'PRP'), ('knows', 'VBZ'), ('anything', 'NN'), ('about', 'IN'), ('their', 'PRP$'), ('part', 'NN'), ('in', 'IN'), ('accepting', 'NN'), ('slaves', 'NNS'), ('as', 'IN'), ('collateral', 'JJ'), ('he', 'PRP'), ('told', 'VBD'), ('me', 'PRP'), ('all', 'DT'), ('he', 'PRP'), ('knows', 'VBZ'), ('is', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('guy', 'NN'), ('on', 'IN'), ('the', 'DT'), ('monopoly', 'NN'), ('game', 'NN'), ('is', 'VBZ'), ('based', 'VBN'), ('on', 'IN'), ('BankD', 'NNP'), ('Name', 'NNP'), ('BankD', 'NNP'), ('that', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('ties', 'NNS'), ('to', 'TO'), ('Name', 'NNP'), ('e', 'NN'), ('ford', 'NN'), ('so', 'RB'), ('cuz', 'NN'), ('they', 'PRP'), ('had', 'VBD'), ('so', 'RB'), ('much', 'RB'), ('money', 'NN'), ('they', 'PRP'), ('opened', 'VBD'), ('a', 'DT'), ('bank', 'NN'), ('then', 'RB'), ('i', 'PRP'), ('read', 'VBP'), ('him', 'PRP'), ('the', 'DT'), ('article', 'NN'), ('i', 'PRP'), ('found', 'VBD'), ('together', 'RB'), ('we', 'PRP'), ('solved', 'VBD'), ('the', 'DT'), ('mystery', 'NN'), ('lmao', 'NN'), ('so', 'RB'), ('now', 'RB'), ('were', 'VBD'), ('both', 'DT'), ('comfortable', 'JJ'), ('w', 'NN'), ('BankD', 'NNP')]
#
# miss BankA bank teller Name sorry my deposit in some singles annoyed you next time Name making my deposit in pennies just to annoy you
# [('miss', 'NN'), ('BankA', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('Name', 'NNP'), ('sorry', 'NN'), ('my', 'PRP$'), ('deposit', 'NN'), ('in', 'IN'), ('some', 'DT'), ('singles', 'NNS'), ('annoyed', 'VBD'), ('you', 'PRP'), ('next', 'JJ'), ('time', 'NN'), ('Name', 'NNP'), ('making', 'VBG'), ('my', 'PRP$'), ('deposit', 'NN'), ('in', 'IN'), ('pennies', 'NNS'), ('just', 'RB'), ('to', 'TO'), ('annoy', 'VB'), ('you', 'PRP')]
#
# my bank is the best BankA i had a check come in wasnt sure about it and my bank teller stopped me and sed lets have your banker check it out cause this dosnt seem right and well it wasnt right that guy isnt getting my parts all i have to say
# [('my', 'PRP$'), ('bank', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('BankA', 'NNP'), ('i', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('check', 'NN'), ('come', 'NN'), ('in', 'IN'), ('wasnt', 'NN'), ('sure', 'NN'), ('about', 'IN'), ('it', 'PRP'), ('and', 'CC'), ('my', 'PRP$'), ('bank', 'NN'), ('teller', 'NN'), ('stopped', 'VBD'), ('me', 'PRP'), ('and', 'CC'), ('sed', 'VBD'), ('lets', 'NNS'), ('have', 'VBP'), ('your', 'PRP$'), ('banker', 'NN'), ('check', 'NN'), ('it', 'PRP'), ('out', 'RP'), ('cause', 'NN'), ('this', 'DT'), ('dosnt', 'NN'), ('seem', 'VBP'), ('right', 'JJ'), ('and', 'CC'), ('well', 'RB'), ('it', 'PRP'), ('wasnt', 'VBP'), ('right', 'RB'), ('that', 'IN'), ('guy', 'NN'), ('isnt', 'NN'), ('getting', 'VBG'), ('my', 'PRP$'), ('parts', 'NNS'), ('all', 'DT'), ('i', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('say', 'VB')]
#
# my BankD bank has touch screen terminals instead of bank tellers now i feel like Name Name Name in the fifth element now or something
# [('my', 'PRP$'), ('BankD', 'NNP'), ('bank', 'NN'), ('has', 'VBZ'), ('touch', 'JJ'), ('screen', 'NN'), ('terminals', 'NNS'), ('instead', 'RB'), ('of', 'IN'), ('bank', 'NN'), ('tellers', 'NNS'), ('now', 'RB'), ('i', 'PRP'), ('feel', 'VBP'), ('like', 'IN'), ('Name', 'NNP'), ('Name', 'NNP'), ('Name', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('fifth', 'JJ'), ('element', 'NN'), ('now', 'RB'), ('or', 'CC'), ('something', 'NN')]
#
# new Name school with a global reach BankDamnameste  Name Name school with a global reach BankD asset management stockport financial advisers  wealth managers
# [('new', 'JJ'), ('Name', 'NNP'), ('school', 'NN'), ('with', 'IN'), ('a', 'DT'), ('global', 'JJ'), ('reach', 'NN'), ('BankDamnameste', 'NNP'), ('Name', 'NNP'), ('Name', 'NNP'), ('school', 'NN'), ('with', 'IN'), ('a', 'DT'), ('global', 'JJ'), ('reach', 'NN'), ('BankD', 'NNP'), ('asset', 'NN'), ('management', 'NN'), ('stockport', 'NN'), ('financial', 'JJ'), ('advisers', 'NNS'), ('wealth', 'NN'), ('managers', 'NNS')]
#
# not surprised BankA hasnt replied to the bad comment only the good grace Name one of there bank tellers turned around a computer and showed me another customers confidential information they cant be bother to call me to find out more why BankA doesnt care not about there customers not about protecting the confidentiality of their customers they dont care cant wait for them to delete this
# [('not', 'RB'), ('surprised', 'VBN'), ('BankA', 'NNP'), ('hasnt', 'NN'), ('replied', 'VBD'), ('to', 'TO'), ('the', 'DT'), ('bad', 'JJ'), ('comment', 'NN'), ('only', 'RB'), ('the', 'DT'), ('good', 'JJ'), ('grace', 'NN'), ('Name', 'NNP'), ('one', 'CD'), ('of', 'IN'), ('there', 'EX'), ('bank', 'NN'), ('tellers', 'NNS'), ('turned', 'VBD'), ('around', 'IN'), ('a', 'DT'), ('computer', 'NN'), ('and', 'CC'), ('showed', 'VBD'), ('me', 'PRP'), ('another', 'DT'), ('customers', 'NNS'), ('confidential', 'JJ'), ('information', 'NN'), ('they', 'PRP'), ('cant', 'VBP'), ('be', 'VB'), ('bother', 'RBR'), ('to', 'TO'), ('call', 'VB'), ('me', 'PRP'), ('to', 'TO'), ('find', 'VB'), ('out', 'RP'), ('more', 'JJR'), ('why', 'WRB'), ('BankA', 'NNP'), ('doesnt', 'NN'), ('care', 'NN'), ('not', 'RB'), ('about', 'IN'), ('there', 'EX'), ('customers', 'NNS'), ('not', 'RB'), ('about', 'IN'), ('protecting', 'VBG'), ('the', 'DT'), ('confidentiality', 'NN'), ('of', 'IN'), ('their', 'PRP$'), ('customers', 'NNS'), ('they', 'PRP'), ('dont', 'VBP'), ('care', 'JJ'), ('cant', 'NN'), ('wait', 'NN'), ('for', 'IN'), ('them', 'PRP'), ('to', 'TO'), ('delete', 'VB'), ('this', 'DT')]
#
# ...
# [('stupid', 'JJ'), ('BankA', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('seriously', 'RB'), ('ten', 'VBN'), ('years', 'NNS'), ('and', 'CC'), ('you', 'PRP'), ('pulled', 'VBD'), ('this', 'DT'), ('sht', 'NN'), ('on', 'IN'), ('me', 'PRP'), ('stupid', 'JJ'), ('Name', 'NNP'), ('tossing', 'NN'), ('the', 'DT'), ('account', 'NN'), ('number', 'NN'), ('to', 'TO'), ('me', 'PRP'), ('rebanke', 'VB'), ('if', 'IN'), ('wasnt', 'NN'), ('that', 'IN'), ('window', 'NN')]
#
# talking craft beer and Name Name breweries with the bank teller while making a deposit got to love that BankA customer service
# [('talking', 'VBG'), ('craft', 'NN'), ('beer', 'NN'), ('and', 'CC'), ('Name', 'NNP'), ('Name', 'NNP'), ('breweries', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('while', 'IN'), ('making', 'VBG'), ('a', 'DT'), ('deposit', 'NN'), ('got', 'VBD'), ('to', 'TO'), ('love', 'VB'), ('that', 'IN'), ('BankA', 'NNP'), ('customer', 'NN'), ('service', 'NN')]
#
# the Name attitude i get from the bank tellers here make me want to never have an account with BankA they should just close this branch would have better service
# [('the', 'DT'), ('Name', 'NNP'), ('attitude', 'NN'), ('i', 'PRP'), ('get', 'VBP'), ('from', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('tellers', 'NNS'), ('here', 'RB'), ('make', 'VBP'), ('me', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('never', 'RB'), ('have', 'VB'), ('an', 'DT'), ('account', 'NN'), ('with', 'IN'), ('BankA', 'NNP'), ('they', 'PRP'), ('should', 'MD'), ('just', 'RB'), ('close', 'VB'), ('this', 'DT'), ('branch', 'NN'), ('would', 'MD'), ('have', 'VB'), ('better', 'JJR'), ('service', 'NN')]
#
# the bank teller at BankD just asked me if i had eaten breakfast yet such an odd question
# [('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankD', 'NNP'), ('just', 'RB'), ('asked', 'VBD'), ('me', 'PRP'), ('if', 'IN'), ('i', 'PRP'), ('had', 'VBD'), ('eaten', 'VBN'), ('breakfast', 'JJ'), ('yet', 'RB'), ('such', 'JJ'), ('an', 'DT'), ('odd', 'JJ'), ('question', 'NN')]
#
# the bank teller at BankD said ur Name Name lol i signed her business card lol and she waived the check cashing feel lol
# [('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankD', 'NNP'), ('said', 'VBD'), ('ur', 'NN'), ('Name', 'NNP'), ('Name', 'NNP'), ('lol', 'NN'), ('i', 'PRP'), ('signed', 'VBD'), ('her', 'PRP'), ('business', 'NN'), ('card', 'NN'), ('lol', 'NN'), ('and', 'CC'), ('she', 'PRP'), ('waived', 'VBD'), ('the', 'DT'), ('check', 'NN'), ('cashing', 'VBG'), ('feel', 'NN'), ('lol', 'NN')]
#
# the bank teller at BankA got me thinkin bout switchin financial institutions lol she was gorgeous and kinda flirtin with a kid glad i gotta go BankB  next week
# [('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('got', 'VBD'), ('me', 'PRP'), ('thinkin', 'VBP'), ('bout', 'IN'), ('switchin', 'NN'), ('financial', 'JJ'), ('institutions', 'NNS'), ('lol', 'NN'), ('she', 'PRP'), ('was', 'VBD'), ('gorgeous', 'JJ'), ('and', 'CC'), ('kinda', 'NN'), ('flirtin', 'NN'), ('with', 'IN'), ('a', 'DT'), ('kid', 'JJ'), ('glad', 'NN'), ('i', 'PRP'), ('gotta', 'VBP'), ('go', 'RB'), ('BankB', 'NNP'), ('next', 'JJ'), ('week', 'NN')]
#
# the BankD bank teller Name Name you stay in Name Name Name lmfao
# [('the', 'DT'), ('BankD', 'NNP'), ('bank', 'NN'), ('teller', 'NN'), ('Name', 'NNP'), ('Name', 'NNP'), ('you', 'PRP'), ('stay', 'VBP'), ('in', 'IN'), ('Name', 'NNP'), ('Name', 'NNP'), ('Name', 'NNP'), ('lmfao', 'NN')]
#
# the new racism is the denial of racism right wing folk would take an oath to Name that this was not the case would an american passport serve as Name i had a stupid bank teller at BankB tell me that an american passport was not id i looked at her and said this is id a drivers license license is only a license to drive the only purpose for a passport is as id lets get the brother an american passport
# [('the', 'DT'), ('new', 'JJ'), ('racism', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('denial', 'JJ'), ('of', 'IN'), ('racism', 'NN'), ('right', 'RB'), ('wing', 'VBG'), ('folk', 'NN'), ('would', 'MD'), ('take', 'VB'), ('an', 'DT'), ('oath', 'NN'), ('to', 'TO'), ('Name', 'NNP'), ('that', 'IN'), ('this', 'DT'), ('was', 'VBD'), ('not', 'RB'), ('the', 'DT'), ('case', 'NN'), ('would', 'MD'), ('an', 'DT'), ('american', 'JJ'), ('passport', 'NN'), ('serve', 'VB'), ('as', 'IN'), ('Name', 'NNP'), ('i', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('stupid', 'JJ'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankB', 'NNP'), ('tell', 'NN'), ('me', 'PRP'), ('that', 'IN'), ('an', 'DT'), ('american', 'JJ'), ('passport', 'NN'), ('was', 'VBD'), ('not', 'RB'), ('id', 'VBN'), ('i', 'PRP'), ('looked', 'VBD'), ('at', 'IN'), ('her', 'PRP$'), ('and', 'CC'), ('said', 'VBD'), ('this', 'DT'), ('is', 'VBZ'), ('id', 'VBN'), ('a', 'DT'), ('drivers', 'NNS'), ('license', 'NN'), ('license', 'NN'), ('is', 'VBZ'), ('only', 'RB'), ('a', 'DT'), ('license', 'NN'), ('to', 'TO'), ('drive', 'VB'), ('the', 'DT'), ('only', 'JJ'), ('purpose', 'NN'), ('for', 'IN'), ('a', 'DT'), ('passport', 'NN'), ('is', 'VBZ'), ('as', 'IN'), ('id', 'JJ'), ('lets', 'NNS'), ('get', 'VBP'), ('the', 'DT'), ('brother', 'NN'), ('an', 'DT'), ('american', 'JJ'), ('passport', 'NN')]
#
# time for no i didnt yes i did bank teller at BankB looks down her nose and ask well mr Name why dont you have an account with us me Name i got tired of loaning you guys money
# [('time', 'NN'), ('for', 'IN'), ('no', 'DT'), ('i', 'PRP'), ('didnt', 'VBP'), ('yes', 'NNS'), ('i', 'PRP'), ('did', 'VBD'), ('bank', 'NN'), ('teller', 'NN'), ('at', 'IN'), ('BankB', 'NNP'), ('looks', 'NNS'), ('down', 'IN'), ('her', 'PRP$'), ('nose', 'NN'), ('and', 'CC'), ('ask', 'NN'), ('well', 'RB'), ('mr', 'JJ'), ('Name', 'NNP'), ('why', 'WRB'), ('dont', 'NN'), ('you', 'PRP'), ('have', 'VB'), ('an', 'DT'), ('account', 'NN'), ('with', 'IN'), ('us', 'PRP'), ('me', 'PRP'), ('Name', 'NNP'), ('i', 'PRP'), ('got', 'VBD'), ('tired', 'JJ'), ('of', 'IN'), ('loaning', 'NN'), ('you', 'PRP'), ('guys', 'VBZ'), ('money', 'NN')]
#
# Name government sells Name stake BankDamnameste  uk government Name government sells Name stake BankD asset management stockport financial advisers  wealth managers
# [('Name', 'NNP'), ('government', 'NN'), ('sells', 'VBZ'), ('Name', 'NNP'), ('stake', 'NN'), ('BankDamnameste', 'NNP'), ('uk', 'NN'), ('government', 'NN'), ('Name', 'NNP'), ('government', 'NN'), ('sells', 'VBZ'), ('Name', 'NNP'), ('stake', 'NN'), ('BankD', 'NNP'), ('asset', 'NN'), ('management', 'NN'), ('stockport', 'NN'), ('financial', 'JJ'), ('advisers', 'NNS'), ('wealth', 'NN'), ('managers', 'NNS')]
#
# we found an atm card on top of the drive through machine in prescott today at BankA my wife turned it into the bank tellers if youre missing you card go inside and get it
# [('we', 'PRP'), ('found', 'VBD'), ('an', 'DT'), ('atm', 'NN'), ('card', 'NN'), ('on', 'IN'), ('top', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('drive', 'JJ'), ('through', 'IN'), ('machine', 'NN'), ('in', 'IN'), ('prescott', 'NN'), ('today', 'NN'), ('at', 'IN'), ('BankA', 'NNP'), ('my', 'PRP$'), ('wife', 'NN'), ('turned', 'VBD'), ('it', 'PRP'), ('into', 'IN'), ('the', 'DT'), ('bank', 'NN'), ('tellers', 'NNS'), ('if', 'IN'), ('youre', 'NN'), ('missing', 'VBG'), ('you', 'PRP'), ('card', 'NN'), ('go', 'VBP'), ('inside', 'RB'), ('and', 'CC'), ('get', 'VB'), ('it', 'PRP')]
#
# BankA bank tellers serve their customers coffee while we wait for a rep impressed
# [('BankA', 'NNP'), ('bank', 'NN'), ('tellers', 'NNS'), ('serve', 'VBP'), ('their', 'PRP$'), ('customers', 'NNS'), ('coffee', 'VBP'), ('while', 'IN'), ('we', 'PRP'), ('wait', 'VBP'), ('for', 'IN'), ('a', 'DT'), ('rep', 'NN'), ('impressed', 'VBN')]
#
# BankA intentionbanke keeps bank tellers below the threshold of hours per week in order to deny any benefits
# [('BankA', 'NNP'), ('intentionbanke', 'VBP'), ('keeps', 'NNS'), ('bank', 'NN'), ('tellers', 'NNS'), ('below', 'IN'), ('the', 'DT'), ('threshold', 'NN'), ('of', 'IN'), ('hours', 'NNS'), ('per', 'IN'), ('week', 'NN'), ('in', 'IN'), ('order', 'NN'), ('to', 'TO'), ('deny', 'VB'), ('any', 'DT'), ('benefits', 'NNS')]
#
# BankA seriously makes me wanna go punch every last one of them bank tellers in they fukin face like seriously
# [('BankA', 'NNP'), ('seriously', 'RB'), ('makes', 'VBZ'), ('me', 'PRP'), ('wanna', 'VBP'), ('go', 'RB'), ('punch', 'JJ'), ('every', 'DT'), ('last', 'JJ'), ('one', 'CD'), ('of', 'IN'), ('them', 'PRP'), ('bank', 'NN'), ('tellers', 'NNS'), ('in', 'IN'), ('they', 'PRP'), ('fukin', 'VBP'), ('face', 'NN'), ('like', 'IN'), ('seriously', 'RB')]
#
# BankA  bank tellers on Name are the slowest in town
# [('BankA', 'NNP'), ('bank', 'NN'), ('tellers', 'NNS'), ('on', 'IN'), ('Name', 'NNP'), ('are', 'VBP'), ('the', 'DT'), ('slowest', 'JJS'), ('in', 'IN'), ('town', 'NN')]
#
# went to Name last night if i didnt have stroke last night last night i probably never will Name lady Name check wont go through ok i said i lost my debt card maybe they have it flagged call bank it is not banke person says Name speaker phone on so we can figure this out Name teller i am telling you mam the check is denied bank person says on speaker phone im telling you it should go through you must be doing it wrong needless to say walk out of Name no groceries in hand with bank teller telling it is Name fault and Name saying it is banks fault going to bank today and ask BankA  if they can do my shopping for me today because i have no time uuuggg i need to get out of this bank
# [('went', 'VBD'), ('to', 'TO'), ('Name', 'NNP'), ('last', 'JJ'), ('night', 'NN'), ('if', 'IN'), ('i', 'PRP'), ('didnt', 'VBP'), ('have', 'VBP'), ('stroke', 'NN'), ('last', 'JJ'), ('night', 'NN'), ('last', 'JJ'), ('night', 'NN'), ('i', 'PRP'), ('probably', 'RB'), ('never', 'RB'), ('will', 'MD'), ('Name', 'VB'), ('lady', 'RB'), ('Name', 'NNP'), ('check', 'NN'), ('wont', 'NN'), ('go', 'VB'), ('through', 'IN'), ('ok', 'NN'), ('i', 'PRP'), ('said', 'VBD'), ('i', 'PRP'), ('lost', 'VBD'), ('my', 'PRP$'), ('debt', 'NN'), ('card', 'NN'), ('maybe', 'RB'), ('they', 'PRP'), ('have', 'VBP'), ('it', 'PRP'), ('flagged', 'VBD'), ('call', 'NN'), ('bank', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('banke', 'VB'), ('person', 'NN'), ('says', 'VBZ'), ('Name', 'NNP'), ('speaker', 'NN'), ('phone', 'NN'), ('on', 'IN'), ('so', 'RB'), ('we', 'PRP'), ('can', 'MD'), ('figure', 'VB'), ('this', 'DT'), ('out', 'RP'), ('Name', 'NNP'), ('teller', 'NN'), ('i', 'PRP'), ('am', 'VBP'), ('telling', 'VBG'), ('you', 'PRP'), ('mam', 'VBP'), ('the', 'DT'), ('check', 'NN'), ('is', 'VBZ'), ('denied', 'VBN'), ('bank', 'NN'), ('person', 'NN'), ('says', 'VBZ'), ('on', 'IN'), ('speaker', 'NN'), ('phone', 'NN'), ('im', 'NN'), ('telling', 'VBG'), ('you', 'PRP'), ('it', 'PRP'), ('should', 'MD'), ('go', 'VB'), ('through', 'IN'), ('you', 'PRP'), ('must', 'MD'), ('be', 'VB'), ('doing', 'VBG'), ('it', 'PRP'), ('wrong', 'JJ'), ('needless', 'NN'), ('to', 'TO'), ('say', 'VB'), ('walk', 'NN'), ('out', 'RP'), ('of', 'IN'), ('Name', 'NNP'), ('no', 'DT'), ('groceries', 'NNS'), ('in', 'IN'), ('hand', 'NN'), ('with', 'IN'), ('bank', 'NN'), ('teller', 'NN'), ('telling', 'VBG'), ('it', 'PRP'), ('is', 'VBZ'), ('Name', 'NNP'), ('fault', 'NN'), ('and', 'CC'), ('Name', 'NNP'), ('saying', 'VBG'), ('it', 'PRP'), ('is', 'VBZ'), ('banks', 'NNS'), ('fault', 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('bank', 'NN'), ('today', 'NN'), ('and', 'CC'), ('ask', 'NN'), ('BankA', 'NNP'), ('if', 'IN'), ('they', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('my', 'PRP$'), ('shopping', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('today', 'NN'), ('because', 'IN'), ('i', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('time', 'NN'), ('uuuggg', 'NN'), ('i', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('get', 'VB'), ('out', 'IN'), ('of', 'IN'), ('this', 'DT'), ('bank', 'NN')]
#
# BankA after  years with BankA bank with Name account business account and personal account i closed them all service is not at all part of the marketing plan for this bank tellers are often not trained not just in one city or bank but numerobankes
# [('BankA', 'NNP'), ('after', 'IN'), ('years', 'NNS'), ('with', 'IN'), ('BankA', 'NNP'), ('bank', 'NN'), ('with', 'IN'), ('Name', 'NNP'), ('account', 'NN'), ('business', 'NN'), ('account', 'NN'), ('and', 'CC'), ('personal', 'JJ'), ('account', 'NN'), ('i', 'PRP'), ('closed', 'VBD'), ('them', 'PRP'), ('all', 'DT'), ('service', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('at', 'IN'), ('all', 'DT'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('marketing', 'NN'), ('plan', 'NN'), ('for', 'IN'), ('this', 'DT'), ('bank', 'NN'), ('tellers', 'NNS'), ('are', 'VBP'), ('often', 'RB'), ('not', 'RB'), ('trained', 'VBN'), ('not', 'RB'), ('just', 'RB'), ('in', 'IN'), ('one', 'CD'), ('city', 'NN'), ('or', 'CC'), ('bank', 'NN'), ('but', 'CC'), ('numerobankes', 'VBZ')]
#
# when you walk into BankD bank and the bank teller knows you by your full name and you have a relationship banker all the other bullshit dont matter qgtm
# [('when', 'WRB'), ('you', 'PRP'), ('walk', 'VBP'), ('into', 'IN'), ('BankD', 'NNP'), ('bank', 'NN'), ('and', 'CC'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('knows', 'VBZ'), ('you', 'PRP'), ('by', 'IN'), ('your', 'PRP$'), ('full', 'JJ'), ('name', 'NN'), ('and', 'CC'), ('you', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('relationship', 'NN'), ('banker', 'NN'), ('all', 'DT'), ('the', 'DT'), ('other', 'JJ'), ('bullshit', 'NN'), ('dont', 'NN'), ('matter', 'NN'), ('qgtm', 'NN')]
#
# why does the bank teller always ask which account Name like to withdrawal from when she can clearly see on her screen that only one account has enough for that amount think BankD protocolisntalwayswise
# [('why', 'WRB'), ('does', 'VBZ'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('always', 'RB'), ('ask', 'VB'), ('which', 'WDT'), ('account', 'NN'), ('Name', 'NNP'), ('like', 'IN'), ('to', 'TO'), ('withdrawal', 'JJ'), ('from', 'IN'), ('when', 'WRB'), ('she', 'PRP'), ('can', 'MD'), ('clearly', 'RB'), ('see', 'VB'), ('on', 'IN'), ('her', 'PRP$'), ('screen', 'NN'), ('that', 'WDT'), ('only', 'RB'), ('one', 'CD'), ('account', 'NN'), ('has', 'VBZ'), ('enough', 'RB'), ('for', 'IN'), ('that', 'DT'), ('amount', 'NN'), ('think', 'VBP'), ('BankD', 'NNP'), ('protocolisntalwayswise', 'NN')]
#
# why is the bank teller for BankA in the rb vons so fucking attractive like god damn Name supposed to be at work and Name over here making a deposit for  minutes
# [('why', 'WRB'), ('is', 'VBZ'), ('the', 'DT'), ('bank', 'NN'), ('teller', 'NN'), ('for', 'IN'), ('BankA', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('rb', 'NN'), ('vons', 'NNS'), ('so', 'RB'), ('fucking', 'VBG'), ('attractive', 'JJ'), ('like', 'IN'), ('god', 'NN'), ('damn', 'RB'), ('Name', 'NNP'), ('supposed', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('at', 'IN'), ('work', 'NN'), ('and', 'CC'), ('Name', 'NNP'), ('over', 'IN'), ('here', 'RB'), ('making', 'VBG'), ('a', 'DT'), ('deposit', 'NN'), ('for', 'IN'), ('minutes', 'NNS')]
#
# wow  bank tellers in bronx BankD bank bank busted for hacking in ppls account watch out peeps
# [('wow', 'NN'), ('bank', 'NN'), ('tellers', 'NNS'), ('in', 'IN'), ('bronx', 'NN'), ('BankD', 'NNP'), ('bank', 'NN'), ('bank', 'NN'), ('busted', 'VBD'), ('for', 'IN'), ('hacking', 'NN'), ('in', 'IN'), ('ppls', 'NNS'), ('account', 'VBP'), ('watch', 'NN'), ('out', 'IN'), ('peeps', 'NNS')]
#
# your horrible bank tellers and lack of helping with a fraudulent chargewhich continues with multiple overdraft chargesis going to end today bye BankB Name bank is a joke
# [('your', 'PRP$'), ('horrible', 'JJ'), ('bank', 'NN'), ('tellers', 'NNS'), ('and', 'CC'), ('lack', 'VBP'), ('of', 'IN'), ('helping', 'VBG'), ('with', 'IN'), ('a', 'DT'), ('fraudulent', 'NN'), ('chargewhich', 'WDT'), ('continues', 'VBZ'), ('with', 'IN'), ('multiple', 'JJ'), ('overdraft', 'NN'), ('chargesis', 'NN'), ('going', 'VBG'), ('to', 'TO'), ('end', 'VB'), ('today', 'NN'), ('bye', 'NN'), ('BankB', 'NNP'), ('Name', 'NNP'), ('bank', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('joke', 'NN')]

# %%
try:
    with open('data/advising.pickle', 'rb') as f:
        picked_data = pickle.load(f)
except NameError as e:
    print(e)

# %%
# Define Chunker Rules
# Taken from Su Nam Kim Paper...
#     {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
#     {<VB.*>+<RB><JJ.*>+}
#     {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
noun_chunker = nltk.RegexpParser('''
    NP:
        {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
        {<VB.*>+<RB><JJ.*>+}
    AJ:
        {<NN.*|N.*>+?<JJ.*>+<NN.*|N.*>+?}
''')

# Key Phrases from Facebook
noun_phrases = []
adj_phrases = []
for i, comment in enumerate(picked_data):
    tree = noun_chunker.parse(comment)
    
    noun_phrase = [w for w in get_terms(tree, 'NP')]
    if len(noun_phrase) > 0:
        for i, phrase in enumerate(noun_phrase):
            noun_phrases.append(phrase)
    
    adj_phrase = [w for w in get_terms(tree, 'AJ')]
    if len(adj_phrase) > 0:
        for i, phrase in enumerate(adj_phrase):
            adj_phrases.append(phrase)

# %%
noun_phrases[:100]
# Out:
# []

# %%
adj_phrases[:100]
# Out:
# [['rebanke', 'everyday', 'times'],
#  ['faces', 'tough', 'new', 'broadband'],
#  ['faces', 'tough', 'new', 'broadband'],
#  ['tests',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers'],
#  ['ambassador',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers'],
#  ['f', 'bankd', 'worst', 'customer'],
#  ['freakin', 'happy', 'november'],
#  ['court',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers'],
#  ['ur', 'own', 'bank'],
#  ['ur', 'own', 'rates'],
#  ['god', 'damn', 'well'],
#  ['i', 'wouldnt', 'wan', 'na'],
#  ['needs', 'extra', 'training'],
#  ['banka', 'bad', 'reputation'],
#  ['math', 'typical', 'banka'],
#  ['bankay', 'modern', 'videos'],
#  ['reach',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers'],
#  ['customers', 'confidential', 'information'],
#  ['account', 'fb', 'new', 'account'],
#  ['day', 'glad', 'i'],
#  ['loan',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers'],
#  ['misselling',
#   'business',
#   'loans',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers'],
#  ['godiva', 'dark', 'chocolate'],
#  ['bankb', 'everyday', 'lmao'],
#  ['bankd', 'asset', 'management', 'stockport', 'financial', 'advisers'],
#  ['bout', 'switchin', 'financial', 'institutions'],
#  ['kid', 'glad', 'i'],
#  ['stake',
#   'bankd',
#   'asset',
#   'management',
#   'stockport',
#   'financial',
#   'advisers']]

# %% [markdown]
# ## Bank Products

# %%
df_bank_products = pd.read_csv("data/product.csv", index_col="AutoID")
print(df_bank_products.describe())
df_bank_products.head()
# Out:
#               Year        Month
# count  3039.000000  3039.000000
# mean   2014.332675     7.712405
# std       0.471249     3.637664
# min    2014.000000     1.000000
# 25%    2014.000000     5.000000
# 50%    2014.000000     9.000000
# 75%    2015.000000    10.000000
# max    2015.000000    12.000000
#               Date  Year  Month MediaType  \
# AutoID
# 79        1/1/2015  2015      1  facebook
# 93      11/18/2014  2014     11  facebook
# 108       4/3/2015  2015      4  facebook
# 165       9/5/2014  2014      9  facebook
# 431       4/6/2015  2015      4  facebook
#
#                                                  FullText
# AutoID
# 79      if niggas keep inboxing w they Name shit all l...
# 93      swear i go Name Name Name Name i come in Name ...
# 108     if anyone has a BankA account i would strongly...
# 165     kudos todayto my financial institution BankD b...
# 431     if u have any active bank active bank account ...

# %%
for text in df_bank_products["FullText"].iloc[:100]:
    print(text.strip())
# Out:
# if niggas keep inboxing w they Name shit all like if i got a fuvking BankD bank card card Name gon violate like stfu b       fuck man
# swear i go Name Name Name Name i come in Name Name off days Name Name BankD Name  Name hour Name Name i see Name bank account Name makes it Name worth Name
# if anyone has a BankA account i would strongly recommend you checking your bank account to make sure that you do not have any unauthorized transactions going to paypal i had money with drawn from my account via paypal to someone i dont evem kno
# kudos todayto my financial institution BankD bank they caught over half a dozen fraudulent purBankDs on my credit card this morning they had to cancel the card because of it hopefully they will catch the Name Name Name fingers are crossed Namei have not been in a home depot in over a yearName knows
# if u have any active bank active bank account Name credit union union account and want to make  quick and   guaranteed add Name me or message me my brother works in BankD bank and can make a deposit into your account you can have  or a negative balance you can still make money hit Name up seriouse people only anywhere in the u s
# Name boomed on i want to propose f u get some Name Name Name new Name yankees new Name Name new Name Name true religion brand Name Name  Name  Name Name greenthats my baby  no fighting babe i love you yes lol son hammer beyonc   year theory BankD and capitol one bank card Name Name for  million dollars Name my wife gucci shoes Name lets play for  million today if nobody wants to get the deal through and kobe has to play for  more years  Name Name still no response whats hove doing rollsroyce motor cars then motor Name Name go to my room only because i have to live to let it live again movies tiffany  Name
# attention Name waste your tax money cause you have it earn extra money within  business days or withing  minutes with a small investment make your money work for it self if you have a bank account with Name Name BankC Name me Name send Name a requesr or Name if you Name invest a small amount serious inquiries only
# and BankD bank declines my debit card in hvar all the trouble i went to registering my trip with their geographiBankC ankechallenged employee and it didnt work  call laterthanks tmobileand i am assured that i will not experience this again Name
# and Name Name has BankA my bank account has purpose again
# and BankA increased my credit card limit by  k why you do this to Name
# Name is spending lunch trying to figure out if the photo of the cow on his BankA platinum card is a different cow than the one on his BankA debit card i will never get tired of this man
# Name BankA my debit card was able to work to deposit money yesturday but its declinded now that i need a lil today ill see you tommorow mr BankA till then hppy turkey time yall
# BankAdebit card blocked please reactivate nice try
# Name india bank Name canara bank  first governor of Name mr Name Name  first indian governor of Name mr c Name Name  first bank to introduce atm in india hsbc  first bank to introduce savings presidency bank in   first bank to introduce cheque system system bengal bank   first bank to introduce internet banking banking Name bank  first bank to introduce mutual fund state bank of Name  first bank to introduce Name Name central bank of Name  first foreign bank in india comptoire d escompte Name paris of france in   first joint stock bank of Name allahabad bank  first bank that is oldest public Name bank in indiaallahabad bank  first indian bank to open branch outside india in london in  bank of Name  first indian bank started with indian capital indigenous bank of Name punjab national bank bank  first regional rural bank name prathama grameen bank bank Name startedby syndicate bank  first bank to launch branch in foreignwas bank of Name in  in london uk  Name bank to introduce credit card in india was central bank of Name Name card   first bank to introduce Name Name in india was BankC bank in bangalore in
# hey chandler dutch is opening up bank account today at BankD bank inside Name on willow creek Name hooking anyone up that sets up a free checking account with direct deposit with a free  go see him today is the last day not a joke i got  yesterdayawessooommmeeeedo it up peeps
# warning     i just received a recorded call from utah claiming to be BankB and stating that my debit card has been locked it asked me to put in my  digit number to unlock my i did not do it i hung up and called BankB who confirmed it is a big scam right now
# alert    i just received a text saying BankBurgent notification call PHONE and yeah i know i shouldnt have but i did i got a recording that said my debit card has been suspended due to a security issue so they needed me to leave my s s on their recording did anyone else get this
# havent gotten your children nothing for christmas yet not enough money for what they want havent had enough money to do something nice for the family christmas in  weeks dirmsg me to find out if your interested Name my offer you never know unless you try a lot of people promoting money but Name really getting money whos really making progress whos really about there business and money   rent due   car insurance   car note     Name Name   phone bill Name light bill Name   need to pay bills period have an active bank card with no cash  need cash if you wanna make a legitimate  serious people only banke BankC BankD Name BankB banke
# having a bigger dreams paper BankD BankD still a hobby bank account shapeless still cant count the zeros omo mi
# beeline mobile recharge mobile recharge is now available in laos send a top up from the usa using your credit card from BankA  bank
# Name Name   cashBankB  on orders avove rs   for BankC credit and debit cards holders flipkart
# BankDs cybersecurity breach raises serious concerns banks like it are connected to major stock exchanges  credit card networks
# Name i need confirm hacker wey fit do Name insyd new BankA  bank account
# vfunnycd i like to think Name taught BankC a valuable lesson about handing out credit cards all willynilly rettwit funny
# welssBankA is holding debit card payments several days prior to processing i have had an account with them for  years and the debit purBankDs were usubanke within an hour or a day for gas stations and paypal was two days max BankB was using this tactic to trap those using the electronic balance for available funds with overdraft fees and now BankA
# whyiwork Name pay for an attorney so that this blasted BankA bank will give me a simple transaction list for my deceased grandmothers checking account
# if u have any active bank account Name credit union union account and want to make  quick and   guaranteed add Name me or message me my brother works in BankD bank and can make a deposit into your account you can have  or a negative balance you can still make money hit Name up seriouse people only anywhere in the u s
# do you have an active bank account or banke and interested in making some quick cash my brother works in BankD bank bank and he doing this thing where hes putting checks into account and you can be with any bank or banke you can make up to  and u can have zero balance or even be in the negatives and it will still go threw hit me BankB  for more info if your interested no Name
# offer for opening BankA  account but you must fund and use the account for at least  monthsuse debit card  times a month  msg me
# within an hour Name for details or if u got a BankD bank account or willing to make one Nameloan
# for each withdrawal out of my savings account yall just love charging outrageous amounts for everything like i have that extra cash to throw away and when i call to maybe get some help you tell me its a federal law and sorry well thank you BankB how likes to steal customers money i will be closing my accounts and changbankes have a great day
# z says BankD bank account says thats impossibru
# minutes they said we understand you dont have a debit card they said BankB is a shitty fuckbanke Name my lunch is almost over and what the fuck
# banking with BankB navyfed usaa BankA  need some in your pocket Name take yaa girl out need to pay a few bills   doing money transfers  today with no bank card needed dirmsg me for more info   banking with BankB navyfed usaa BankA  need some in your pocket Name take yaa girl out need to pay a few bills   doing money transfers  today with no bank card needed dirmsg me for more info
# with a Name BankD bank card Name trying get you some nfs
# has decided to pummel me one last time with my debit card showing fraudulent use i dont have a BankA within  miles and have next to no access to my funds for  business days awesome
# is the scam number just told me i need give info about my lost BankA credit card lol i have o credit cards
# nd person i know where u authorized Name debit hits checking account with BankA bank check your statements as apparently the first charge is minimal but the next one isnt
# bank account money taken from nevada ste bank equitably bank Name bank cheyenne state bank not only that nevada unemployment benefits filed using my cell phone they stoled and my original hard drive that Name king has which means BankA  kyle Name and the comea shelter shelter is behind all there fire walls not only them but Name bank of the west Name n go also who would have  atm shut down in a row when trying to use a banks debit card
# times in a year BankB has sent me a new debit card does this happen with bankes or is BankB just easier to hack in to
# for BankC credit card and  for Name bank credit cards are valid for the offer please read complete t  Name of the offer
# dollars over drawn in my bank account and no money for gas anyone wanna help and go to BankA  and put a lil money on my account it can b a secret gift or i can pay yu BankB  either way i dont have to be there for it to get put in
# million account of BankD  Name BankD  Name hacked after my trip to paris i became a victim to this cyber crime my credit card was being used in the us these criminals are on our tails scared of using these banking apps now Name
# a big warning to all my friends on Name Name sure everyone knows about the hacking to BankD costumers i just got a warning in my personal email from BankD bank about fraudulent transactions using my debit card i just spoke to a costumer service representative and confirmed that my information has been compromised these crooks were trying to use my information in georgia i just wanted to let everyone know this and to check every transaction you made the last couple of days and call immediately if you suspect fraud
# a busy afternoon coming up got an email at  am from BankD that one of my credit cards had a  charge attempted this morning when the Name three digit code didnt match or wasnt supplied it raised a flag reviewing the last few charges showed a   charge had been attempted then reversed online cancelled the card and now will be checking all other credit cards cards and account
# a BankD debit card belonging to Name l Name was found on floor by gas pump at exxon  eleven on Name chica and palm blvdacross taco palenque  given to female attendant inside store around pm
# a BankD visa debit card was found in the womens restroom in Name it was just dropped off at the mtcc welcome desk
# a credit card was turned into the team today it is a BankA debit card call Name to see if it is yours  PHONE i will have it at the Name Name market tomorrow between am and pm
# a friend of mine got a call yesterday from BankB security department they were inquiring about suspicious charges on his wifes credit card and asked if there were any problems he told them that her card was stolen about  months ago when they asked why he had not reported it stolen he said that whoever stole it was spending a lot less than she was
# a good friend of mine lost  in his BankD bank account  years ago identity theft is real keylogger is real if youre not sure what that is visit this website and educate yourself take action now as low as  a month you can secure youre computer from cyber crime
# a look facebook friends if u have an bank account thats active BankB BankC bank Name BankD Name fifth third Name Name in box Name now you can make  only serious Name only
# a lot of people ask me why i dont get a bank account in california but stcu makes my life so easy with their BankCs at  and shared branching with every major banke here and they always seem to have my BankB  on everything including my one and only car loan from my chevy cavalier cavalier as my Name is paid in full i think this is why i have continued to use them for the past decade and my family as well
# a Name tried to use my bank card to get some gift cards lmao BankB is not going they shut that Name down Name and sent me a text like nigga is this you Name shame on them helloworld
# a recent study shows that gals from poor not well to do families are the ones that BankD after men with fat bank account  married men i need to prove this info so this valentine week am conducting a research which i shall subject to a statistical analysis using ttest with a sample size of  randomly picked gals Name thesis should be ready by sundy th february  watch the space
# a us bank atm machine just ate my BankB debit card on payday i think its a sign Name
# a warning for anyone that banks at BankA  your debit card may have been cloned mine was and thankfully i have red flags Name my account set up they were only successful at  debits for gift card purBankDs and bank stopped it thank god please check your account to the Name Name did this they have u on camera and we know your Name tampa and we have signed with the bank to have you arrested you Name they have your name Name cards no good no more Name waste your time my account is closed
# a warning to all yesterday i received a phone call from someone who said that they were from BankB they wanted to know if i wanted to lower my intrist rate i said yes they wanted to know the last  digits of my credit card i told them that if they were from BankB that they have it i asked them to read it BankB  to me and i will tell them if it was right they said that they needed to know the the numbers to make sure that i was the card holder i wouldnt give it to them and hung up they called me BankB  three times before i shut my cell phone off never give out your credit card number to anyone you dont know
# a BankA credit card was found on friday nightmarch thwith the name of Name Name Name extend this message to her if anyone has any way of contacting her thank you
# a wise woman once told me to face my problems and that its okay to ask for help took the plunge today and called BankD bank about my credit card they worked out a payment plan with me and waived all my late fees aaahhhh one call down momalwaysknows BankDhashumanbeingemployees byebyecreditcards
# Name got a BankD bank account and wants to make money
# about  years ago my purse was stollen and i filed a police report i put in a claim with BankB and gave them my police report number my debit card was charged a few hundred dollars at a gas station and at the time over drafted my bank account they kept charging me overdraft fees which added up to hundreds on top of the money that was stolen they denied my claim the reasoning was because i had used that gas station once before made hundreds of dollars at one gas station a legit purBankD even with my police report too biggest scam company of all time
# about to check BankD bank account
# about to get a new checking and savings account goodbye BankB BankB go suck it
# about to head to BankA close my empty checking account then take a walk dont know where need to clear my head got alot on my plate i just dont have time for fake friends drama or broke bitches ima finish this brew an leave
# absolute five stars for this bank i have been with BankB ever sense i could get a job and earn money i have never been mistreated most recently i made a transaction within my account that overdrew my checking account the mistake was mine and mine alone i was charged the usual overdraft fees i called in with a sliver of hope that they could help me they did they took off the overdraft fee and reversed the transaction amoung my account so that i could fix my mistake my sliver of hope turned into great respect for BankB thanks
# accidentbanke overdrew my bank account for  got charged  in overdraft fees called BankB and explained it was an oversight on my part and simply asked if they could please forgive my fee and the lady was super nice and said no problem and refunded my money i didnt catch her name but she was awesome and i wish all the customer service people were like her
# Name spoke to the fraud dept at our BankD bank bank and they said they were investigating it they sent us the email regarding the transactions in the first place we reported it to the krogers that we used the day before we also reported it two other places of business that we used the debit card at a couple of days before the numbers were used also filed a police report good idea to ask the stores to check their cameras
# Name was rummaging my wallet and i told him it had credit cards and money he handed Name Name Name my BankA card and said it was horse money
# Name Name the only fee you ever see on a free checking account is if you get an overdraft fee and most of the time if you call and explain your mistake they will take the fee off Name the only fee Name ever seen in my  years of being with a banke i had BankB before and didnt even realize how much i was getting raped
# after being with BankA for  yearsall of my adult lifethey have decided to start charging me to have a checking account with them i will not pay to keep my money in a bank this is how you lose business ill be sure to tell every one i know about this
# after having my bank account hacked and  multiple fraud charges at a winn Name in Name Name hello i live in miami BankC and dont drive can some brainiac come up with a system that when you swipe your card a pic comes up showing its you even gyms have these systems come on banks get with the program
# after i called BankA for a possible fraud in my account they cancel my debit card right away after that they said i going to get the new card in  business days and nothing yet i called BankB  to find out what happen to my card they told my they dont do that by the phone i have to go to a location to order a new card Name the kind of crap we as customer we need to deal with the banks they do that maybe to keep our money longer in their account to make money
# after my little outing today i am making a suggestion that may save u heartache in the future never put your name on a checking account with your spouse i went to banke banke to verify that my savings account was still active cause in nov this is where my social security security will be sent my account was rolled over in my deceased and my checking account they charged my deceased husbands amount on the account of  dollars in order to get a savings accountand i never wrote a checki have to pay in cash  to get an account because i was on the checking account i am expected to pay not happening in my lifetime guess its BankA for me cause my deceased husband pulled real boners with banke too i learn too late but who would have thought just remember that nobody likes your money like u do
# again my bank account got hacked at BankD bank bank Name i the only one having this problem with BankD bank bank
# again screwed over by BankA went to the store to discover my debit card has expired thought id Name make a quick run to BankA to get a new one order since all my money is in the bank only to find out that the reason i oft get a debit card is that a savings account sent to collections which it shouldnt have been i made sure they were in good standings with the bank manager and then had her close it i do not like this lady nor do i feel she cares about her customers but she promised me it was taken care of ok so i have to get that strbankehtened out now but tell me this BankAsince your bank person couldntwhy could my husband have his new debit card when the savings and checking account are joint so mad i am done with BankA and Name dont with you taking my money Name done with you
# alarm went off at am n boy was i mad got to work n called my debit card in that frown turned into the biggest smile either BankD is playing games wit me or my check was rebanke  dollars this wk i think its safe to say jesus did dat  hrs down  more to go  more wk of tunnel vision n Name off   wks blessed
# alcohol that stuffs not for me one time i got wasted and went to BankB and opened a savings account account
# alerettwit friends with account at BankB beware of fraud text messages and phone calls about your account or debit card being blocked it is a scam thieves are trying to get your info
# alerettwit i just got an automated call from phone number  telling me my debit card has been deactivated i could enter my card number and expiration date date to have it reactivated but i dont bank with BankA
# alerettwit my son received an email from BankB stating that his debit card had an error and couldnt be used until he went to the web page provided and made corrections the link took him to what looked exactly like the BankB site only it wasnt asked him for all of his info including Name luckily he called BankB and reported it they said that day a million people had had their identities stolen beware
# alert check your checking account some lazy a hole physiBankC anke reproduced my debit card and went and emptied my account they went to  different BankA locations and did cash advances the lady in Name protection said i was the third person they did it to today what a bunch of losers i hope they get caught but i know they wont
# alerettwit i have  people i know got their bank accounts hacked BankD and BankC please check your account
# alesha teamkeke miller Name Name shared a photo anyone wanting to donate to teamkeke can also go to BankA bank account  please share this information so that it may reach our out of town supporters   with Name felton and  others ok here u Name everyone Name wants to donate to our baby funeral the family thanks everyone in advance for all your love and supporettwit Name is a movement Name lets keep her Name teamkeke teamkeke teamkeke
# all banks are except bankes happy for couple i worked for BankA  their thiefs cheaters n liars the banks are liars n they deserve to be held accountable they ruin peoples life for more n they make thousands of mistakes n turn the other way n destroy folks credit loan history bank account history just to make money on baking fees n win bankes jerks
# all BankD bank card holders please check your account they were hacked again
# all BankC checking folks be aware of your charges  recent occurances amongst my friends of stolen pin info debit cards cards beings used far far away from where they live
# all face book friends just got a text to call BankB with Name debit card do not even have anything to do with BankB they text me three times in a row and now my sister just called and she said she got one its a big scam so do not call
# all i want for valentines Name is Name BankD Name BankC bank card  lets make some shmoneyyyy
# all my friendsknow i do not write on this much this is worth telling eveyone about i was stupid and gave information i should not have i thought i was giving it to my bank BankD i had this bank account for  years they took me for all my money as a wire transfer now BankD will not give me any of my money BankB  i would like all my friends and family to know so you all will not be defrouded and screwed by the bank sorry i was stupid but please forward this so this will not happen to others they make you think the bank is asking for this information it looks very official please pass this information Name
# all my online shoppers be extremely careful during this holiday season i did majority shopping online this year and i was just informed by BankA they had to close my account because someone hacked into my walmart online account and attempted to make online purBankDs multiple attempts thanks to BankA they shut the account down because the multiple fraudulent attempts please watch your bank account and transition coming out
# all of my bills come out of my checking account automatiBankC anke so i only had two items that they wouldnt put through since they had a  day hold on a check my pilot fuel card and my Name payment to BankA which i just wired to them both today i put in a request to have both of those nsfs refunded since it only bounced because of the two day hold we will see the Name union makes plenty of money off of me to let those slide but if i must be punished then so be it
# all BankA bank cards are down nation wide confirmed thanks to shannon d for pointing that out to us
# all who hold BankC credit cards should cut them up and mail them to BankC
# all Name non ye dick riders riders Name Name down goo open up a BankC bank account
# all you antihalal hypocrites stop filling up your vehicles with saudi fuel then stop flying Name who is in partnership with the emirates except no imported goods that come across dubai world Name wharves in australia return your credit cards to BankC group bank Name australian businesses and workers in agriculture and manufacturing need all the help they can get Name about team stupid
# all you BankB account holders if you get a weird call stating that they are the bank and your debit card had been compromised ignore and hang up its a fraud if the bank is calling a rep will be on the phone not an automated recording just a Name
# Name Name Name read if you receive a text from BankB saying your debit card has been locked its a scam becareful everyone i have never even used that bank in my life and still received it
# aloha from the Name coffee house its time to get the f out of vegas Name my super subscriber just went through to my BankD bank account Name thank you guys so where should i go now
# alright Name be careful out there new phone scam they just tried to get me call comes in from PHONE so theres red flag  ebony Name answered it the recording says your BankB debit card has been locked enter your card number now as verification to have the lock removed first off i dont have a BankB debit or credit card she entered some random number just to see what would happen and it came BankB  on and said that was an invalid card number please check the number and enter it again to unlock my card Name things people will try sad part is for every person they dont get they trick four unsuspecting people
# alright friends and family the end of the quarter is near and Name just  checking account away from my bonus if you need an account let me know also if youve never been with BankA before you can qualify for  free just for opening and using your account

# %%
try:
    with open('data/product.pickle', 'rb') as f:
        picked_data = pickle.load(f)
except NameError as e:
    print(e)

# %%
# Define Chunker Rules
# Taken from Su Nam Kim Paper...
#     {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
#     {<VB.*>+<RB><JJ.*>+}
#     {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
noun_chunker = nltk.RegexpParser('''
    NP:
        {(<NN.*|N.*>+<VBZ><DT|RB>?<JJ.*><NN.*|N.*>+?)}
        {<VB.*>+<RB><JJ.*>+}
    AJ:
        {<NN.*|N.*>+?<JJ.*>+<NN.*|N.*>+?}
''')

# Key Phrases from Facebook
noun_phrases = []
adj_phrases = []
for i, comment in enumerate(picked_data):
    tree = noun_chunker.parse(comment)
    
    noun_phrase = [w for w in get_terms(tree, 'NP')]
    if len(noun_phrase) > 0:
        for i, phrase in enumerate(noun_phrase):
            noun_phrases.append(phrase)
    
    adj_phrase = [w for w in get_terms(tree, 'AJ')]
    if len(adj_phrase) > 0:
        for i, phrase in enumerate(adj_phrase):
            adj_phrases.append(phrase)
